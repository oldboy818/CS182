# %% [markdown]
# # Policy Gradients
# The goal in policy gradient algorithms is to maximize the expected returns of a policy $\pi_\theta$ with parameters $\theta$. Letting $\tau=((s_0, a_0, r_0), \ldots, (s_T, a_T, r_T) )$ denote a trajectory and $R(\tau)$ the return of $\tau$, this objective can be written as
# $$\max_{\theta} \mathbb E_{\tau \sim \pi_{\theta}}[R(\tau)].$$
#
# Using the REINFORCE trick, we can compute the policy gradient (the gradient of expected policy returns) as
# $$\sum_{t=0}^T \mathbb E_{s_t, a_t \sim \pi(\tau)} \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
#
# We can then estimate this with a very simple scheme.
# We first sample a trajectory $\tau = ((s_t, a_t, r_t))_{t=0}^\infty$ from our current policy, compute the discounted return of the trajectory as $R$, then take a stochastic estimate of the policy gradient as
#
# $$\sum_{t=0}^T \mathbb \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
# We can then repeat sample more trajectories to average the estimate over multiple samples.
# In practice, we will often use _discounted_ returns $\tilde R(\tau) = \sum_{t=0}^T \gamma^t r_t$ where $\gamma$ is the discount factor and our policy gradient estimate will simply replace the undiscounted returns with $\tilde R(\tau)$.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import gym
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import PG_Trainer
from deeprl.infrastructure.trainers import BC_Trainer

from deeprl.agents.pg_agent import PGAgent
from deeprl.policies.MLP_policy import MLPPolicyPG

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
pg_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_pg', #@param
    save_params = False, #@param {type: "boolean"}
    
    ep_len = 200, #@param {type: "integer"}
    discount = 0.95, #@param {type: "number"}

    reward_to_go = True, #@param {type: "boolean"}
    nn_baseline = False, #@param {type: "boolean"}
    dont_standardize_advantages = True, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 1000, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# ## Implementing policy gradients
# We will first compute a very naive policy gradient calculation by taking the whole discounted return of a trajectory. Fill out the method <code>_discounted_return</code> in <code>pg_agent.py</code>. Your error should be 1e-6 or lower.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_returns = pgagent._discounted_return(rewards)

expected_return = 6.49674307
return_error = rel_error(discounted_returns, expected_return)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       4 env_str = 'CartPole'
#       5 pg_args['env_name'] = '{}-v0'.format(env_str)
# ----> 6 pgtrainer = PG_Trainer(pg_args)
#       7 pgagent = pgtrainer.rl_trainer.agent
#       9 T = 10
#
# File ~/Library/CloudStorage/OneDrive-UOS/MAC/AI/CS182/CS182_HW/CS182/assignment4/deeprl/infrastructure/trainers.py:91, in PG_Trainer.__init__(self, params)
#      85 self.params['batch_size_initial'] = self.params['batch_size']
#      87 ################
#      88 ## RL TRAINER
#      89 ################
# ---> 91 self.rl_trainer = RL_Trainer(self.params)
#
# File ~/Library/CloudStorage/OneDrive-UOS/MAC/AI/CS182/CS182_HW/CS182/assignment4/deeprl/infrastructure/rl_trainer.py:55, in RL_Trainer.__init__(self, params)
#      44 ptu.init_gpu(
#      45     use_gpu=not self.params['no_gpu'],
#      46     gpu_id=self.params['which_gpu']
#      47 )
#      49 #############
#      50 ## ENV
#      51 #############
#      52
#      53 # Make the gym environment
#      54 # 사용자 정의 환경 등록. 사용자가 정의한 환경을 Gym 환경 레지스트리에 등록
# ---> 55 register_custom_envs()
#      56 print(self.params['env_name'])
#      58 # 지정된 이름의 gym 환경 개체를 생성
#
# File ~/Library/CloudStorage/OneDrive-UOS/MAC/AI/CS182/CS182_HW/CS182/assignment4/deeprl/infrastructure/dqn_utils.py:30, in register_custom_envs()
#      29 def register_custom_envs():
# ---> 30     if 'LunarLander-v3' not in registry.env_specs:
#      31         register(
#      32             id='LunarLander-v3',
#      33             entry_point='deeprl.envs.box2d.lunar_lander:LunarLander',
#      34             max_episode_steps=1000,
#      35             reward_threshold=200,
#      36         )
#
# AttributeError: 'dict' object has no attribute 'env_specs'

# %% [markdown]
# Next, we'll consider a return estimate with lower variance by taking the discounted reward-to-go at each timestep instead of the entire discounted return. More precisely, instead of taking $\sum_{t'=0}^T \gamma^{t'} r_{t'}$ as the return estimate for all timesteps $t$, we will instead use $\sum_{t'=t}^T \gamma^{t' - t} r_{t'}$ for the return estimate at timestep $t$. Fill out the method <code>_discounted_cumsum</code> in <code>pg_agent.py</code>.   Your error should be 1e-6 or lower.

# %%
### Test reward to go computations
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_cumsum = pgagent._discounted_cumsum(rewards)
expected_cumsum = np.array([6.49674307, 4.98177971, 4.82276053, 4.04633952, 1.90046981, 0.03464402,
 1.06518095, 0.12115003, 0.28684973, 0.4105985])

return_error = rel_error(discounted_cumsum, expected_cumsum)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.0143655677664199e-08
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:440: UserWarning: WARN: The `registry.env_specs` property along with `EnvSpecTree` is deprecated. Please use `registry` directly as a dictionary instead.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %% [markdown]
# Finally, we'll use our return estimates to compute a policy gradient. Fill out the surrogate loss computation in the <code>update</code> method in MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
### Test policy gradient (check gradients match what we expect)
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs)['Training Loss']

print(loss)
expected_loss = -6142.9116
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 1.035012, 1.0455959, 0.11085394],
                            [-1.1532364, -0.5915445, 0.557522]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432253  0.30971587 -0.47518533]
#  [-0.42489457 -0.22236899  0.15482074]]
# -6142.911
# Loss Error 3.8026553900586275e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 1.0306894   1.3553118  -0.36433142]
#  [-1.5781314  -0.8139109   0.71234274]]
# Change in weights [[ 1.0350119   1.0455959   0.11085391]
#  [-1.1532369  -0.5915419   0.557522  ]]
# Weight Update Error 2.2091965382665285e-06 should be on the order of 1e-6 or lower

# %% [markdown]
# We can compare the two return estimators on a simple environment and compare how well they do.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = False
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/CartPole/full_returns/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.0000
# Eval_StdReturn : 11.006815910339355
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 26.0
# Train_AverageReturn : 24.414634704589844
# Train_StdReturn : 10.264729499816895
# Train_MaxReturn : 57.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.414634146341463
# Train_EnvstepsSoFar : 1001
# TimeSinceStart : 0.20642709732055664
# Training Loss : 10.156880378723145
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1071 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.864864349365234
# Eval_StdReturn : 11.9348726272583
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 27.864864864864863
# Train_AverageReturn : 26.774999618530273
# Train_StdReturn : 13.97048282623291
# Train_MaxReturn : 79.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 26.775
# Train_EnvstepsSoFar : 2072
# TimeSinceStart : 0.374373197555542
# Training Loss : 10.486858367919922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.2702693939209
# Eval_StdReturn : 15.403840065002441
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 27.27027027027027
# Train_AverageReturn : 27.675676345825195
# Train_StdReturn : 15.785820007324219
# Train_MaxReturn : 78.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 27.675675675675677
# Train_EnvstepsSoFar : 3096
# TimeSinceStart : 0.5395760536193848
# Training Loss : 10.612787246704102
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1003 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.400001525878906
# Eval_StdReturn : 13.62008285522461
# Eval_MaxReturn : 67.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 33.4
# Train_AverageReturn : 41.79166793823242
# Train_StdReturn : 21.523202896118164
# Train_MaxReturn : 93.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 41.791666666666664
# Train_EnvstepsSoFar : 4099
# TimeSinceStart : 0.7022171020507812
# Training Loss : 11.780434608459473
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1050 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.560001373291016
# Eval_StdReturn : 22.15956687927246
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 40.56
# Train_AverageReturn : 35.0
# Train_StdReturn : 19.790569305419922
# Train_MaxReturn : 92.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 35.0
# Train_EnvstepsSoFar : 5149
# TimeSinceStart : 0.9290440082550049
# Training Loss : 11.226252555847168
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.71428680419922
# Eval_StdReturn : 19.158842086791992
# Eval_MaxReturn : 87.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 35.714285714285715
# Train_AverageReturn : 26.921052932739258
# Train_StdReturn : 10.071799278259277
# Train_MaxReturn : 49.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 26.92105263157895
# Train_EnvstepsSoFar : 6172
# TimeSinceStart : 1.0861790180206299
# Training Loss : 10.21047592163086
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.8157901763916
# Eval_StdReturn : 15.92061710357666
# Eval_MaxReturn : 106.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 26.81578947368421
# Train_AverageReturn : 28.714284896850586
# Train_StdReturn : 13.133537292480469
# Train_MaxReturn : 66.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 28.714285714285715
# Train_EnvstepsSoFar : 7177
# TimeSinceStart : 1.237687110900879
# Training Loss : 10.44265365600586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.264705657958984
# Eval_StdReturn : 13.51319408416748
# Eval_MaxReturn : 62.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 30.264705882352942
# Train_AverageReturn : 30.47058868408203
# Train_StdReturn : 15.46007251739502
# Train_MaxReturn : 76.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 30.470588235294116
# Train_EnvstepsSoFar : 8213
# TimeSinceStart : 1.3864610195159912
# Training Loss : 10.699284553527832
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.53125
# Eval_StdReturn : 18.47800064086914
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 31.53125
# Train_AverageReturn : 26.3157901763916
# Train_StdReturn : 13.418575286865234
# Train_MaxReturn : 67.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 26.31578947368421
# Train_EnvstepsSoFar : 9213
# TimeSinceStart : 1.5352940559387207
# Training Loss : 9.89104175567627
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.02941131591797
# Eval_StdReturn : 20.21281623840332
# Eval_MaxReturn : 104.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 32.029411764705884
# Train_AverageReturn : 29.823530197143555
# Train_StdReturn : 23.052968978881836
# Train_MaxReturn : 144.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 29.823529411764707
# Train_EnvstepsSoFar : 10227
# TimeSinceStart : 1.6935529708862305
# Training Loss : 10.37423038482666
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1039 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.13333511352539
# Eval_StdReturn : 12.935051918029785
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 34.13333333333333
# Train_AverageReturn : 29.685714721679688
# Train_StdReturn : 13.538878440856934
# Train_MaxReturn : 63.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 29.685714285714287
# Train_EnvstepsSoFar : 11266
# TimeSinceStart : 1.8468999862670898
# Training Loss : 10.199644088745117
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.967742919921875
# Eval_StdReturn : 14.243241310119629
# Eval_MaxReturn : 54.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 32.96774193548387
# Train_AverageReturn : 30.939393997192383
# Train_StdReturn : 14.998867988586426
# Train_MaxReturn : 92.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 30.939393939393938
# Train_EnvstepsSoFar : 12287
# TimeSinceStart : 2.003801107406616
# Training Loss : 10.38410472869873
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.766666412353516
# Eval_StdReturn : 21.478179931640625
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 34.766666666666666
# Train_AverageReturn : 31.393939971923828
# Train_StdReturn : 20.602941513061523
# Train_MaxReturn : 107.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 31.393939393939394
# Train_EnvstepsSoFar : 13323
# TimeSinceStart : 2.1606650352478027
# Training Loss : 10.32798957824707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.703704833984375
# Eval_StdReturn : 17.71965789794922
# Eval_MaxReturn : 82.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 37.7037037037037
# Train_AverageReturn : 45.5
# Train_StdReturn : 26.86625099182129
# Train_MaxReturn : 99.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 45.5
# Train_EnvstepsSoFar : 14324
# TimeSinceStart : 2.3071439266204834
# Training Loss : 11.36578369140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.80952453613281
# Eval_StdReturn : 19.030349731445312
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 47.80952380952381
# Train_AverageReturn : 48.9523811340332
# Train_StdReturn : 35.0747184753418
# Train_MaxReturn : 156.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 48.95238095238095
# Train_EnvstepsSoFar : 15352
# TimeSinceStart : 2.455268144607544
# Training Loss : 11.3904390335083
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.5000
# Eval_StdReturn : 21.18479347229004
# Eval_MaxReturn : 105.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 46.5
# Train_AverageReturn : 50.400001525878906
# Train_StdReturn : 20.08830451965332
# Train_MaxReturn : 90.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 50.4
# Train_EnvstepsSoFar : 16360
# TimeSinceStart : 2.6034860610961914
# Training Loss : 11.362070083618164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1052 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 48.71428680419922
# Eval_StdReturn : 20.31218910217285
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 48.714285714285715
# Train_AverageReturn : 45.739131927490234
# Train_StdReturn : 19.645151138305664
# Train_MaxReturn : 99.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 45.73913043478261
# Train_EnvstepsSoFar : 17412
# TimeSinceStart : 2.758498191833496
# Training Loss : 11.185049057006836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.380950927734375
# Eval_StdReturn : 19.686777114868164
# Eval_MaxReturn : 98.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 49.38095238095238
# Train_AverageReturn : 53.73684310913086
# Train_StdReturn : 20.7867431640625
# Train_MaxReturn : 112.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 53.73684210526316
# Train_EnvstepsSoFar : 18433
# TimeSinceStart : 2.915130853652954
# Training Loss : 11.497129440307617
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.4782600402832
# Eval_StdReturn : 20.681581497192383
# Eval_MaxReturn : 110.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 43.47826086956522
# Train_AverageReturn : 53.31578826904297
# Train_StdReturn : 15.61730670928955
# Train_MaxReturn : 88.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 53.31578947368421
# Train_EnvstepsSoFar : 19446
# TimeSinceStart : 3.087959051132202
# Training Loss : 11.190743446350098
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.619049072265625
# Eval_StdReturn : 21.599109649658203
# Eval_MaxReturn : 105.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 49.61904761904762
# Train_AverageReturn : 53.0
# Train_StdReturn : 16.933305740356445
# Train_MaxReturn : 89.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 53.0
# Train_EnvstepsSoFar : 20453
# TimeSinceStart : 3.2487051486968994
# Training Loss : 11.34857177734375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1009 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.14285659790039
# Eval_StdReturn : 21.545711517333984
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 51.142857142857146
# Train_AverageReturn : 43.869564056396484
# Train_StdReturn : 14.136920928955078
# Train_MaxReturn : 79.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 43.869565217391305
# Train_EnvstepsSoFar : 21462
# TimeSinceStart : 3.4097721576690674
# Training Loss : 10.91489028930664
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1032 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.6363639831543
# Eval_StdReturn : 21.493223190307617
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 45.63636363636363
# Train_AverageReturn : 46.90909194946289
# Train_StdReturn : 18.223134994506836
# Train_MaxReturn : 89.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 46.90909090909091
# Train_EnvstepsSoFar : 22494
# TimeSinceStart : 3.591724157333374
# Training Loss : 10.8839111328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1009 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.599998474121094
# Eval_StdReturn : 19.98349380493164
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 50.6
# Train_AverageReturn : 50.45000076293945
# Train_StdReturn : 26.723539352416992
# Train_MaxReturn : 124.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 50.45
# Train_EnvstepsSoFar : 23503
# TimeSinceStart : 3.765559196472168
# Training Loss : 11.035639762878418
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.6875
# Eval_StdReturn : 33.11479949951172
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 64.6875
# Train_AverageReturn : 39.42307662963867
# Train_StdReturn : 17.696529388427734
# Train_MaxReturn : 79.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 39.42307692307692
# Train_EnvstepsSoFar : 24528
# TimeSinceStart : 3.95409893989563
# Training Loss : 10.679463386535645
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.959999084472656
# Eval_StdReturn : 19.296588897705078
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 40.96
# Train_AverageReturn : 53.421051025390625
# Train_StdReturn : 22.39434814453125
# Train_MaxReturn : 104.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 53.421052631578945
# Train_EnvstepsSoFar : 25543
# TimeSinceStart : 4.108197212219238
# Training Loss : 11.236908912658691
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.20000076293945
# Eval_StdReturn : 17.244129180908203
# Eval_MaxReturn : 82.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 40.2
# Train_AverageReturn : 47.8636360168457
# Train_StdReturn : 34.59545135498047
# Train_MaxReturn : 142.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 47.86363636363637
# Train_EnvstepsSoFar : 26596
# TimeSinceStart : 4.261449098587036
# Training Loss : 10.908994674682617
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1048 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.08000183105469
# Eval_StdReturn : 19.32236099243164
# Eval_MaxReturn : 109.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 40.08
# Train_AverageReturn : 47.6363639831543
# Train_StdReturn : 19.712812423706055
# Train_MaxReturn : 103.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 47.63636363636363
# Train_EnvstepsSoFar : 27644
# TimeSinceStart : 4.415210962295532
# Training Loss : 11.328255653381348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.272727966308594
# Eval_StdReturn : 20.961395263671875
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 46.27272727272727
# Train_AverageReturn : 43.625
# Train_StdReturn : 17.836788177490234
# Train_MaxReturn : 92.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 43.625
# Train_EnvstepsSoFar : 28691
# TimeSinceStart : 4.570291996002197
# Training Loss : 10.975765228271484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.230770111083984
# Eval_StdReturn : 21.110164642333984
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 40.23076923076923
# Train_AverageReturn : 50.79999923706055
# Train_StdReturn : 34.12858200073242
# Train_MaxReturn : 181.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 50.8
# Train_EnvstepsSoFar : 29707
# TimeSinceStart : 4.7226691246032715
# Training Loss : 11.307150840759277
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1062 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.79166793823242
# Eval_StdReturn : 21.256330490112305
# Eval_MaxReturn : 107.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 42.791666666666664
# Train_AverageReturn : 40.846153259277344
# Train_StdReturn : 17.971542358398438
# Train_MaxReturn : 90.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 40.84615384615385
# Train_EnvstepsSoFar : 30769
# TimeSinceStart : 4.876858949661255
# Training Loss : 10.769144058227539
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.814815521240234
# Eval_StdReturn : 19.12151527404785
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 37.81481481481482
# Train_AverageReturn : 42.08333206176758
# Train_StdReturn : 23.730987548828125
# Train_MaxReturn : 110.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 42.083333333333336
# Train_EnvstepsSoFar : 31779
# TimeSinceStart : 5.024945020675659
# Training Loss : 10.876139640808105
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1019 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.727272033691406
# Eval_StdReturn : 24.164554595947266
# Eval_MaxReturn : 112.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 45.72727272727273
# Train_AverageReturn : 37.74074172973633
# Train_StdReturn : 15.12317943572998
# Train_MaxReturn : 74.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 37.74074074074074
# Train_EnvstepsSoFar : 32798
# TimeSinceStart : 5.175973892211914
# Training Loss : 10.84489917755127
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.400001525878906
# Eval_StdReturn : 36.84074020385742
# Eval_MaxReturn : 177.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 51.4
# Train_AverageReturn : 35.85714340209961
# Train_StdReturn : 15.592384338378906
# Train_MaxReturn : 72.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 35.857142857142854
# Train_EnvstepsSoFar : 33802
# TimeSinceStart : 5.325904846191406
# Training Loss : 10.617934226989746
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1031 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.439998626708984
# Eval_StdReturn : 22.30888557434082
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 40.44
# Train_AverageReturn : 36.82143020629883
# Train_StdReturn : 13.182926177978516
# Train_MaxReturn : 61.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 36.82142857142857
# Train_EnvstepsSoFar : 34833
# TimeSinceStart : 5.47334098815918
# Training Loss : 10.69960880279541
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.20000076293945
# Eval_StdReturn : 19.093454360961914
# Eval_MaxReturn : 96.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 50.2
# Train_AverageReturn : 48.42856979370117
# Train_StdReturn : 21.875343322753906
# Train_MaxReturn : 94.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 48.42857142857143
# Train_EnvstepsSoFar : 35850
# TimeSinceStart : 5.61890721321106
# Training Loss : 11.328971862792969
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.59090805053711
# Eval_StdReturn : 16.472177505493164
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 46.59090909090909
# Train_AverageReturn : 47.71428680419922
# Train_StdReturn : 26.72459602355957
# Train_MaxReturn : 121.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 47.714285714285715
# Train_EnvstepsSoFar : 36852
# TimeSinceStart : 5.7657060623168945
# Training Loss : 11.364911079406738
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1065 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.318180084228516
# Eval_StdReturn : 15.955580711364746
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 46.31818181818182
# Train_AverageReturn : 44.375
# Train_StdReturn : 16.577627182006836
# Train_MaxReturn : 89.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 44.375
# Train_EnvstepsSoFar : 37917
# TimeSinceStart : 5.92366099357605
# Training Loss : 11.095847129821777
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.40909194946289
# Eval_StdReturn : 18.317054748535156
# Eval_MaxReturn : 93.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 47.40909090909091
# Train_AverageReturn : 61.0
# Train_StdReturn : 23.26825523376465
# Train_MaxReturn : 125.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 61.0
# Train_EnvstepsSoFar : 38954
# TimeSinceStart : 6.084740161895752
# Training Loss : 11.950285911560059
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.66666793823242
# Eval_StdReturn : 14.670454025268555
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 41.666666666666664
# Train_AverageReturn : 43.69565200805664
# Train_StdReturn : 15.363521575927734
# Train_MaxReturn : 79.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 43.69565217391305
# Train_EnvstepsSoFar : 39959
# TimeSinceStart : 6.242013931274414
# Training Loss : 11.06292724609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.095237731933594
# Eval_StdReturn : 29.336965560913086
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 49.095238095238095
# Train_AverageReturn : 50.79999923706055
# Train_StdReturn : 23.176713943481445
# Train_MaxReturn : 106.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 50.8
# Train_EnvstepsSoFar : 40975
# TimeSinceStart : 6.393777847290039
# Training Loss : 11.618191719055176
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1039 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.105262756347656
# Eval_StdReturn : 34.51757049560547
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 55.10526315789474
# Train_AverageReturn : 45.173912048339844
# Train_StdReturn : 14.559183120727539
# Train_MaxReturn : 72.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 45.17391304347826
# Train_EnvstepsSoFar : 42014
# TimeSinceStart : 6.552577972412109
# Training Loss : 11.087138175964355
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.650001525878906
# Eval_StdReturn : 13.18815803527832
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 50.65
# Train_AverageReturn : 47.80952453613281
# Train_StdReturn : 17.60578727722168
# Train_MaxReturn : 85.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 47.80952380952381
# Train_EnvstepsSoFar : 43018
# TimeSinceStart : 6.696624994277954
# Training Loss : 11.11673641204834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.772727966308594
# Eval_StdReturn : 20.06338119506836
# Eval_MaxReturn : 97.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 45.77272727272727
# Train_AverageReturn : 47.272727966308594
# Train_StdReturn : 15.565643310546875
# Train_MaxReturn : 82.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 47.27272727272727
# Train_EnvstepsSoFar : 44058
# TimeSinceStart : 6.849108934402466
# Training Loss : 11.251968383789062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.8125
# Eval_StdReturn : 29.673681259155273
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 62.8125
# Train_AverageReturn : 56.5
# Train_StdReturn : 28.402366638183594
# Train_MaxReturn : 140.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 56.5
# Train_EnvstepsSoFar : 45075
# TimeSinceStart : 7.000149965286255
# Training Loss : 11.301424980163574
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1048 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.588233947753906
# Eval_StdReturn : 22.457958221435547
# Eval_MaxReturn : 118.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 59.588235294117645
# Train_AverageReturn : 55.157894134521484
# Train_StdReturn : 16.0041561126709
# Train_MaxReturn : 96.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 55.1578947368421
# Train_EnvstepsSoFar : 46123
# TimeSinceStart : 7.148373126983643
# Training Loss : 11.314953804016113
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.0000
# Eval_StdReturn : 19.17719268798828
# Eval_MaxReturn : 97.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 62.0
# Train_AverageReturn : 61.588233947753906
# Train_StdReturn : 22.744253158569336
# Train_MaxReturn : 130.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 61.588235294117645
# Train_EnvstepsSoFar : 47170
# TimeSinceStart : 7.313153982162476
# Training Loss : 11.611361503601074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.7500
# Eval_StdReturn : 19.42388916015625
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 50.75
# Train_AverageReturn : 67.13333129882812
# Train_StdReturn : 25.658958435058594
# Train_MaxReturn : 105.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 67.13333333333334
# Train_EnvstepsSoFar : 48177
# TimeSinceStart : 7.461932182312012
# Training Loss : 11.61232852935791
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1018 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 57.55555725097656
# Eval_StdReturn : 22.7918643951416
# Eval_MaxReturn : 103.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 57.55555555555556
# Train_AverageReturn : 50.900001525878906
# Train_StdReturn : 17.33753204345703
# Train_MaxReturn : 79.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 50.9
# Train_EnvstepsSoFar : 49195
# TimeSinceStart : 7.616440057754517
# Training Loss : 11.04604721069336
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.599998474121094
# Eval_StdReturn : 16.51181411743164
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 51.6
# Train_AverageReturn : 49.0
# Train_StdReturn : 15.146900177001953
# Train_MaxReturn : 72.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 49.0
# Train_EnvstepsSoFar : 50224
# TimeSinceStart : 7.766310930252075
# Training Loss : 10.922186851501465
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1039 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.55555725097656
# Eval_StdReturn : 18.977245330810547
# Eval_MaxReturn : 97.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 59.55555555555556
# Train_AverageReturn : 57.72222137451172
# Train_StdReturn : 18.84381866455078
# Train_MaxReturn : 89.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 57.72222222222222
# Train_EnvstepsSoFar : 51263
# TimeSinceStart : 7.917942047119141
# Training Loss : 11.124370574951172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1074 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.95000076293945
# Eval_StdReturn : 17.106943130493164
# Eval_MaxReturn : 105.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 51.95
# Train_AverageReturn : 67.125
# Train_StdReturn : 30.399168014526367
# Train_MaxReturn : 137.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 67.125
# Train_EnvstepsSoFar : 52337
# TimeSinceStart : 8.070827960968018
# Training Loss : 11.454516410827637
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.80000305175781
# Eval_StdReturn : 25.659826278686523
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 44.0
# Eval_AverageEpLen : 70.8
# Train_AverageReturn : 57.05555725097656
# Train_StdReturn : 24.87853240966797
# Train_MaxReturn : 120.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 57.05555555555556
# Train_EnvstepsSoFar : 53364
# TimeSinceStart : 8.222609996795654
# Training Loss : 11.19270133972168
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1102 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.66666793823242
# Eval_StdReturn : 12.991450309753418
# Eval_MaxReturn : 85.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 55.666666666666664
# Train_AverageReturn : 58.0
# Train_StdReturn : 29.460052490234375
# Train_MaxReturn : 141.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 58.0
# Train_EnvstepsSoFar : 54466
# TimeSinceStart : 8.372963190078735
# Training Loss : 11.244555473327637
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.5000
# Eval_StdReturn : 27.062427520751953
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 67.5
# Train_AverageReturn : 73.5
# Train_StdReturn : 23.267850875854492
# Train_MaxReturn : 107.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 73.5
# Train_EnvstepsSoFar : 55495
# TimeSinceStart : 8.525889158248901
# Training Loss : 11.56985855102539
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1079 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.3750
# Eval_StdReturn : 24.66240882873535
# Eval_MaxReturn : 105.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 63.375
# Train_AverageReturn : 83.0
# Train_StdReturn : 39.3328971862793
# Train_MaxReturn : 162.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 83.0
# Train_EnvstepsSoFar : 56574
# TimeSinceStart : 8.690223217010498
# Training Loss : 11.217706680297852
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1054 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.70588302612305
# Eval_StdReturn : 23.01090431213379
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 59.705882352941174
# Train_AverageReturn : 58.55555725097656
# Train_StdReturn : 17.295543670654297
# Train_MaxReturn : 90.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 58.55555555555556
# Train_EnvstepsSoFar : 57628
# TimeSinceStart : 8.84566617012024
# Training Loss : 11.312285423278809
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.66666412353516
# Eval_StdReturn : 28.144075393676758
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 69.66666666666667
# Train_AverageReturn : 68.53333282470703
# Train_StdReturn : 45.71632385253906
# Train_MaxReturn : 200.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 68.53333333333333
# Train_EnvstepsSoFar : 58656
# TimeSinceStart : 8.993442058563232
# Training Loss : 11.13000774383545
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.69230651855469
# Eval_StdReturn : 27.322532653808594
# Eval_MaxReturn : 146.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 80.6923076923077
# Train_AverageReturn : 66.80000305175781
# Train_StdReturn : 24.33981704711914
# Train_MaxReturn : 104.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 66.8
# Train_EnvstepsSoFar : 59658
# TimeSinceStart : 9.147611856460571
# Training Loss : 10.991409301757812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.07691955566406
# Eval_StdReturn : 31.46784019470215
# Eval_MaxReturn : 145.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 82.07692307692308
# Train_AverageReturn : 60.411766052246094
# Train_StdReturn : 25.695178985595703
# Train_MaxReturn : 137.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 60.411764705882355
# Train_EnvstepsSoFar : 60685
# TimeSinceStart : 9.305008888244629
# Training Loss : 10.8633394241333
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 72.85713958740234
# Eval_StdReturn : 16.097280502319336
# Eval_MaxReturn : 107.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 72.85714285714286
# Train_AverageReturn : 74.07142639160156
# Train_StdReturn : 22.776756286621094
# Train_MaxReturn : 115.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 74.07142857142857
# Train_EnvstepsSoFar : 61722
# TimeSinceStart : 9.454012870788574
# Training Loss : 11.23065185546875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.4375
# Eval_StdReturn : 28.15796661376953
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 65.4375
# Train_AverageReturn : 66.66666412353516
# Train_StdReturn : 26.423892974853516
# Train_MaxReturn : 151.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 66.66666666666667
# Train_EnvstepsSoFar : 62722
# TimeSinceStart : 9.600039958953857
# Training Loss : 10.818763732910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1011 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 60.411766052246094
# Eval_StdReturn : 28.344640731811523
# Eval_MaxReturn : 155.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 60.411764705882355
# Train_AverageReturn : 67.4000015258789
# Train_StdReturn : 28.196453094482422
# Train_MaxReturn : 122.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 67.4
# Train_EnvstepsSoFar : 63733
# TimeSinceStart : 9.7521390914917
# Training Loss : 10.83725643157959
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.95000076293945
# Eval_StdReturn : 22.48883056640625
# Eval_MaxReturn : 115.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 51.95
# Train_AverageReturn : 50.650001525878906
# Train_StdReturn : 16.77878189086914
# Train_MaxReturn : 93.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 50.65
# Train_EnvstepsSoFar : 64746
# TimeSinceStart : 9.907360076904297
# Training Loss : 10.347549438476562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1035 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 57.578948974609375
# Eval_StdReturn : 29.562273025512695
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 57.578947368421055
# Train_AverageReturn : 57.5
# Train_StdReturn : 30.247589111328125
# Train_MaxReturn : 151.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 57.5
# Train_EnvstepsSoFar : 65781
# TimeSinceStart : 10.063365936279297
# Training Loss : 10.41482925415039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1009 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.71428680419922
# Eval_StdReturn : 18.53219223022461
# Eval_MaxReturn : 114.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 47.714285714285715
# Train_AverageReturn : 45.8636360168457
# Train_StdReturn : 14.394744873046875
# Train_MaxReturn : 86.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 45.86363636363637
# Train_EnvstepsSoFar : 66790
# TimeSinceStart : 10.211618185043335
# Training Loss : 9.790399551391602
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1003 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.33333206176758
# Eval_StdReturn : 12.883021354675293
# Eval_MaxReturn : 66.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 43.333333333333336
# Train_AverageReturn : 45.59090805053711
# Train_StdReturn : 15.233511924743652
# Train_MaxReturn : 79.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 45.59090909090909
# Train_EnvstepsSoFar : 67793
# TimeSinceStart : 10.359515190124512
# Training Loss : 9.615021705627441
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1018 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.85714340209961
# Eval_StdReturn : 8.626016616821289
# Eval_MaxReturn : 54.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 35.857142857142854
# Train_AverageReturn : 40.720001220703125
# Train_StdReturn : 13.501171112060547
# Train_MaxReturn : 88.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 40.72
# Train_EnvstepsSoFar : 68811
# TimeSinceStart : 10.516517162322998
# Training Loss : 9.304509162902832
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.28571319580078
# Eval_StdReturn : 12.035237312316895
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 36.285714285714285
# Train_AverageReturn : 39.14814758300781
# Train_StdReturn : 10.8958158493042
# Train_MaxReturn : 65.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 39.148148148148145
# Train_EnvstepsSoFar : 69868
# TimeSinceStart : 10.67038106918335
# Training Loss : 9.268108367919922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.6875
# Eval_StdReturn : 7.67478609085083
# Eval_MaxReturn : 54.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 31.6875
# Train_AverageReturn : 34.900001525878906
# Train_StdReturn : 10.044401168823242
# Train_MaxReturn : 71.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 34.9
# Train_EnvstepsSoFar : 70915
# TimeSinceStart : 10.821332931518555
# Training Loss : 8.885618209838867
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# ...
# Train_EnvstepsSoFar : 80658
# TimeSinceStart : 13.658375978469849
# Training Loss : 6.355707168579102
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.132076263427734
# Eval_StdReturn : 3.5022244453430176
# Eval_MaxReturn : 33.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 19.132075471698112
# Train_AverageReturn : 20.139999389648438
# Train_StdReturn : 4.034897804260254
# Train_MaxReturn : 28.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 20.14
# Train_EnvstepsSoFar : 81665
# TimeSinceStart : 13.810416221618652
# Training Loss : 5.923388481140137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.519229888916016
# Eval_StdReturn : 2.8181443214416504
# Eval_MaxReturn : 26.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 19.51923076923077
# Train_AverageReturn : 19.5
# Train_StdReturn : 3.505490303039551
# Train_MaxReturn : 28.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 19.5
# Train_EnvstepsSoFar : 82679
# TimeSinceStart : 13.981259107589722
# Training Loss : 5.759715557098389
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 18.703702926635742
# Eval_StdReturn : 2.7864065170288086
# Eval_MaxReturn : 25.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 18.703703703703702
# Train_AverageReturn : 18.943395614624023
# Train_StdReturn : 3.158785820007324
# Train_MaxReturn : 26.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 18.943396226415093
# Train_EnvstepsSoFar : 83683
# TimeSinceStart : 14.152392148971558
# Training Loss : 5.502122402191162
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 19.09433937072754
# Eval_StdReturn : 3.4217071533203125
# Eval_MaxReturn : 29.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 19.09433962264151
# Train_AverageReturn : 19.188678741455078
# Train_StdReturn : 2.7817234992980957
# Train_MaxReturn : 26.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 19.18867924528302
# Train_EnvstepsSoFar : 84700
# TimeSinceStart : 14.31016206741333
# Training Loss : 5.589503288269043
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1018 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.83333396911621
# Eval_StdReturn : 2.838231086730957
# Eval_MaxReturn : 28.0
# Eval_MinReturn : 13.0
# Eval_AverageEpLen : 20.833333333333332
# Train_AverageReturn : 19.20754623413086
# Train_StdReturn : 2.8639495372772217
# Train_MaxReturn : 26.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 19.20754716981132
# Train_EnvstepsSoFar : 85718
# TimeSinceStart : 14.469595193862915
# Training Loss : 5.788458824157715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.510204315185547
# Eval_StdReturn : 3.3571274280548096
# Eval_MaxReturn : 28.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 20.510204081632654
# Train_AverageReturn : 20.280000686645508
# Train_StdReturn : 3.731165885925293
# Train_MaxReturn : 34.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 20.28
# Train_EnvstepsSoFar : 86732
# TimeSinceStart : 14.622945070266724
# Training Loss : 5.990711688995361
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 22.795454025268555
# Eval_StdReturn : 4.245744228363037
# Eval_MaxReturn : 32.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 22.795454545454547
# Train_AverageReturn : 21.10416603088379
# Train_StdReturn : 3.5014257431030273
# Train_MaxReturn : 31.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 21.104166666666668
# Train_EnvstepsSoFar : 87745
# TimeSinceStart : 14.817846059799194
# Training Loss : 5.614813804626465
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.424999237060547
# Eval_StdReturn : 4.934001922607422
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 25.425
# Train_AverageReturn : 23.534883499145508
# Train_StdReturn : 4.211550235748291
# Train_MaxReturn : 33.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 23.53488372093023
# Train_EnvstepsSoFar : 88757
# TimeSinceStart : 15.002902030944824
# Training Loss : 6.046781539916992
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.846153259277344
# Eval_StdReturn : 23.91120147705078
# Eval_MaxReturn : 89.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 38.84615384615385
# Train_AverageReturn : 27.91666603088379
# Train_StdReturn : 6.286559104919434
# Train_MaxReturn : 49.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 27.916666666666668
# Train_EnvstepsSoFar : 89762
# TimeSinceStart : 15.168512105941772
# Training Loss : 6.760247707366943
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.0000
# Eval_StdReturn : 23.010395050048828
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 45.0
# Train_AverageReturn : 37.22222137451172
# Train_StdReturn : 17.248367309570312
# Train_MaxReturn : 88.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 37.22222222222222
# Train_EnvstepsSoFar : 90767
# TimeSinceStart : 15.339621305465698
# Training Loss : 6.891447067260742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 76.71428680419922
# Eval_StdReturn : 25.41492462158203
# Eval_MaxReturn : 108.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 76.71428571428571
# Train_AverageReturn : 58.94444274902344
# Train_StdReturn : 24.42101287841797
# Train_MaxReturn : 98.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 58.94444444444444
# Train_EnvstepsSoFar : 91828
# TimeSinceStart : 15.497204065322876
# Training Loss : 8.068764686584473
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1080 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 91.0000
# Eval_StdReturn : 15.29111385345459
# Eval_MaxReturn : 104.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 91.0
# Train_AverageReturn : 77.14286041259766
# Train_StdReturn : 19.949424743652344
# Train_MaxReturn : 98.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 77.14285714285714
# Train_EnvstepsSoFar : 92908
# TimeSinceStart : 15.657808303833008
# Training Loss : 8.052308082580566
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1086 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.69999694824219
# Eval_StdReturn : 7.642643451690674
# Eval_MaxReturn : 115.0
# Eval_MinReturn : 92.0
# Eval_AverageEpLen : 103.7
# Train_AverageReturn : 90.5
# Train_StdReturn : 10.912530899047852
# Train_MaxReturn : 104.0
# Train_MinReturn : 60.0
# Train_AverageEpLen : 90.5
# Train_EnvstepsSoFar : 93994
# TimeSinceStart : 15.820728063583374
# Training Loss : 8.408085823059082
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.69999694824219
# Eval_StdReturn : 8.062877655029297
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 88.0
# Eval_AverageEpLen : 102.7
# Train_AverageReturn : 104.0
# Train_StdReturn : 8.049844741821289
# Train_MaxReturn : 116.0
# Train_MinReturn : 91.0
# Train_AverageEpLen : 104.0
# Train_EnvstepsSoFar : 95034
# TimeSinceStart : 15.974277257919312
# Training Loss : 8.263856887817383
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1103 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.000
# Eval_StdReturn : 12.049896240234375
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 91.0
# Eval_AverageEpLen : 105.0
# Train_AverageReturn : 110.30000305175781
# Train_StdReturn : 9.198369026184082
# Train_MaxReturn : 124.0
# Train_MinReturn : 93.0
# Train_AverageEpLen : 110.3
# Train_EnvstepsSoFar : 96137
# TimeSinceStart : 16.14211106300354
# Training Loss : 7.951305389404297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1054 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.88888549804688
# Eval_StdReturn : 32.8513298034668
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 83.0
# Eval_AverageEpLen : 115.88888888888889
# Train_AverageReturn : 105.4000015258789
# Train_StdReturn : 14.164745330810547
# Train_MaxReturn : 135.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 105.4
# Train_EnvstepsSoFar : 97191
# TimeSinceStart : 16.30849814414978
# Training Loss : 7.984078407287598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.000
# Eval_StdReturn : 32.07802963256836
# Eval_MaxReturn : 191.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 138.0
# Train_AverageReturn : 125.125
# Train_StdReturn : 28.87229347229004
# Train_MaxReturn : 200.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 125.125
# Train_EnvstepsSoFar : 98192
# TimeSinceStart : 16.46805214881897
# Training Loss : 8.086211204528809
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 143.7142791748047
# Eval_StdReturn : 29.927122116088867
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 143.71428571428572
# Train_AverageReturn : 134.0
# Train_StdReturn : 29.74054527282715
# Train_MaxReturn : 200.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 134.0
# Train_EnvstepsSoFar : 99264
# TimeSinceStart : 16.62053418159485
# Training Loss : 7.542171478271484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1107 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.375
# Eval_StdReturn : 25.20881462097168
# Eval_MaxReturn : 170.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 133.375
# Train_AverageReturn : 158.14285278320312
# Train_StdReturn : 43.1324462890625
# Train_MaxReturn : 200.0
# Train_MinReturn : 99.0
# Train_AverageEpLen : 158.14285714285714
# Train_EnvstepsSoFar : 100371
# TimeSinceStart : 16.781200170516968
# Training Loss : 7.908629894256592
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1092 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.6666717529297
# Eval_StdReturn : 17.451519012451172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 141.0
# Eval_AverageEpLen : 167.66666666666666
# Train_AverageReturn : 156.0
# Train_StdReturn : 34.694583892822266
# Train_MaxReturn : 195.0
# Train_MinReturn : 88.0
# Train_AverageEpLen : 156.0
# Train_EnvstepsSoFar : 101463
# TimeSinceStart : 16.93482804298401
# Training Loss : 7.424808502197266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1084 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.000
# Eval_StdReturn : 23.46628761291504
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 142.0
# Eval_AverageEpLen : 169.0
# Train_AverageReturn : 154.85714721679688
# Train_StdReturn : 30.907367706298828
# Train_MaxReturn : 200.0
# Train_MinReturn : 100.0
# Train_AverageEpLen : 154.85714285714286
# Train_EnvstepsSoFar : 102547
# TimeSinceStart : 17.09021806716919
# Training Loss : 7.830053806304932
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1067 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.2857208251953
# Eval_StdReturn : 36.13353729248047
# Eval_MaxReturn : 196.0
# Eval_MinReturn : 107.0
# Eval_AverageEpLen : 162.28571428571428
# Train_AverageReturn : 177.8333282470703
# Train_StdReturn : 25.556581497192383
# Train_MaxReturn : 200.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 177.83333333333334
# Train_EnvstepsSoFar : 103614
# TimeSinceStart : 17.25015115737915
# Training Loss : 7.844292640686035
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1135 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.875
# Eval_StdReturn : 29.472179412841797
# Eval_MaxReturn : 174.0
# Eval_MinReturn : 99.0
# Eval_AverageEpLen : 138.875
# Train_AverageReturn : 141.875
# Train_StdReturn : 30.275556564331055
# Train_MaxReturn : 200.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 141.875
# Train_EnvstepsSoFar : 104749
# TimeSinceStart : 17.407288074493408
# Training Loss : 8.227328300476074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = True
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/CartPole/return_to_go/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.33333396911621
# Eval_StdReturn : 13.417044639587402
# Eval_MaxReturn : 75.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 26.333333333333332
# Train_AverageReturn : 24.414634704589844
# Train_StdReturn : 10.264729499816895
# Train_MaxReturn : 57.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.414634146341463
# Train_EnvstepsSoFar : 1001
# TimeSinceStart : 0.1416480541229248
# Training Loss : 6.549466609954834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1022 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.16666793823242
# Eval_StdReturn : 16.323976516723633
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 34.166666666666664
# Train_AverageReturn : 26.205127716064453
# Train_StdReturn : 19.547677993774414
# Train_MaxReturn : 133.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 26.205128205128204
# Train_EnvstepsSoFar : 2023
# TimeSinceStart : 0.2849750518798828
# Training Loss : 6.960094928741455
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1022 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.91666793823242
# Eval_StdReturn : 25.793922424316406
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 41.916666666666664
# Train_AverageReturn : 30.058822631835938
# Train_StdReturn : 15.350687026977539
# Train_MaxReturn : 73.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 30.058823529411764
# Train_EnvstepsSoFar : 3045
# TimeSinceStart : 0.4299149513244629
# Training Loss : 7.229406356811523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.70000076293945
# Eval_StdReturn : 35.014427185058594
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 52.7
# Train_AverageReturn : 33.36666488647461
# Train_StdReturn : 18.311168670654297
# Train_MaxReturn : 88.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 33.36666666666667
# Train_EnvstepsSoFar : 4046
# TimeSinceStart : 0.5727779865264893
# Training Loss : 7.457221984863281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1082 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.8125
# Eval_StdReturn : 41.254119873046875
# Eval_MaxReturn : 159.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 64.8125
# Train_AverageReturn : 45.08333206176758
# Train_StdReturn : 27.06307029724121
# Train_MaxReturn : 114.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 45.083333333333336
# Train_EnvstepsSoFar : 5128
# TimeSinceStart : 0.7211349010467529
# Training Loss : 8.3656005859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.47999954223633
# Eval_StdReturn : 17.23744773864746
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 40.48
# Train_AverageReturn : 47.40909194946289
# Train_StdReturn : 24.005035400390625
# Train_MaxReturn : 88.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 47.40909090909091
# Train_EnvstepsSoFar : 6171
# TimeSinceStart : 0.86952805519104
# Training Loss : 8.306663513183594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1056 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.0000
# Eval_StdReturn : 33.304988861083984
# Eval_MaxReturn : 146.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 59.0
# Train_AverageReturn : 52.79999923706055
# Train_StdReturn : 25.4825439453125
# Train_MaxReturn : 107.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 52.8
# Train_EnvstepsSoFar : 7227
# TimeSinceStart : 1.0250530242919922
# Training Loss : 8.579404830932617
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.57142639160156
# Eval_StdReturn : 54.70533752441406
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 84.57142857142857
# Train_AverageReturn : 56.44444274902344
# Train_StdReturn : 39.99336242675781
# Train_MaxReturn : 200.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 56.44444444444444
# Train_EnvstepsSoFar : 8243
# TimeSinceStart : 1.18367600440979
# Training Loss : 8.590761184692383
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.90908813476562
# Eval_StdReturn : 61.22901153564453
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 106.9090909090909
# Train_AverageReturn : 61.47058868408203
# Train_StdReturn : 27.628028869628906
# Train_MaxReturn : 131.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 61.470588235294116
# Train_EnvstepsSoFar : 9288
# TimeSinceStart : 1.3422508239746094
# Training Loss : 8.542736053466797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1052 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 118.66666412353516
# Eval_StdReturn : 61.97490692138672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 118.66666666666667
# Train_AverageReturn : 80.92308044433594
# Train_StdReturn : 45.09385299682617
# Train_MaxReturn : 200.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 80.92307692307692
# Train_EnvstepsSoFar : 10340
# TimeSinceStart : 1.4994001388549805
# Training Loss : 9.391489028930664
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.57142639160156
# Eval_StdReturn : 51.43610763549805
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 63.0
# Eval_AverageEpLen : 158.57142857142858
# Train_AverageReturn : 130.625
# Train_StdReturn : 59.54816818237305
# Train_MaxReturn : 200.0
# Train_MinReturn : 35.0
# Train_AverageEpLen : 130.625
# Train_EnvstepsSoFar : 11385
# TimeSinceStart : 1.6517670154571533
# Training Loss : 10.214722633361816
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1138 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 152.2857208251953
# Eval_StdReturn : 48.251468658447266
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 75.0
# Eval_AverageEpLen : 152.28571428571428
# Train_AverageReturn : 126.44444274902344
# Train_StdReturn : 53.31481170654297
# Train_MaxReturn : 200.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 126.44444444444444
# Train_EnvstepsSoFar : 12523
# TimeSinceStart : 1.8087918758392334
# Training Loss : 10.041926383972168
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1168 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.66666412353516
# Eval_StdReturn : 48.730552673339844
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 116.66666666666667
# Train_AverageReturn : 146.0
# Train_StdReturn : 45.69737243652344
# Train_MaxReturn : 200.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 146.0
# Train_EnvstepsSoFar : 13691
# TimeSinceStart : 1.9695310592651367
# Training Loss : 10.2409086227417
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1102 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.000
# Eval_StdReturn : 38.3057861328125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 57.0
# Eval_AverageEpLen : 116.0
# Train_AverageReturn : 110.19999694824219
# Train_StdReturn : 51.943817138671875
# Train_MaxReturn : 200.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 110.2
# Train_EnvstepsSoFar : 14793
# TimeSinceStart : 2.1241719722747803
# Training Loss : 9.837316513061523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1164 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 107.4000015258789
# Eval_StdReturn : 34.70504379272461
# Eval_MaxReturn : 152.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 107.4
# Train_AverageReturn : 116.4000015258789
# Train_StdReturn : 47.66801834106445
# Train_MaxReturn : 196.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 116.4
# Train_EnvstepsSoFar : 15957
# TimeSinceStart : 2.2920138835906982
# Training Loss : 9.791284561157227
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1083 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.81818389892578
# Eval_StdReturn : 47.097225189208984
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 92.81818181818181
# Train_AverageReturn : 98.45454406738281
# Train_StdReturn : 58.26953887939453
# Train_MaxReturn : 200.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 98.45454545454545
# Train_EnvstepsSoFar : 17040
# TimeSinceStart : 2.438281774520874
# Training Loss : 9.47828197479248
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.2727279663086
# Eval_StdReturn : 51.525970458984375
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 93.27272727272727
# Train_AverageReturn : 128.5
# Train_StdReturn : 45.910240173339844
# Train_MaxReturn : 200.0
# Train_MinReturn : 79.0
# Train_AverageEpLen : 128.5
# Train_EnvstepsSoFar : 18068
# TimeSinceStart : 2.5878031253814697
# Training Loss : 9.976299285888672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.33333587646484
# Eval_StdReturn : 76.35734558105469
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 120.33333333333333
# Train_AverageReturn : 128.625
# Train_StdReturn : 47.38126754760742
# Train_MaxReturn : 200.0
# Train_MinReturn : 79.0
# Train_AverageEpLen : 128.625
# Train_EnvstepsSoFar : 19097
# TimeSinceStart : 2.7566909790039062
# Training Loss : 9.787140846252441
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1084 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.000
# Eval_StdReturn : 47.59952163696289
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 79.0
# Eval_AverageEpLen : 148.0
# Train_AverageReturn : 120.44444274902344
# Train_StdReturn : 37.64486312866211
# Train_MaxReturn : 200.0
# Train_MinReturn : 73.0
# Train_AverageEpLen : 120.44444444444444
# Train_EnvstepsSoFar : 20181
# TimeSinceStart : 2.907529830932617
# Training Loss : 9.527170181274414
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1063 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.875
# Eval_StdReturn : 54.15357208251953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 126.875
# Train_AverageReturn : 132.875
# Train_StdReturn : 56.40797424316406
# Train_MaxReturn : 200.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 132.875
# Train_EnvstepsSoFar : 21244
# TimeSinceStart : 3.053924083709717
# Training Loss : 9.659847259521484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1121 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.1666717529297
# Eval_StdReturn : 23.73756980895996
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 135.0
# Eval_AverageEpLen : 187.16666666666666
# Train_AverageReturn : 186.8333282470703
# Train_StdReturn : 28.556474685668945
# Train_MaxReturn : 200.0
# Train_MinReturn : 123.0
# Train_AverageEpLen : 186.83333333333334
# Train_EnvstepsSoFar : 22365
# TimeSinceStart : 3.225235939025879
# Training Loss : 9.95986557006836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.2857208251953
# Eval_StdReturn : 61.69675827026367
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 160.28571428571428
# Train_AverageReturn : 153.14285278320312
# Train_StdReturn : 29.60419273376465
# Train_MaxReturn : 200.0
# Train_MinReturn : 113.0
# Train_AverageEpLen : 153.14285714285714
# Train_EnvstepsSoFar : 23437
# TimeSinceStart : 3.3825550079345703
# Training Loss : 9.67226791381836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 147.000
# Eval_StdReturn : 34.99795913696289
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 108.0
# Eval_AverageEpLen : 147.0
# Train_AverageReturn : 145.85714721679688
# Train_StdReturn : 32.21104049682617
# Train_MaxReturn : 200.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 145.85714285714286
# Train_EnvstepsSoFar : 24458
# TimeSinceStart : 3.5321388244628906
# Training Loss : 9.374802589416504
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1088 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.77777862548828
# Eval_StdReturn : 46.689937591552734
# Eval_MaxReturn : 179.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 112.77777777777777
# Train_AverageReturn : 120.88888549804688
# Train_StdReturn : 18.266206741333008
# Train_MaxReturn : 143.0
# Train_MinReturn : 81.0
# Train_AverageEpLen : 120.88888888888889
# Train_EnvstepsSoFar : 25546
# TimeSinceStart : 3.7031679153442383
# Training Loss : 9.128135681152344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1038 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.07691955566406
# Eval_StdReturn : 30.106122970581055
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 77.07692307692308
# Train_AverageReturn : 103.80000305175781
# Train_StdReturn : 29.942609786987305
# Train_MaxReturn : 140.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 103.8
# Train_EnvstepsSoFar : 26584
# TimeSinceStart : 3.8973710536956787
# Training Loss : 8.539077758789062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1105 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.71428680419922
# Eval_StdReturn : 26.5502986907959
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 74.71428571428571
# Train_AverageReturn : 85.0
# Train_StdReturn : 34.28612518310547
# Train_MaxReturn : 142.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 85.0
# Train_EnvstepsSoFar : 27689
# TimeSinceStart : 4.051349878311157
# Training Loss : 8.208603858947754
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1083 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.46154022216797
# Eval_StdReturn : 23.979528427124023
# Eval_MaxReturn : 115.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 78.46153846153847
# Train_AverageReturn : 77.35713958740234
# Train_StdReturn : 27.09139633178711
# Train_MaxReturn : 116.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 77.35714285714286
# Train_EnvstepsSoFar : 28772
# TimeSinceStart : 4.200407981872559
# Training Loss : 7.92587947845459
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1074 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.5000
# Eval_StdReturn : 29.22511100769043
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 77.5
# Train_AverageReturn : 76.71428680419922
# Train_StdReturn : 25.50469970703125
# Train_MaxReturn : 113.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 76.71428571428571
# Train_EnvstepsSoFar : 29846
# TimeSinceStart : 4.355803966522217
# Training Loss : 7.512829780578613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.88888549804688
# Eval_StdReturn : 25.030845642089844
# Eval_MaxReturn : 134.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 112.88888888888889
# Train_AverageReturn : 86.75
# Train_StdReturn : 28.455007553100586
# Train_MaxReturn : 122.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 86.75
# Train_EnvstepsSoFar : 30887
# TimeSinceStart : 4.50202202796936
# Training Loss : 7.963744163513184
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.80000305175781
# Eval_StdReturn : 30.941234588623047
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 101.8
# Train_AverageReturn : 84.5
# Train_StdReturn : 35.39420700073242
# Train_MaxReturn : 130.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 84.5
# Train_EnvstepsSoFar : 31901
# TimeSinceStart : 4.648219108581543
# Training Loss : 7.712536334991455
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 125.22222137451172
# Eval_StdReturn : 28.038774490356445
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 58.0
# Eval_AverageEpLen : 125.22222222222223
# Train_AverageReturn : 113.44444274902344
# Train_StdReturn : 17.938854217529297
# Train_MaxReturn : 132.0
# Train_MinReturn : 69.0
# Train_AverageEpLen : 113.44444444444444
# Train_EnvstepsSoFar : 32922
# TimeSinceStart : 4.805656909942627
# Training Loss : 8.32075023651123
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1085 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 141.375
# Eval_StdReturn : 12.951231002807617
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 141.375
# Train_AverageReturn : 120.55555725097656
# Train_StdReturn : 9.452937126159668
# Train_MaxReturn : 140.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 120.55555555555556
# Train_EnvstepsSoFar : 34007
# TimeSinceStart : 4.968177080154419
# Training Loss : 8.483895301818848
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 139.250
# Eval_StdReturn : 33.03691101074219
# Eval_MaxReturn : 184.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 139.25
# Train_AverageReturn : 132.125
# Train_StdReturn : 27.750844955444336
# Train_MaxReturn : 156.0
# Train_MinReturn : 63.0
# Train_AverageEpLen : 132.125
# Train_EnvstepsSoFar : 35064
# TimeSinceStart : 5.1227030754089355
# Training Loss : 8.419280052185059
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.000
# Eval_StdReturn : 21.928455352783203
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 131.0
# Eval_AverageEpLen : 169.0
# Train_AverageReturn : 151.2857208251953
# Train_StdReturn : 15.52614688873291
# Train_MaxReturn : 173.0
# Train_MinReturn : 127.0
# Train_AverageEpLen : 151.28571428571428
# Train_EnvstepsSoFar : 36123
# TimeSinceStart : 5.364404916763306
# Training Loss : 8.663304328918457
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1009 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.500
# Eval_StdReturn : 17.0758113861084
# Eval_MaxReturn : 197.0
# Eval_MinReturn : 144.0
# Eval_AverageEpLen : 171.5
# Train_AverageReturn : 168.1666717529297
# Train_StdReturn : 11.639254570007324
# Train_MaxReturn : 180.0
# Train_MinReturn : 145.0
# Train_AverageEpLen : 168.16666666666666
# Train_EnvstepsSoFar : 37132
# TimeSinceStart : 5.5403571128845215
# Training Loss : 8.696377754211426
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1106 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.500
# Eval_StdReturn : 9.569918632507324
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 173.0
# Eval_AverageEpLen : 191.5
# Train_AverageReturn : 184.3333282470703
# Train_StdReturn : 21.853042602539062
# Train_MaxReturn : 200.0
# Train_MinReturn : 151.0
# Train_AverageEpLen : 184.33333333333334
# Train_EnvstepsSoFar : 38238
# TimeSinceStart : 5.7015769481658936
# Training Loss : 8.917411804199219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1172 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.8333282470703
# Eval_StdReturn : 7.080881595611572
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 181.0
# Eval_AverageEpLen : 196.83333333333334
# Train_AverageReturn : 195.3333282470703
# Train_StdReturn : 8.055364608764648
# Train_MaxReturn : 200.0
# Train_MinReturn : 178.0
# Train_AverageEpLen : 195.33333333333334
# Train_EnvstepsSoFar : 39410
# TimeSinceStart : 5.868495941162109
# Training Loss : 8.879924774169922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 40410
# TimeSinceStart : 6.007802963256836
# Training Loss : 8.781070709228516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 41410
# TimeSinceStart : 6.148523807525635
# Training Loss : 8.7061128616333
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 42410
# TimeSinceStart : 6.29001784324646
# Training Loss : 8.717732429504395
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 43410
# TimeSinceStart : 6.441353797912598
# Training Loss : 8.477831840515137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 44410
# TimeSinceStart : 6.589107036590576
# Training Loss : 8.730228424072266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 45410
# TimeSinceStart : 6.731215000152588
# Training Loss : 8.27181625366211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 46410
# TimeSinceStart : 6.871309041976929
# Training Loss : 8.456888198852539
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 47410
# TimeSinceStart : 7.0153889656066895
# Training Loss : 8.602038383483887
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 48410
# TimeSinceStart : 7.156865835189819
# Training Loss : 8.403267860412598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 49410
# TimeSinceStart : 7.295341968536377
# Training Loss : 8.296006202697754
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 50410
# TimeSinceStart : 7.4358580112457275
# Training Loss : 8.546695709228516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 51410
# TimeSinceStart : 7.575495004653931
# Training Loss : 8.452625274658203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 52410
# TimeSinceStart : 7.715888977050781
# Training Loss : 8.155616760253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1198 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 199.6666717529297
# Train_StdReturn : 0.745356023311615
# Train_MaxReturn : 200.0
# Train_MinReturn : 198.0
# Train_AverageEpLen : 199.66666666666666
# Train_EnvstepsSoFar : 53608
# TimeSinceStart : 7.88098406791687
# Training Loss : 8.437295913696289
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 54608
# TimeSinceStart : 8.032207012176514
# Training Loss : 8.387062072753906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1170 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.6666717529297
# Eval_StdReturn : 2.981423854827881
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 192.0
# Eval_AverageEpLen : 198.66666666666666
# Train_AverageReturn : 195.0
# Train_StdReturn : 7.071067810058594
# Train_MaxReturn : 200.0
# Train_MinReturn : 185.0
# Train_AverageEpLen : 195.0
# Train_EnvstepsSoFar : 55778
# TimeSinceStart : 8.207571029663086
# Training Loss : 8.539886474609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1184 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.1666717529297
# Eval_StdReturn : 7.711823463439941
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 179.0
# Eval_AverageEpLen : 196.16666666666666
# Train_AverageReturn : 197.3333282470703
# Train_StdReturn : 4.749269008636475
# Train_MaxReturn : 200.0
# Train_MinReturn : 187.0
# Train_AverageEpLen : 197.33333333333334
# Train_EnvstepsSoFar : 56962
# TimeSinceStart : 8.402718782424927
# Training Loss : 8.124626159667969
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1150 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.1666717529297
# Eval_StdReturn : 11.006311416625977
# Eval_MaxReturn : 199.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 184.16666666666666
# Train_AverageReturn : 191.6666717529297
# Train_StdReturn : 7.43116569519043
# Train_MaxReturn : 200.0
# Train_MinReturn : 180.0
# Train_AverageEpLen : 191.66666666666666
# Train_EnvstepsSoFar : 58112
# TimeSinceStart : 8.581971168518066
# Training Loss : 8.561662673950195
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1120 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.3333282470703
# Eval_StdReturn : 10.796090126037598
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 164.0
# Eval_AverageEpLen : 182.33333333333334
# Train_AverageReturn : 186.6666717529297
# Train_StdReturn : 5.557777404785156
# Train_MaxReturn : 193.0
# Train_MinReturn : 178.0
# Train_AverageEpLen : 186.66666666666666
# Train_EnvstepsSoFar : 59232
# TimeSinceStart : 8.741950035095215
# Training Loss : 8.433545112609863
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1124 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.000
# Eval_StdReturn : 5.94418478012085
# Eval_MaxReturn : 195.0
# Eval_MinReturn : 177.0
# Eval_AverageEpLen : 186.0
# Train_AverageReturn : 187.3333282470703
# Train_StdReturn : 6.574361324310303
# Train_MaxReturn : 196.0
# Train_MinReturn : 177.0
# Train_AverageEpLen : 187.33333333333334
# Train_EnvstepsSoFar : 60356
# TimeSinceStart : 8.900512933731079
# Training Loss : 7.907977104187012
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1070 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.6666717529297
# Eval_StdReturn : 7.909207344055176
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 175.0
# Eval_AverageEpLen : 188.66666666666666
# Train_AverageReturn : 178.3333282470703
# Train_StdReturn : 15.986104965209961
# Train_MaxReturn : 191.0
# Train_MinReturn : 144.0
# Train_AverageEpLen : 178.33333333333334
# Train_EnvstepsSoFar : 61426
# TimeSinceStart : 9.066545963287354
# Training Loss : 8.19996452331543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.000
# Eval_StdReturn : 54.440006256103516
# Eval_MaxReturn : 192.0
# Eval_MinReturn : 32.0
# Eval_AverageEpLen : 165.0
# Train_AverageReturn : 168.8333282470703
# Train_StdReturn : 35.90922164916992
# Train_MaxReturn : 194.0
# Train_MinReturn : 90.0
# Train_AverageEpLen : 168.83333333333334
# Train_EnvstepsSoFar : 62439
# TimeSinceStart : 9.22122597694397
# Training Loss : 8.317123413085938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1085 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.000
# Eval_StdReturn : 4.082482814788818
# Eval_MaxReturn : 199.0
# Eval_MinReturn : 188.0
# Eval_AverageEpLen : 192.0
# Train_AverageReturn : 180.8333282470703
# Train_StdReturn : 19.462928771972656
# Train_MaxReturn : 199.0
# Train_MinReturn : 139.0
# Train_AverageEpLen : 180.83333333333334
# Train_EnvstepsSoFar : 63524
# TimeSinceStart : 9.378209829330444
# Training Loss : 8.129114151000977
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1118 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.3333282470703
# Eval_StdReturn : 24.122373580932617
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 134.0
# Eval_AverageEpLen : 186.33333333333334
# Train_AverageReturn : 186.3333282470703
# Train_StdReturn : 9.122621536254883
# Train_MaxReturn : 200.0
# Train_MinReturn : 175.0
# Train_AverageEpLen : 186.33333333333334
# Train_EnvstepsSoFar : 64642
# TimeSinceStart : 9.531385898590088
# Training Loss : 8.406208038330078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1026 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.000
# Eval_StdReturn : 52.25213623046875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 80.0
# Eval_AverageEpLen : 158.0
# Train_AverageReturn : 146.57142639160156
# Train_StdReturn : 54.45275115966797
# Train_MaxReturn : 200.0
# Train_MinReturn : 81.0
# Train_AverageEpLen : 146.57142857142858
# Train_EnvstepsSoFar : 65668
# TimeSinceStart : 9.679812908172607
# Training Loss : 7.956710338592529
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.85714721679688
# Eval_StdReturn : 55.944942474365234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 72.0
# Eval_AverageEpLen : 159.85714285714286
# Train_AverageReturn : 133.0
# Train_StdReturn : 54.52751541137695
# Train_MaxReturn : 200.0
# Train_MinReturn : 76.0
# Train_AverageEpLen : 133.0
# Train_EnvstepsSoFar : 66732
# TimeSinceStart : 9.83368992805481
# Training Loss : 7.826821804046631
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1092 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.85714721679688
# Eval_StdReturn : 55.277034759521484
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 153.85714285714286
# Train_AverageReturn : 156.0
# Train_StdReturn : 60.919151306152344
# Train_MaxReturn : 200.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 156.0
# Train_EnvstepsSoFar : 67824
# TimeSinceStart : 9.984694957733154
# Training Loss : 8.202040672302246
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.8333282470703
# Eval_StdReturn : 47.645973205566406
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 63.0
# Eval_AverageEpLen : 166.83333333333334
# Train_AverageReturn : 148.7142791748047
# Train_StdReturn : 59.31686019897461
# Train_MaxReturn : 200.0
# Train_MinReturn : 73.0
# Train_AverageEpLen : 148.71428571428572
# Train_EnvstepsSoFar : 68865
# TimeSinceStart : 10.199009895324707
# Training Loss : 8.219807624816895
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 145.250
# Eval_StdReturn : 57.79435348510742
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 145.25
# Train_AverageReturn : 111.11111450195312
# Train_StdReturn : 64.21741485595703
# Train_MaxReturn : 200.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 111.11111111111111
# Train_EnvstepsSoFar : 69865
# TimeSinceStart : 10.349113941192627
# Training Loss : 7.516595840454102
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.250
# Eval_StdReturn : 60.304954528808594
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 64.0
# Eval_AverageEpLen : 142.25
# Train_AverageReturn : 100.19999694824219
# Train_StdReturn : 46.65361785888672
# Train_MaxReturn : 200.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 100.2
# Train_EnvstepsSoFar : 70867
# TimeSinceStart : 10.50256085395813
# Training Loss : 7.691504001617432
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1058 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.5999984741211
# Eval_StdReturn : 57.03192138671875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 100.6
# Train_AverageReturn : 117.55555725097656
# Train_StdReturn : 54.77045440673828
# Train_MaxReturn : 200.0
# Train_MinReturn : 63.0
# Train_AverageEpLen : 117.55555555555556
# Train_EnvstepsSoFar : 71925
# TimeSinceStart : 10.651483058929443
# Training Loss : 7.862732887268066
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.30000305175781
# Eval_StdReturn : 66.73837280273438
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 102.3
# Train_AverageReturn : 89.41666412353516
# Train_StdReturn : 51.072593688964844
# Train_MaxReturn : 200.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 89.41666666666667
# Train_EnvstepsSoFar : 72998
# TimeSinceStart : 10.799154996871948
# Training Loss : 7.624004364013672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1101 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.375
# Eval_StdReturn : 65.69425201416016
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 126.375
# Train_AverageReturn : 122.33333587646484
# Train_StdReturn : 62.9532470703125
# Train_MaxReturn : 200.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 122.33333333333333
# Train_EnvstepsSoFar : 74099
# TimeSinceStart : 10.950594902038574
# Training Loss : 7.851454257965088
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 24.414634704589844
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
# At timestep:     1071 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.2857208251953
# ...
# Eval_AverageEpLen : 144.14285714285714
# Train_AverageReturn : 151.14285278320312
# Train_StdReturn : 7.376189231872559
# Train_MaxReturn : 164.0
# Train_MinReturn : 142.0
# Train_AverageEpLen : 151.14285714285714
# Train_EnvstepsSoFar : 80653
# TimeSinceStart : 12.308725118637085
# Training Loss : 4.963077068328857
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1082 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 135.875
# Eval_StdReturn : 7.270445346832275
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 126.0
# Eval_AverageEpLen : 135.875
# Train_AverageReturn : 154.57142639160156
# Train_StdReturn : 12.408028602600098
# Train_MaxReturn : 184.0
# Train_MinReturn : 145.0
# Train_AverageEpLen : 154.57142857142858
# Train_EnvstepsSoFar : 81735
# TimeSinceStart : 12.492469072341919
# Training Loss : 4.843043327331543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 145.7142791748047
# Eval_StdReturn : 12.780725479125977
# Eval_MaxReturn : 169.0
# Eval_MinReturn : 131.0
# Eval_AverageEpLen : 145.71428571428572
# Train_AverageReturn : 146.7142791748047
# Train_StdReturn : 14.2198486328125
# Train_MaxReturn : 178.0
# Train_MinReturn : 132.0
# Train_AverageEpLen : 146.71428571428572
# Train_EnvstepsSoFar : 82762
# TimeSinceStart : 12.671971082687378
# Training Loss : 4.890585899353027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.7142791748047
# Eval_StdReturn : 20.596216201782227
# Eval_MaxReturn : 186.0
# Eval_MinReturn : 129.0
# Eval_AverageEpLen : 158.71428571428572
# Train_AverageReturn : 148.7142791748047
# Train_StdReturn : 14.45895004272461
# Train_MaxReturn : 173.0
# Train_MinReturn : 130.0
# Train_AverageEpLen : 148.71428571428572
# Train_EnvstepsSoFar : 83803
# TimeSinceStart : 12.823143243789673
# Training Loss : 4.8636956214904785
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.2857208251953
# Eval_StdReturn : 16.077617645263672
# Eval_MaxReturn : 183.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 158.28571428571428
# Train_AverageReturn : 152.0
# Train_StdReturn : 18.935983657836914
# Train_MaxReturn : 187.0
# Train_MinReturn : 120.0
# Train_AverageEpLen : 152.0
# Train_EnvstepsSoFar : 84867
# TimeSinceStart : 12.97909927368164
# Training Loss : 4.549404621124268
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1074 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.375
# Eval_StdReturn : 10.463478088378906
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 115.0
# Eval_AverageEpLen : 128.375
# Train_AverageReturn : 153.42857360839844
# Train_StdReturn : 14.04947566986084
# Train_MaxReturn : 173.0
# Train_MinReturn : 130.0
# Train_AverageEpLen : 153.42857142857142
# Train_EnvstepsSoFar : 85941
# TimeSinceStart : 13.126638174057007
# Training Loss : 4.936763286590576
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1121 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.55555725097656
# Eval_StdReturn : 7.875575542449951
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 121.55555555555556
# Train_AverageReturn : 140.125
# Train_StdReturn : 13.373831748962402
# Train_MaxReturn : 164.0
# Train_MinReturn : 118.0
# Train_AverageEpLen : 140.125
# Train_EnvstepsSoFar : 87062
# TimeSinceStart : 13.330010175704956
# Training Loss : 4.516178131103516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1075 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.000
# Eval_StdReturn : 9.137833595275879
# Eval_MaxReturn : 146.0
# Eval_MinReturn : 113.0
# Eval_AverageEpLen : 128.0
# Train_AverageReturn : 134.375
# Train_StdReturn : 19.26744270324707
# Train_MaxReturn : 177.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 134.375
# Train_EnvstepsSoFar : 88137
# TimeSinceStart : 13.488624334335327
# Training Loss : 4.5882110595703125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1006 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.625
# Eval_StdReturn : 9.564746856689453
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 117.0
# Eval_AverageEpLen : 132.625
# Train_AverageReturn : 125.75
# Train_StdReturn : 12.305994033813477
# Train_MaxReturn : 146.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 125.75
# Train_EnvstepsSoFar : 89143
# TimeSinceStart : 13.640656232833862
# Training Loss : 4.940335750579834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1090 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.44444274902344
# Eval_StdReturn : 11.71049976348877
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 106.0
# Eval_AverageEpLen : 122.44444444444444
# Train_AverageReturn : 136.25
# Train_StdReturn : 11.82951831817627
# Train_MaxReturn : 158.0
# Train_MinReturn : 121.0
# Train_AverageEpLen : 136.25
# Train_EnvstepsSoFar : 90233
# TimeSinceStart : 13.802611351013184
# Training Loss : 4.055854320526123
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1095 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.55555725097656
# Eval_StdReturn : 12.166540145874023
# Eval_MaxReturn : 142.0
# Eval_MinReturn : 106.0
# Eval_AverageEpLen : 120.55555555555556
# Train_AverageReturn : 136.875
# Train_StdReturn : 18.66438865661621
# Train_MaxReturn : 172.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 136.875
# Train_EnvstepsSoFar : 91328
# TimeSinceStart : 13.958112001419067
# Training Loss : 4.682816028594971
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 135.625
# Eval_StdReturn : 17.24773597717285
# Eval_MaxReturn : 170.0
# Eval_MinReturn : 115.0
# Eval_AverageEpLen : 135.625
# Train_AverageReturn : 133.0
# Train_StdReturn : 11.779218673706055
# Train_MaxReturn : 155.0
# Train_MinReturn : 116.0
# Train_AverageEpLen : 133.0
# Train_EnvstepsSoFar : 92392
# TimeSinceStart : 14.113689184188843
# Training Loss : 4.234470844268799
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1093 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 135.125
# Eval_StdReturn : 12.200794219970703
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 121.0
# Eval_AverageEpLen : 135.125
# Train_AverageReturn : 136.625
# Train_StdReturn : 15.491429328918457
# Train_MaxReturn : 156.0
# Train_MinReturn : 106.0
# Train_AverageEpLen : 136.625
# Train_EnvstepsSoFar : 93485
# TimeSinceStart : 14.26487398147583
# Training Loss : 4.3085761070251465
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 131.625
# Eval_StdReturn : 14.044015884399414
# Eval_MaxReturn : 152.0
# Eval_MinReturn : 114.0
# Eval_AverageEpLen : 131.625
# Train_AverageReturn : 130.0
# Train_StdReturn : 9.380831718444824
# Train_MaxReturn : 146.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 130.0
# Train_EnvstepsSoFar : 94525
# TimeSinceStart : 14.413831233978271
# Training Loss : 4.788403511047363
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1118 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 134.125
# Eval_StdReturn : 15.218717575073242
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 117.0
# Eval_AverageEpLen : 134.125
# Train_AverageReturn : 124.22222137451172
# Train_StdReturn : 16.05392074584961
# Train_MaxReturn : 160.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 124.22222222222223
# Train_EnvstepsSoFar : 95643
# TimeSinceStart : 14.567111253738403
# Training Loss : 4.453845024108887
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1026 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.875
# Eval_StdReturn : 12.046134948730469
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 111.0
# Eval_AverageEpLen : 130.875
# Train_AverageReturn : 128.25
# Train_StdReturn : 12.705805778503418
# Train_MaxReturn : 149.0
# Train_MinReturn : 111.0
# Train_AverageEpLen : 128.25
# Train_EnvstepsSoFar : 96669
# TimeSinceStart : 14.716477394104004
# Training Loss : 4.581711769104004
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1006 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 137.625
# Eval_StdReturn : 6.945096969604492
# Eval_MaxReturn : 148.0
# Eval_MinReturn : 131.0
# Eval_AverageEpLen : 137.625
# Train_AverageReturn : 143.7142791748047
# Train_StdReturn : 14.839275360107422
# Train_MaxReturn : 168.0
# Train_MinReturn : 120.0
# Train_AverageEpLen : 143.71428571428572
# Train_EnvstepsSoFar : 97675
# TimeSinceStart : 14.864465236663818
# Training Loss : 4.869815349578857
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1062 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.750
# Eval_StdReturn : 13.516194343566895
# Eval_MaxReturn : 150.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 130.75
# Train_AverageReturn : 132.75
# Train_StdReturn : 18.005207061767578
# Train_MaxReturn : 174.0
# Train_MinReturn : 113.0
# Train_AverageEpLen : 132.75
# Train_EnvstepsSoFar : 98737
# TimeSinceStart : 15.01692533493042
# Training Loss : 4.402007102966309
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.22222137451172
# Eval_StdReturn : 5.513171672821045
# Eval_MaxReturn : 126.0
# Eval_MinReturn : 108.0
# Eval_AverageEpLen : 115.22222222222223
# Train_AverageReturn : 127.125
# Train_StdReturn : 9.061422348022461
# Train_MaxReturn : 142.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 127.125
# Train_EnvstepsSoFar : 99754
# TimeSinceStart : 15.168049335479736
# Training Loss : 4.556375503540039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.625
# Eval_StdReturn : 12.287569999694824
# Eval_MaxReturn : 146.0
# Eval_MinReturn : 113.0
# Eval_AverageEpLen : 132.625
# Train_AverageReturn : 132.625
# Train_StdReturn : 15.231033325195312
# Train_MaxReturn : 168.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 132.625
# Train_EnvstepsSoFar : 100815
# TimeSinceStart : 15.324217319488525
# Training Loss : 4.726733207702637
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1074 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.44444274902344
# Eval_StdReturn : 6.767752170562744
# Eval_MaxReturn : 139.0
# Eval_MinReturn : 115.0
# Eval_AverageEpLen : 124.44444444444444
# Train_AverageReturn : 134.25
# Train_StdReturn : 11.04253101348877
# Train_MaxReturn : 148.0
# Train_MinReturn : 113.0
# Train_AverageEpLen : 134.25
# Train_EnvstepsSoFar : 101889
# TimeSinceStart : 15.50186014175415
# Training Loss : 4.6451826095581055
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1140 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.000
# Eval_StdReturn : 11.236102104187012
# Eval_MaxReturn : 153.0
# Eval_MinReturn : 122.0
# Eval_AverageEpLen : 142.0
# Train_AverageReturn : 142.5
# Train_StdReturn : 19.678668975830078
# Train_MaxReturn : 169.0
# Train_MinReturn : 115.0
# Train_AverageEpLen : 142.5
# Train_EnvstepsSoFar : 103029
# TimeSinceStart : 15.723149061203003
# Training Loss : 4.688541889190674
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1106 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 144.000
# Eval_StdReturn : 23.916521072387695
# Eval_MaxReturn : 194.0
# Eval_MinReturn : 118.0
# Eval_AverageEpLen : 144.0
# Train_AverageReturn : 138.25
# Train_StdReturn : 20.28392219543457
# Train_MaxReturn : 185.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 138.25
# Train_EnvstepsSoFar : 104135
# TimeSinceStart : 15.884581327438354
# Training Loss : 4.722438812255859
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.500
# Eval_StdReturn : 19.015344619750977
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 144.0
# Eval_AverageEpLen : 173.5
# Train_AverageReturn : 151.57142639160156
# Train_StdReturn : 15.295724868774414
# Train_MaxReturn : 173.0
# Train_MinReturn : 131.0
# Train_AverageEpLen : 151.57142857142858
# Train_EnvstepsSoFar : 105196
# TimeSinceStart : 16.032109260559082
# Training Loss : 4.8732428550720215
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 25.149999618530273
# Done logging...

# %% [markdown]
# We should see the reward to go estimator outperforming the full returns estimator, with some runs reaching the maximum reward of 200. There will likely however be high variance between runs.

# %%
### Visualize Policy Gradient results on CartPole
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/CartPole
# Out:
#       <iframe id="tensorboard-frame-810107a0f6826f0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-810107a0f6826f0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# We can also compare our estimators on a more complex task, though you will probably see that they don't perform well (not getting much above 200 returns). Note that on this more complex task, we use a much larger batch size to reduce variance in the policy gradients.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = False
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/Hopper/full_returns/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:440: UserWarning: WARN: The `registry.env_specs` property along with `EnvSpecTree` is deprecated. Please use `registry` directly as a dictionary instead.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment Hopper-v2 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/Cython/Distutils/old_build_ext.py:14: DeprecationWarning: dep_util is Deprecated. Use functions from setuptools instead.
#   from distutils.dep_util import newer, newer_group
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/mujoco/mujoco_env.py:237: UserWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.4118537902832
# Eval_StdReturn : 46.61728286743164
# Eval_MaxReturn : 162.16844177246094
# Eval_MinReturn : 8.17390251159668
# Eval_AverageEpLen : 35.7
# Train_AverageReturn : 9.695383071899414
# Train_StdReturn : 5.122409820556641
# Train_MaxReturn : 75.24513244628906
# Train_MinReturn : 2.3481526374816895
# Train_AverageEpLen : 13.217965653896961
# Train_EnvstepsSoFar : 10006
# TimeSinceStart : 2.3097472190856934
# Training Loss : 34.156253814697266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.4079360961914
# Eval_StdReturn : 34.9294319152832
# Eval_MaxReturn : 224.99478149414062
# Eval_MinReturn : 56.08492660522461
# Eval_AverageEpLen : 47.09090909090909
# Train_AverageReturn : 46.077613830566406
# Train_StdReturn : 38.28781509399414
# Train_MaxReturn : 242.06600952148438
# Train_MinReturn : 5.773202896118164
# Train_AverageEpLen : 34.641379310344824
# Train_EnvstepsSoFar : 20052
# TimeSinceStart : 4.602428197860718
# Training Loss : 84.92732238769531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 58.38317108154297
# Eval_StdReturn : 6.268874168395996
# Eval_MaxReturn : 74.43610382080078
# Eval_MinReturn : 48.534942626953125
# Eval_AverageEpLen : 35.689655172413794
# Train_AverageReturn : 72.69496154785156
# Train_StdReturn : 20.16348648071289
# Train_MaxReturn : 146.70150756835938
# Train_MinReturn : 6.766763687133789
# Train_AverageEpLen : 46.022935779816514
# Train_EnvstepsSoFar : 30085
# TimeSinceStart : 6.823116064071655
# Training Loss : 99.57820129394531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.933502197265625
# Eval_StdReturn : 7.610837459564209
# Eval_MaxReturn : 72.0389404296875
# Eval_MinReturn : 43.231563568115234
# Eval_AverageEpLen : 32.61290322580645
# Train_AverageReturn : 59.31076431274414
# Train_StdReturn : 9.448347091674805
# Train_MaxReturn : 112.51678466796875
# Train_MinReturn : 43.415897369384766
# Train_AverageEpLen : 36.12230215827338
# Train_EnvstepsSoFar : 40127
# TimeSinceStart : 9.006413221359253
# Training Loss : 102.69141387939453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 58.73696517944336
# Eval_StdReturn : 11.993568420410156
# Eval_MaxReturn : 99.101806640625
# Eval_MinReturn : 44.131465911865234
# Eval_AverageEpLen : 34.06666666666667
# Train_AverageReturn : 55.69554138183594
# Train_StdReturn : 10.594849586486816
# Train_MaxReturn : 122.84895324707031
# Train_MinReturn : 43.90467071533203
# Train_AverageEpLen : 32.72875816993464
# Train_EnvstepsSoFar : 50142
# TimeSinceStart : 11.310802221298218
# Training Loss : 105.25565338134766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.14258575439453
# Eval_StdReturn : 25.734054565429688
# Eval_MaxReturn : 175.37161254882812
# Eval_MinReturn : 47.12706756591797
# Eval_AverageEpLen : 39.03846153846154
# Train_AverageReturn : 56.39609146118164
# Train_StdReturn : 9.6419095993042
# Train_MaxReturn : 92.91867065429688
# Train_MinReturn : 42.55605697631836
# Train_AverageEpLen : 32.493506493506494
# Train_EnvstepsSoFar : 60150
# TimeSinceStart : 13.429877042770386
# Training Loss : 108.58161163330078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.40436553955078
# Eval_StdReturn : 40.10634231567383
# Eval_MaxReturn : 204.1906280517578
# Eval_MinReturn : 3.909097909927368
# Eval_AverageEpLen : 43.875
# Train_AverageReturn : 61.68965148925781
# Train_StdReturn : 13.095187187194824
# Train_MaxReturn : 138.72238159179688
# Train_MinReturn : 44.98158645629883
# Train_AverageEpLen : 35.126315789473686
# Train_EnvstepsSoFar : 70161
# TimeSinceStart : 15.502539157867432
# Training Loss : 114.0258560180664
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.75731658935547
# Eval_StdReturn : 18.281539916992188
# Eval_MaxReturn : 102.25847625732422
# Eval_MinReturn : 40.65214920043945
# Eval_AverageEpLen : 40.08
# Train_AverageReturn : 70.42090606689453
# Train_StdReturn : 22.899808883666992
# Train_MaxReturn : 188.59735107421875
# Train_MinReturn : 40.52927017211914
# Train_AverageEpLen : 40.104
# Train_EnvstepsSoFar : 80187
# TimeSinceStart : 17.55556035041809
# Training Loss : 119.54219055175781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.37786102294922
# Eval_StdReturn : 28.18362808227539
# Eval_MaxReturn : 178.0700225830078
# Eval_MinReturn : 36.56525421142578
# Eval_AverageEpLen : 36.357142857142854
# Train_AverageReturn : 64.42373657226562
# Train_StdReturn : 21.45113754272461
# Train_MaxReturn : 173.37429809570312
# Train_MinReturn : 3.5699381828308105
# Train_AverageEpLen : 38.46153846153846
# Train_EnvstepsSoFar : 90187
# TimeSinceStart : 19.612183094024658
# Training Loss : 116.45843505859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 57.616050720214844
# Eval_StdReturn : 24.115930557250977
# Eval_MaxReturn : 142.23239135742188
# Eval_MinReturn : 3.51591157913208
# Eval_AverageEpLen : 35.51724137931034
# Train_AverageReturn : 57.2835693359375
# Train_StdReturn : 21.289466857910156
# Train_MaxReturn : 172.7536163330078
# Train_MinReturn : 3.435241222381592
# Train_AverageEpLen : 35.39575971731449
# Train_EnvstepsSoFar : 100204
# TimeSinceStart : 21.815122365951538
# Training Loss : 111.0018081665039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.09111022949219
# Eval_StdReturn : 25.92901039123535
# Eval_MaxReturn : 161.246826171875
# Eval_MinReturn : 36.903953552246094
# Eval_AverageEpLen : 38.5
# Train_AverageReturn : 52.18424987792969
# Train_StdReturn : 18.875133514404297
# Train_MaxReturn : 188.1126251220703
# Train_MinReturn : 3.3762688636779785
# Train_AverageEpLen : 32.94078947368421
# Train_EnvstepsSoFar : 110218
# TimeSinceStart : 23.896655321121216
# Training Loss : 106.68455505371094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 71.09754943847656
# Eval_StdReturn : 35.52497100830078
# Eval_MaxReturn : 167.76776123046875
# Eval_MinReturn : 36.29480743408203
# Eval_AverageEpLen : 43.91304347826087
# Train_AverageReturn : 63.12498474121094
# Train_StdReturn : 27.015527725219727
# Train_MaxReturn : 169.51531982421875
# Train_MinReturn : 35.96122741699219
# Train_AverageEpLen : 39.1171875
# Train_EnvstepsSoFar : 120232
# TimeSinceStart : 26.08584713935852
# Training Loss : 113.92753601074219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 90.77165985107422
# Eval_StdReturn : 46.22522735595703
# Eval_MaxReturn : 173.7526397705078
# Eval_MinReturn : 36.523841857910156
# Eval_AverageEpLen : 53.473684210526315
# Train_AverageReturn : 81.37638854980469
# Train_StdReturn : 39.95554733276367
# Train_MaxReturn : 174.8937530517578
# Train_MinReturn : 3.3156585693359375
# Train_AverageEpLen : 48.82439024390244
# Train_EnvstepsSoFar : 130241
# TimeSinceStart : 28.205700159072876
# Training Loss : 121.23351287841797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.7865753173828
# Eval_StdReturn : 37.613162994384766
# Eval_MaxReturn : 168.40049743652344
# Eval_MinReturn : 60.59563446044922
# Eval_AverageEpLen : 74.35714285714286
# Train_AverageReturn : 100.98271942138672
# Train_StdReturn : 41.9932861328125
# Train_MaxReturn : 188.05152893066406
# Train_MinReturn : 36.565670013427734
# Train_AverageEpLen : 58.82941176470588
# Train_EnvstepsSoFar : 140242
# TimeSinceStart : 30.34405207633972
# Training Loss : 127.18077087402344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10063 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.33592224121094
# Eval_StdReturn : 45.591617584228516
# Eval_MaxReturn : 164.23886108398438
# Eval_MinReturn : 39.2294921875
# Eval_AverageEpLen : 60.588235294117645
# Train_AverageReturn : 113.96295166015625
# Train_StdReturn : 41.92570114135742
# Train_MaxReturn : 172.37142944335938
# Train_MinReturn : 36.978248596191406
# Train_AverageEpLen : 65.34415584415585
# Train_EnvstepsSoFar : 150305
# TimeSinceStart : 32.46056604385376
# Training Loss : 129.11614990234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.72583770751953
# Eval_StdReturn : 27.632640838623047
# Eval_MaxReturn : 142.56634521484375
# Eval_MinReturn : 39.33003616333008
# Eval_AverageEpLen : 42.2
# Train_AverageReturn : 94.53317260742188
# Train_StdReturn : 40.53189468383789
# Train_MaxReturn : 178.368896484375
# Train_MinReturn : 36.51641082763672
# Train_AverageEpLen : 56.245810055865924
# Train_EnvstepsSoFar : 160373
# TimeSinceStart : 34.54077911376953
# Training Loss : 125.10922241210938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.140350341796875
# Eval_StdReturn : 9.06386947631836
# Eval_MaxReturn : 66.1031494140625
# Eval_MinReturn : 28.797435760498047
# Eval_AverageEpLen : 30.176470588235293
# Train_AverageReturn : 64.0173568725586
# Train_StdReturn : 23.415138244628906
# Train_MaxReturn : 138.53543090820312
# Train_MinReturn : 34.025421142578125
# Train_AverageEpLen : 40.152
# Train_EnvstepsSoFar : 170411
# TimeSinceStart : 36.619014263153076
# Training Loss : 113.32849884033203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 54.9023323059082
# Eval_StdReturn : 16.79741668701172
# Eval_MaxReturn : 96.1866226196289
# Eval_MinReturn : 32.28703689575195
# Eval_AverageEpLen : 35.44827586206897
# Train_AverageReturn : 50.62221145629883
# Train_StdReturn : 12.065972328186035
# Train_MaxReturn : 98.08721923828125
# Train_MinReturn : 22.30780029296875
# Train_AverageEpLen : 32.712418300653596
# Train_EnvstepsSoFar : 180421
# TimeSinceStart : 38.71280527114868
# Training Loss : 103.57603454589844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.20494842529297
# Eval_StdReturn : 22.874868392944336
# Eval_MaxReturn : 137.91529846191406
# Eval_MinReturn : 33.2822380065918
# Eval_AverageEpLen : 42.375
# Train_AverageReturn : 51.299461364746094
# Train_StdReturn : 15.594260215759277
# Train_MaxReturn : 137.39559936523438
# Train_MinReturn : 24.141515731811523
# Train_AverageEpLen : 33.336666666666666
# Train_EnvstepsSoFar : 190422
# TimeSinceStart : 41.54229021072388
# Training Loss : 103.89852905273438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.60900115966797
# Eval_StdReturn : 41.64830017089844
# Eval_MaxReturn : 148.4892578125
# Eval_MinReturn : 41.47611618041992
# Eval_AverageEpLen : 58.94117647058823
# Train_AverageReturn : 69.34617614746094
# Train_StdReturn : 29.89370346069336
# Train_MaxReturn : 150.67343139648438
# Train_MinReturn : 33.5279426574707
# Train_AverageEpLen : 44.08810572687225
# Train_EnvstepsSoFar : 200430
# TimeSinceStart : 43.9812171459198
# Training Loss : 114.28726959228516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.00423431396484
# Eval_StdReturn : 22.44901466369629
# Eval_MaxReturn : 139.3798828125
# Eval_MinReturn : 41.13844299316406
# Eval_AverageEpLen : 69.86666666666666
# Train_AverageReturn : 100.6067123413086
# Train_StdReturn : 33.14950180053711
# Train_MaxReturn : 156.12693786621094
# Train_MinReturn : 39.28748321533203
# Train_AverageEpLen : 61.61963190184049
# Train_EnvstepsSoFar : 210474
# TimeSinceStart : 46.06881833076477
# Training Loss : 123.9762954711914
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.93305969238281
# Eval_StdReturn : 13.346026420593262
# Eval_MaxReturn : 135.35240173339844
# Eval_MinReturn : 74.44475555419922
# Eval_AverageEpLen : 69.53333333333333
# Train_AverageReturn : 110.11356353759766
# Train_StdReturn : 22.58753204345703
# Train_MaxReturn : 144.09640502929688
# Train_MinReturn : 37.38492202758789
# Train_AverageEpLen : 68.17687074829932
# Train_EnvstepsSoFar : 220496
# TimeSinceStart : 48.38630032539368
# Training Loss : 126.19544219970703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.02433776855469
# Eval_StdReturn : 15.147570610046387
# Eval_MaxReturn : 122.97152709960938
# Eval_MinReturn : 68.51282501220703
# Eval_AverageEpLen : 59.1764705882353
# Train_AverageReturn : 109.45355224609375
# Train_StdReturn : 20.954893112182617
# Train_MaxReturn : 137.88174438476562
# Train_MinReturn : 37.1779899597168
# Train_AverageEpLen : 68.71232876712328
# Train_EnvstepsSoFar : 230528
# TimeSinceStart : 50.441052198410034
# Training Loss : 125.85018157958984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.91976928710938
# Eval_StdReturn : 13.801961898803711
# Eval_MaxReturn : 129.06924438476562
# Eval_MinReturn : 67.86355590820312
# Eval_AverageEpLen : 59.1764705882353
# Train_AverageReturn : 99.16726684570312
# Train_StdReturn : 15.83681583404541
# Train_MaxReturn : 135.62078857421875
# Train_MinReturn : 37.437870025634766
# Train_AverageEpLen : 60.035928143712574
# Train_EnvstepsSoFar : 240554
# TimeSinceStart : 52.79133415222168
# Training Loss : 125.84042358398438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.40091705322266
# Eval_StdReturn : 25.462081909179688
# Eval_MaxReturn : 125.97380828857422
# Eval_MinReturn : 36.549163818359375
# Eval_AverageEpLen : 58.0
# Train_AverageReturn : 97.74553680419922
# Train_StdReturn : 18.444242477416992
# Train_MaxReturn : 131.95838928222656
# Train_MinReturn : 36.273841857910156
# Train_AverageEpLen : 59.414201183431956
# Train_EnvstepsSoFar : 250595
# TimeSinceStart : 55.17229700088501
# Training Loss : 125.36761474609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.59800720214844
# Eval_StdReturn : 37.98117446899414
# Eval_MaxReturn : 135.10911560058594
# Eval_MinReturn : 35.06875991821289
# Eval_AverageEpLen : 61.411764705882355
# Train_AverageReturn : 92.66368865966797
# Train_StdReturn : 19.50991439819336
# Train_MaxReturn : 130.36886596679688
# Train_MinReturn : 35.61750793457031
# Train_AverageEpLen : 56.41573033707865
# Train_EnvstepsSoFar : 260637
# TimeSinceStart : 57.2359561920166
# Training Loss : 124.93498229980469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 91.05887603759766
# Eval_StdReturn : 26.704788208007812
# Eval_MaxReturn : 120.26176452636719
# Eval_MinReturn : 35.664894104003906
# Eval_AverageEpLen : 62.8125
# Train_AverageReturn : 100.25494384765625
# Train_StdReturn : 36.271366119384766
# Train_MaxReturn : 140.44606018066406
# Train_MinReturn : 35.21550369262695
# Train_AverageEpLen : 62.68125
# Train_EnvstepsSoFar : 270666
# TimeSinceStart : 59.38718819618225
# Training Loss : 123.3904037475586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.23223114013672
# Eval_StdReturn : 29.69322395324707
# Eval_MaxReturn : 107.51094055175781
# Eval_MinReturn : 34.54707336425781
# Eval_AverageEpLen : 54.36842105263158
# Train_AverageReturn : 81.37934875488281
# Train_StdReturn : 31.333749771118164
# Train_MaxReturn : 120.19972229003906
# Train_MinReturn : 34.51404571533203
# Train_AverageEpLen : 56.28089887640449
# Train_EnvstepsSoFar : 280684
# TimeSinceStart : 61.69511914253235
# Training Loss : 118.05696105957031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.5362319946289
# Eval_StdReturn : 22.459524154663086
# Eval_MaxReturn : 101.73436737060547
# Eval_MinReturn : 35.40996551513672
# Eval_AverageEpLen : 61.05882352941177
# Train_AverageReturn : 81.71415710449219
# Train_StdReturn : 27.75371742248535
# Train_MaxReturn : 117.96781921386719
# Train_MinReturn : 34.36248779296875
# Train_AverageEpLen : 57.96531791907515
# Train_EnvstepsSoFar : 290712
# TimeSinceStart : 63.80765914916992
# Training Loss : 118.68059539794922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.60538482666016
# Eval_StdReturn : 18.312000274658203
# Eval_MaxReturn : 95.0958480834961
# Eval_MinReturn : 36.411346435546875
# Eval_AverageEpLen : 63.25
# Train_AverageReturn : 85.36421966552734
# Train_StdReturn : 21.49139404296875
# Train_MaxReturn : 106.65819549560547
# Train_MinReturn : 33.92180633544922
# Train_AverageEpLen : 62.192546583850934
# Train_EnvstepsSoFar : 300725
# TimeSinceStart : 65.93346118927002
# Training Loss : 119.96105194091797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.46055603027344
# Eval_StdReturn : 3.1985268592834473
# Eval_MaxReturn : 102.21101379394531
# Eval_MinReturn : 88.79302978515625
# Eval_AverageEpLen : 69.8
# Train_AverageReturn : 91.75360870361328
# Train_StdReturn : 12.843222618103027
# Train_MaxReturn : 108.12532806396484
# Train_MinReturn : 35.15083694458008
# Train_AverageEpLen : 67.03333333333333
# Train_EnvstepsSoFar : 310780
# TimeSinceStart : 68.04624724388123
# Training Loss : 121.10834503173828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.1291275024414
# Eval_StdReturn : 4.399224281311035
# Eval_MaxReturn : 109.43578338623047
# Eval_MinReturn : 91.47640228271484
# Eval_AverageEpLen : 70.2
# Train_AverageReturn : 95.92243194580078
# Train_StdReturn : 3.357459306716919
# Train_MaxReturn : 106.14132690429688
# Train_MinReturn : 87.4931411743164
# Train_AverageEpLen : 69.48611111111111
# Train_EnvstepsSoFar : 320786
# TimeSinceStart : 70.22080206871033
# Training Loss : 123.19805908203125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.99236297607422
# Eval_StdReturn : 13.865134239196777
# Eval_MaxReturn : 126.94184112548828
# Eval_MinReturn : 67.14404296875
# Eval_AverageEpLen : 73.57142857142857
# Train_AverageReturn : 97.81199645996094
# Train_StdReturn : 4.096791744232178
# Train_MaxReturn : 112.2064437866211
# Train_MinReturn : 89.9283447265625
# Train_AverageEpLen : 70.16783216783217
# Train_EnvstepsSoFar : 330820
# TimeSinceStart : 72.45174312591553
# Training Loss : 124.13105773925781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10059 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.4372787475586
# Eval_StdReturn : 11.877925872802734
# Eval_MaxReturn : 117.94296264648438
# Eval_MinReturn : 57.34169006347656
# Eval_AverageEpLen : 40.88
# Train_AverageReturn : 117.2229995727539
# Train_StdReturn : 15.582810401916504
# Train_MaxReturn : 137.97337341308594
# Train_MinReturn : 55.98741149902344
# Train_AverageEpLen : 73.96323529411765
# Train_EnvstepsSoFar : 340879
# TimeSinceStart : 74.56998920440674
# Training Loss : 128.55723571777344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.61785125732422
# Eval_StdReturn : 4.362163066864014
# Eval_MaxReturn : 66.47543334960938
# Eval_MinReturn : 42.004669189453125
# Eval_AverageEpLen : 31.34375
# Train_AverageReturn : 66.17765808105469
# Train_StdReturn : 10.59449577331543
# Train_MaxReturn : 131.73060607910156
# Train_MinReturn : 50.916873931884766
# Train_AverageEpLen : 39.488188976377955
# Train_EnvstepsSoFar : 350909
# TimeSinceStart : 76.94624900817871
# Training Loss : 115.6024398803711
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.181968688964844
# Eval_StdReturn : 3.1392462253570557
# Eval_MaxReturn : 58.984458923339844
# Eval_MinReturn : 43.310001373291016
# Eval_AverageEpLen : 29.91176470588235
# Train_AverageReturn : 52.98703384399414
# Train_StdReturn : 3.7537431716918945
# Train_MaxReturn : 67.11024475097656
# Train_MinReturn : 45.038665771484375
# Train_AverageEpLen : 31.5251572327044
# Train_EnvstepsSoFar : 360934
# TimeSinceStart : 79.22934412956238
# Training Loss : 106.83895111083984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.736122131347656
# Eval_StdReturn : 2.950385570526123
# Eval_MaxReturn : 52.917877197265625
# Eval_MinReturn : 41.160125732421875
# Eval_AverageEpLen : 27.2972972972973
# Train_AverageReturn : 48.426815032958984
# Train_StdReturn : 3.2497060298919678
# Train_MaxReturn : 61.35641860961914
# Train_MinReturn : 41.601192474365234
# Train_AverageEpLen : 28.85014409221902
# Train_EnvstepsSoFar : 370945
# TimeSinceStart : 81.39973831176758
# Training Loss : 102.54181671142578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.210121154785156
# Eval_StdReturn : 3.084510087966919
# Eval_MaxReturn : 53.48766326904297
# Eval_MinReturn : 39.542144775390625
# Eval_AverageEpLen : 25.923076923076923
# Train_AverageReturn : 45.68724822998047
# Train_StdReturn : 2.9513089656829834
# Train_MaxReturn : 61.76653289794922
# Train_MinReturn : 39.68425750732422
# Train_AverageEpLen : 27.29972752043597
# Train_EnvstepsSoFar : 380964
# TimeSinceStart : 83.58797717094421
# Training Loss : 99.95033264160156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.742122650146484
# Eval_StdReturn : 3.7408652305603027
# Eval_MaxReturn : 59.35205078125
# Eval_MinReturn : 37.917762756347656
# Eval_AverageEpLen : 25.641025641025642
# Train_AverageReturn : 43.4793815612793
# Train_StdReturn : 2.9686241149902344
# Train_MaxReturn : 64.12741088867188
# Train_MinReturn : 38.15325164794922
# Train_AverageEpLen : 26.036363636363635
# Train_EnvstepsSoFar : 390988
# TimeSinceStart : 85.75123000144958
# Training Loss : 97.40449523925781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.07707595825195
# Eval_StdReturn : 2.0111284255981445
# Eval_MaxReturn : 47.696311950683594
# Eval_MinReturn : 37.95909118652344
# Eval_AverageEpLen : 24.682926829268293
# Train_AverageReturn : 42.367034912109375
# Train_StdReturn : 2.980046033859253
# Train_MaxReturn : 58.54449462890625
# Train_MinReturn : 37.746070861816406
# Train_AverageEpLen : 25.385786802030456
# Train_EnvstepsSoFar : 400990
# TimeSinceStart : 87.9497082233429
# Training Loss : 96.07937622070312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.431976318359375
# Eval_StdReturn : 2.731390953063965
# Eval_MaxReturn : 49.354610443115234
# Eval_MinReturn : 36.20639419555664
# Eval_AverageEpLen : 24.285714285714285
# Train_AverageReturn : 41.303306579589844
# Train_StdReturn : 2.84865403175354
# Train_MaxReturn : 60.87571716308594
# Train_MinReturn : 36.392730712890625
# Train_AverageEpLen : 24.77970297029703
# Train_EnvstepsSoFar : 411001
# TimeSinceStart : 90.17391014099121
# Training Loss : 95.1728286743164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.121673583984375
# Eval_StdReturn : 2.621063709259033
# Eval_MaxReturn : 49.19364547729492
# Eval_MinReturn : 36.430213928222656
# Eval_AverageEpLen : 24.166666666666668
# Train_AverageReturn : 40.69870376586914
# Train_StdReturn : 2.6835005283355713
# Train_MaxReturn : 57.50861358642578
# Train_MinReturn : 36.388668060302734
# Train_AverageEpLen : 24.459657701711492
# Train_EnvstepsSoFar : 421005
# TimeSinceStart : 92.3552770614624
# Training Loss : 94.42329406738281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 39.717342376708984
# Eval_StdReturn : 3.402864456176758
# Eval_MaxReturn : 55.01966094970703
# Eval_MinReturn : 35.966739654541016
# Eval_AverageEpLen : 23.928571428571427
# Train_AverageReturn : 40.32872009277344
# Train_StdReturn : 3.088176965713501
# Train_MaxReturn : 62.112640380859375
# Train_MinReturn : 36.010093688964844
# Train_AverageEpLen : 24.23728813559322
# Train_EnvstepsSoFar : 431015
# TimeSinceStart : 94.63040614128113
# Training Loss : 93.97370147705078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.844871520996094
# Eval_StdReturn : 3.375156879425049
# Eval_MaxReturn : 56.66028594970703
# Eval_MinReturn : 37.80623245239258
# Eval_AverageEpLen : 24.5609756097561
# Train_AverageReturn : 40.36037826538086
# Train_StdReturn : 3.083927869796753
# Train_MaxReturn : 61.51338195800781
# Train_MinReturn : 35.8949089050293
# Train_AverageEpLen : 24.26634382566586
# Train_EnvstepsSoFar : 441037
# TimeSinceStart : 97.03781318664551
# Training Loss : 93.91490173339844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.41664505004883
# Eval_StdReturn : 5.106456756591797
# Eval_MaxReturn : 58.8990478515625
# Eval_MinReturn : 36.037960052490234
# Eval_AverageEpLen : 24.30952380952381
# Train_AverageReturn : 39.95984649658203
# Train_StdReturn : 2.7974393367767334
# Train_MaxReturn : 51.64179992675781
# Train_MinReturn : 35.725929260253906
# Train_AverageEpLen : 24.06971153846154
# Train_EnvstepsSoFar : 451050
# TimeSinceStart : 99.3444082736969
# Training Loss : 93.27281188964844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 39.609039306640625
# Eval_StdReturn : 2.7148921489715576
# Eval_MaxReturn : 48.70907974243164
# Eval_MinReturn : 35.971778869628906
# Eval_AverageEpLen : 23.88095238095238
# Train_AverageReturn : 39.79343795776367
# Train_StdReturn : 2.946383237838745
# Train_MaxReturn : 54.406951904296875
# Train_MinReturn : 35.556854248046875
# Train_AverageEpLen : 23.99040767386091
# Train_EnvstepsSoFar : 461054
# TimeSinceStart : 101.55877923965454
# Training Loss : 93.02059936523438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.36428451538086
# Eval_StdReturn : 3.685519218444824
# Eval_MaxReturn : 49.78095626831055
# Eval_MinReturn : 35.969478607177734
# Eval_AverageEpLen : 24.829268292682926
# Train_AverageReturn : 40.48385238647461
# Train_StdReturn : 3.8209657669067383
# Train_MaxReturn : 58.85648727416992
# Train_MinReturn : 35.613311767578125
# Train_AverageEpLen : 24.355231143552313
# Train_EnvstepsSoFar : 471064
# TimeSinceStart : 103.78988313674927
# Training Loss : 94.63471221923828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.10317611694336
# Eval_StdReturn : 3.7569453716278076
# Eval_MaxReturn : 51.37718200683594
# Eval_MinReturn : 36.11967468261719
# Eval_AverageEpLen : 24.70731707317073
# Train_AverageReturn : 41.31056594848633
# Train_StdReturn : 4.3389482498168945
# Train_MaxReturn : 65.20458984375
# Train_MinReturn : 35.72758102416992
# Train_AverageEpLen : 24.777227722772277
# Train_EnvstepsSoFar : 481074
# TimeSinceStart : 105.96775913238525
# Training Loss : 94.83246612548828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.187042236328125
# Eval_StdReturn : 6.0908660888671875
# Eval_MaxReturn : 68.45745849609375
# Eval_MinReturn : 36.38874816894531
# Eval_AverageEpLen : 25.75
# Train_AverageReturn : 41.908203125
# Train_StdReturn : 4.942085266113281
# Train_MaxReturn : 62.35435104370117
# Train_MinReturn : 35.63149642944336
# Train_AverageEpLen : 25.082706766917294
# Train_EnvstepsSoFar : 491082
# TimeSinceStart : 108.15941309928894
# Training Loss : 96.38941192626953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.58123779296875
# Eval_StdReturn : 5.384498596191406
# Eval_MaxReturn : 62.9764518737793
# Eval_MinReturn : 36.314109802246094
# Eval_AverageEpLen : 26.025641025641026
# Train_AverageReturn : 42.87922668457031
# Train_StdReturn : 5.500891208648682
# Train_MaxReturn : 66.40641021728516
# Train_MinReturn : 35.74429702758789
# Train_AverageEpLen : 25.603580562659847
# Train_EnvstepsSoFar : 501093
# TimeSinceStart : 110.40428423881531
# Training Loss : 97.46514129638672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 46.23093795776367
# Eval_StdReturn : 8.05119800567627
# Eval_MaxReturn : 76.66093444824219
# Eval_MinReturn : 36.51237869262695
# Eval_AverageEpLen : 27.27027027027027
# Train_AverageReturn : 44.21906661987305
# Train_StdReturn : 6.453917026519775
# Train_MaxReturn : 70.17523193359375
# Train_MinReturn : 34.90864944458008
# Train_AverageEpLen : 26.31233595800525
# Train_EnvstepsSoFar : 511118
# TimeSinceStart : 112.73002505302429
# Training Loss : 99.31035614013672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 56.4779052734375
# Eval_StdReturn : 21.89800262451172
# Eval_MaxReturn : 150.2186737060547
# Eval_MinReturn : 36.563655853271484
# Eval_AverageEpLen : 32.70967741935484
# Train_AverageReturn : 47.700130462646484
# Train_StdReturn : 12.976253509521484
# Train_MaxReturn : 167.61705017089844
# Train_MinReturn : 34.668418884277344
# Train_AverageEpLen : 28.146067415730336
# Train_EnvstepsSoFar : 521138
# TimeSinceStart : 114.97263813018799
# Training Loss : 103.53516387939453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.09132385253906
# Eval_StdReturn : 46.128807067871094
# Eval_MaxReturn : 171.0152130126953
# Eval_MinReturn : 37.841461181640625
# Eval_AverageEpLen : 44.95652173913044
# Train_AverageReturn : 54.894798278808594
# Train_StdReturn : 22.27460289001465
# Train_MaxReturn : 174.0642852783203
# Train_MinReturn : 35.83250427246094
# Train_AverageEpLen : 31.961661341853034
# Train_EnvstepsSoFar : 531142
# TimeSinceStart : 117.21675324440002
# Training Loss : 109.72563171386719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.42313385009766
# Eval_StdReturn : 25.954755783081055
# Eval_MaxReturn : 153.8753204345703
# Eval_MinReturn : 39.875244140625
# Eval_AverageEpLen : 37.285714285714285
# Train_AverageReturn : 65.06401824951172
# Train_StdReturn : 32.207027435302734
# Train_MaxReturn : 173.1787567138672
# Train_MinReturn : 35.934444427490234
# Train_AverageEpLen : 37.38805970149254
# Train_EnvstepsSoFar : 541162
# TimeSinceStart : 119.43904614448547
# Training Loss : 116.55925750732422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.7916259765625
# Eval_StdReturn : 35.54561996459961
# Eval_MaxReturn : 165.03150939941406
# Eval_MinReturn : 38.005638122558594
# Eval_AverageEpLen : 51.2
# Train_AverageReturn : 63.40953063964844
# Train_StdReturn : 25.666141510009766
# Train_MaxReturn : 170.98219299316406
# Train_MinReturn : 36.08388137817383
# Train_AverageEpLen : 36.565693430656935
# Train_EnvstepsSoFar : 551181
# TimeSinceStart : 121.9208312034607
# Training Loss : 115.726806640625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.53302001953125
# Eval_StdReturn : 23.459238052368164
# Eval_MaxReturn : 146.32278442382812
# Eval_MinReturn : 40.14385223388672
# Eval_AverageEpLen : 50.23809523809524
# Train_AverageReturn : 96.89976501464844
# Train_StdReturn : 36.63401794433594
# Train_MaxReturn : 174.91226196289062
# Train_MinReturn : 39.22539520263672
# Train_AverageEpLen : 55.57222222222222
# Train_EnvstepsSoFar : 561184
# TimeSinceStart : 124.88249611854553
# Training Loss : 128.87924194335938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.64167785644531
# Eval_StdReturn : 10.117167472839355
# Eval_MaxReturn : 90.13370513916016
# Eval_MinReturn : 52.5848274230957
# Eval_AverageEpLen : 41.44
# Train_AverageReturn : 80.84149932861328
# Train_StdReturn : 19.06084442138672
# Train_MaxReturn : 165.8171844482422
# Train_MinReturn : 36.34906005859375
# Train_AverageEpLen : 48.27884615384615
# Train_EnvstepsSoFar : 571226
# TimeSinceStart : 127.43793725967407
# Training Loss : 124.28082275390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.475337982177734
# Eval_StdReturn : 7.637240409851074
# Eval_MaxReturn : 79.67247772216797
# Eval_MinReturn : 49.61434555053711
# Eval_AverageEpLen : 37.48148148148148
# Train_AverageReturn : 69.9540786743164
# Train_StdReturn : 13.098200798034668
# Train_MaxReturn : 128.2521209716797
# Train_MinReturn : 45.981414794921875
# Train_AverageEpLen : 42.20675105485232
# Train_EnvstepsSoFar : 581229
# TimeSinceStart : 130.08027911186218
# Training Loss : 119.52716827392578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.89257049560547
# Eval_StdReturn : 9.087445259094238
# Eval_MaxReturn : 80.56993865966797
# Eval_MinReturn : 47.19700622558594
# Eval_AverageEpLen : 36.67857142857143
# Train_AverageReturn : 61.573524475097656
# Train_StdReturn : 9.626983642578125
# Train_MaxReturn : 97.92164611816406
# Train_MinReturn : 43.53481674194336
# Train_AverageEpLen : 37.546816479400746
# Train_EnvstepsSoFar : 591254
# TimeSinceStart : 132.61261534690857
# Training Loss : 114.66824340820312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 67.20999145507812
# Eval_StdReturn : 7.673730850219727
# Eval_MaxReturn : 80.01300811767578
# Eval_MinReturn : 53.51938247680664
# Eval_AverageEpLen : 40.64
# Train_AverageReturn : 60.11735916137695
# Train_StdReturn : 8.074010848999023
# Train_MaxReturn : 88.80182647705078
# Train_MinReturn : 43.87327575683594
# Train_AverageEpLen : 36.786764705882355
# Train_EnvstepsSoFar : 601260
# TimeSinceStart : 134.93602013587952
# Training Loss : 113.1473617553711
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.54765319824219
# Eval_StdReturn : 8.972426414489746
# Eval_MaxReturn : 79.8739013671875
# Eval_MinReturn : 47.40162658691406
# Eval_AverageEpLen : 39.03846153846154
# ...
# Train_AverageEpLen : 56.70056497175141
# Train_EnvstepsSoFar : 792318
# TimeSinceStart : 179.4491879940033
# Training Loss : 117.22906494140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 107.75789642333984
# Eval_StdReturn : 6.55460262298584
# Eval_MaxReturn : 120.0266342163086
# Eval_MinReturn : 96.68754577636719
# Eval_AverageEpLen : 68.8
# Train_AverageReturn : 96.46520233154297
# Train_StdReturn : 2.947977066040039
# Train_MaxReturn : 104.93453979492188
# Train_MinReturn : 89.59354400634766
# Train_AverageEpLen : 61.864197530864196
# Train_EnvstepsSoFar : 802340
# TimeSinceStart : 181.84492707252502
# Training Loss : 117.93508911132812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.6789321899414
# Eval_StdReturn : 6.484145164489746
# Eval_MaxReturn : 128.9244384765625
# Eval_MinReturn : 104.28207397460938
# Eval_AverageEpLen : 72.0
# Train_AverageReturn : 106.96908569335938
# Train_StdReturn : 5.668711185455322
# Train_MaxReturn : 122.52242279052734
# Train_MinReturn : 96.95502471923828
# Train_AverageEpLen : 68.39455782312925
# Train_EnvstepsSoFar : 812394
# TimeSinceStart : 184.3313810825348
# Training Loss : 120.07740783691406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.92259216308594
# Eval_StdReturn : 4.955950736999512
# Eval_MaxReturn : 121.63538360595703
# Eval_MinReturn : 105.35147094726562
# Eval_AverageEpLen : 71.5
# Train_AverageReturn : 112.7361068725586
# Train_StdReturn : 7.203312873840332
# Train_MaxReturn : 132.09335327148438
# Train_MinReturn : 101.03461456298828
# Train_AverageEpLen : 71.47142857142858
# Train_EnvstepsSoFar : 822400
# TimeSinceStart : 187.2964882850647
# Training Loss : 120.65592193603516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10065 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.16984558105469
# Eval_StdReturn : 5.598596096038818
# Eval_MaxReturn : 123.24134826660156
# Eval_MinReturn : 104.23444366455078
# Eval_AverageEpLen : 71.2
# Train_AverageReturn : 111.8683090209961
# Train_StdReturn : 7.302209377288818
# Train_MaxReturn : 127.27357482910156
# Train_MinReturn : 99.42439270019531
# Train_AverageEpLen : 70.88028169014085
# Train_EnvstepsSoFar : 832465
# TimeSinceStart : 189.94100093841553
# Training Loss : 120.11833953857422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.7928695678711
# Eval_StdReturn : 5.386040687561035
# Eval_MaxReturn : 121.33775329589844
# Eval_MinReturn : 104.03412628173828
# Eval_AverageEpLen : 70.6
# Train_AverageReturn : 114.67127990722656
# Train_StdReturn : 7.1945109367370605
# Train_MaxReturn : 131.8895263671875
# Train_MinReturn : 99.79208374023438
# Train_AverageEpLen : 72.54347826086956
# Train_EnvstepsSoFar : 842476
# TimeSinceStart : 192.58765506744385
# Training Loss : 119.99815368652344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 107.77696990966797
# Eval_StdReturn : 4.22379732131958
# Eval_MaxReturn : 118.01636505126953
# Eval_MinReturn : 101.62232971191406
# Eval_AverageEpLen : 69.0
# Train_AverageReturn : 111.06782531738281
# Train_StdReturn : 6.5162272453308105
# Train_MaxReturn : 125.6704330444336
# Train_MinReturn : 99.321533203125
# Train_AverageEpLen : 70.6830985915493
# Train_EnvstepsSoFar : 852513
# TimeSinceStart : 195.01585602760315
# Training Loss : 119.63616943359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.98741149902344
# Eval_StdReturn : 4.130033493041992
# Eval_MaxReturn : 104.91670227050781
# Eval_MinReturn : 89.46857452392578
# Eval_AverageEpLen : 63.0625
# Train_AverageReturn : 105.59654998779297
# Train_StdReturn : 5.932904243469238
# Train_MaxReturn : 124.76006317138672
# Train_MinReturn : 95.73668670654297
# Train_AverageEpLen : 67.63513513513513
# Train_EnvstepsSoFar : 862523
# TimeSinceStart : 197.3697588443756
# Training Loss : 119.20367431640625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.70729064941406
# Eval_StdReturn : 2.8785452842712402
# Eval_MaxReturn : 102.75593566894531
# Eval_MinReturn : 91.22405242919922
# Eval_AverageEpLen : 61.588235294117645
# Train_AverageReturn : 99.6071548461914
# Train_StdReturn : 4.282199859619141
# Train_MaxReturn : 113.60611724853516
# Train_MinReturn : 88.4933090209961
# Train_AverageEpLen : 64.10897435897436
# Train_EnvstepsSoFar : 872524
# TimeSinceStart : 199.81545114517212
# Training Loss : 118.49618530273438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 90.45924377441406
# Eval_StdReturn : 3.9541819095611572
# Eval_MaxReturn : 96.71577453613281
# Eval_MinReturn : 82.50786590576172
# Eval_AverageEpLen : 58.111111111111114
# Train_AverageReturn : 95.28568267822266
# Train_StdReturn : 3.2212002277374268
# Train_MaxReturn : 106.611572265625
# Train_MinReturn : 85.32034301757812
# Train_AverageEpLen : 61.26829268292683
# Train_EnvstepsSoFar : 882572
# TimeSinceStart : 202.47571516036987
# Training Loss : 117.0560531616211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 81.64376831054688
# Eval_StdReturn : 2.964230537414551
# Eval_MaxReturn : 85.88475799560547
# Eval_MinReturn : 76.26312255859375
# Eval_AverageEpLen : 51.9
# Train_AverageReturn : 89.60794830322266
# Train_StdReturn : 3.2015390396118164
# Train_MaxReturn : 98.26033020019531
# Train_MinReturn : 79.63253784179688
# Train_AverageEpLen : 57.36571428571428
# Train_EnvstepsSoFar : 892611
# TimeSinceStart : 208.38868713378906
# Training Loss : 115.8097152709961
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.09577941894531
# Eval_StdReturn : 2.2789409160614014
# Eval_MaxReturn : 81.4904556274414
# Eval_MinReturn : 72.830322265625
# Eval_AverageEpLen : 48.904761904761905
# Train_AverageReturn : 82.83541870117188
# Train_StdReturn : 3.291987180709839
# Train_MaxReturn : 90.7681655883789
# Train_MinReturn : 74.7401123046875
# Train_AverageEpLen : 52.8
# Train_EnvstepsSoFar : 902643
# TimeSinceStart : 212.0662660598755
# Training Loss : 114.74125671386719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.261474609375
# Eval_StdReturn : 3.723116636276245
# Eval_MaxReturn : 82.53211212158203
# Eval_MinReturn : 70.59010314941406
# Eval_AverageEpLen : 47.904761904761905
# Train_AverageReturn : 77.73880767822266
# Train_StdReturn : 3.13905930519104
# Train_MaxReturn : 86.39450073242188
# Train_MinReturn : 66.63446044921875
# Train_AverageEpLen : 49.423645320197046
# Train_EnvstepsSoFar : 912676
# TimeSinceStart : 215.16828322410583
# Training Loss : 113.0440902709961
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.57939147949219
# Eval_StdReturn : 3.268202781677246
# Eval_MaxReturn : 76.70556640625
# Eval_MinReturn : 61.9733772277832
# Eval_AverageEpLen : 44.130434782608695
# Train_AverageReturn : 74.47872924804688
# Train_StdReturn : 3.170696496963501
# Train_MaxReturn : 83.57234954833984
# Train_MinReturn : 62.546630859375
# Train_AverageEpLen : 47.367924528301884
# Train_EnvstepsSoFar : 922718
# TimeSinceStart : 219.06032991409302
# Training Loss : 111.25955963134766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.73609161376953
# Eval_StdReturn : 2.853085517883301
# Eval_MaxReturn : 69.70220184326172
# Eval_MinReturn : 57.17048645019531
# Eval_AverageEpLen : 39.88461538461539
# Train_AverageReturn : 69.20799255371094
# Train_StdReturn : 3.0761730670928955
# Train_MaxReturn : 75.78768157958984
# Train_MinReturn : 59.17676544189453
# Train_AverageEpLen : 43.916666666666664
# Train_EnvstepsSoFar : 932731
# TimeSinceStart : 222.5159411430359
# Training Loss : 109.25102233886719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.197723388671875
# Eval_StdReturn : 3.018292188644409
# Eval_MaxReturn : 59.733360290527344
# Eval_MinReturn : 47.56086730957031
# Eval_AverageEpLen : 34.93103448275862
# Train_AverageReturn : 61.8624267578125
# Train_StdReturn : 2.942702531814575
# Train_MaxReturn : 70.30451965332031
# Train_MinReturn : 52.69879913330078
# Train_AverageEpLen : 39.21484375
# Train_EnvstepsSoFar : 942770
# TimeSinceStart : 225.30105328559875
# Training Loss : 105.40425109863281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.66934585571289
# Eval_StdReturn : 2.801759958267212
# Eval_MaxReturn : 56.03240966796875
# Eval_MinReturn : 44.63491439819336
# Eval_AverageEpLen : 32.03125
# Train_AverageReturn : 55.7925910949707
# Train_StdReturn : 2.6347498893737793
# Train_MaxReturn : 62.44256591796875
# Train_MinReturn : 49.4442024230957
# Train_AverageEpLen : 35.313380281690144
# Train_EnvstepsSoFar : 952799
# TimeSinceStart : 228.096360206604
# Training Loss : 102.26594543457031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.182960510253906
# Eval_StdReturn : 1.7786598205566406
# Eval_MaxReturn : 53.20880126953125
# Eval_MinReturn : 44.25493240356445
# Eval_AverageEpLen : 29.764705882352942
# Train_AverageReturn : 50.67007064819336
# Train_StdReturn : 2.261898994445801
# Train_MaxReturn : 56.61140441894531
# Train_MinReturn : 44.48469924926758
# Train_AverageEpLen : 32.04472843450479
# Train_EnvstepsSoFar : 962829
# TimeSinceStart : 231.08134508132935
# Training Loss : 97.75990295410156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 44.68482971191406
# Eval_StdReturn : 1.7773412466049194
# Eval_MaxReturn : 48.73183059692383
# Eval_MinReturn : 41.31154251098633
# Eval_AverageEpLen : 28.25
# Train_AverageReturn : 47.02214431762695
# Train_StdReturn : 1.9978324174880981
# Train_MaxReturn : 52.21833038330078
# Train_MinReturn : 41.778202056884766
# Train_AverageEpLen : 29.706231454005934
# Train_EnvstepsSoFar : 972840
# TimeSinceStart : 234.11932802200317
# Training Loss : 95.33911895751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.89086151123047
# Eval_StdReturn : 1.2777299880981445
# Eval_MaxReturn : 45.73072052001953
# Eval_MinReturn : 39.86309814453125
# Eval_AverageEpLen : 27.216216216216218
# Train_AverageReturn : 44.23334884643555
# Train_StdReturn : 1.6768951416015625
# Train_MaxReturn : 50.123531341552734
# Train_MinReturn : 39.920066833496094
# Train_AverageEpLen : 27.972067039106147
# Train_EnvstepsSoFar : 982854
# TimeSinceStart : 237.29326725006104
# Training Loss : 92.60443115234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.4785270690918
# Eval_StdReturn : 1.5013395547866821
# Eval_MaxReturn : 43.79368591308594
# Eval_MinReturn : 38.006431579589844
# Eval_AverageEpLen : 26.31578947368421
# Train_AverageReturn : 42.749000549316406
# Train_StdReturn : 1.4970755577087402
# Train_MaxReturn : 46.985774993896484
# Train_MinReturn : 38.21269989013672
# Train_AverageEpLen : 27.048648648648648
# Train_EnvstepsSoFar : 992862
# TimeSinceStart : 242.0984182357788
# Training Loss : 90.45465087890625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.2862548828125
# Eval_StdReturn : 1.2788403034210205
# Eval_MaxReturn : 42.71038055419922
# Eval_MinReturn : 36.4423828125
# Eval_AverageEpLen : 25.55
# Train_AverageReturn : 41.44269943237305
# Train_StdReturn : 1.3438466787338257
# Train_MaxReturn : 45.76610565185547
# Train_MinReturn : 37.79916000366211
# Train_AverageEpLen : 26.27296587926509
# Train_EnvstepsSoFar : 1002872
# TimeSinceStart : 246.13666915893555
# Training Loss : 89.02838134765625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/Hopper/return_to_go/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.02117919921875
# Eval_StdReturn : 61.76866912841797
# Eval_MaxReturn : 264.6962890625
# Eval_MinReturn : 13.24337387084961
# Eval_AverageEpLen : 63.76470588235294
# Train_AverageReturn : 9.695383071899414
# Train_StdReturn : 5.122409820556641
# Train_MaxReturn : 75.24513244628906
# Train_MinReturn : 2.3481526374816895
# Train_AverageEpLen : 13.217965653896961
# Train_EnvstepsSoFar : 10006
# TimeSinceStart : 3.9211807250976562
# Training Loss : 17.84083366394043
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 76.61843872070312
# Eval_StdReturn : 12.733243942260742
# Eval_MaxReturn : 119.46549987792969
# Eval_MinReturn : 61.55160903930664
# Eval_AverageEpLen : 47.27272727272727
# Train_AverageReturn : 88.39493560791016
# Train_StdReturn : 53.162811279296875
# Train_MaxReturn : 263.3277893066406
# Train_MinReturn : 7.667899131774902
# Train_AverageEpLen : 55.833333333333336
# Train_EnvstepsSoFar : 20056
# TimeSinceStart : 6.872038841247559
# Training Loss : 103.3144302368164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.27686309814453
# Eval_StdReturn : 17.787460327148438
# Eval_MaxReturn : 131.58761596679688
# Eval_MinReturn : 60.38636779785156
# Eval_AverageEpLen : 49.666666666666664
# Train_AverageReturn : 80.41482543945312
# Train_StdReturn : 17.53108024597168
# Train_MaxReturn : 138.30691528320312
# Train_MinReturn : 54.62295150756836
# Train_AverageEpLen : 48.93658536585366
# Train_EnvstepsSoFar : 30088
# TimeSinceStart : 10.673054933547974
# Training Loss : 98.62165832519531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.23504638671875
# Eval_StdReturn : 52.174659729003906
# Eval_MaxReturn : 214.79837036132812
# Eval_MinReturn : 71.78096771240234
# Eval_AverageEpLen : 65.625
# Train_AverageReturn : 85.04756927490234
# Train_StdReturn : 17.726408004760742
# Train_MaxReturn : 143.41488647460938
# Train_MinReturn : 52.804100036621094
# Train_AverageEpLen : 49.554455445544555
# Train_EnvstepsSoFar : 40098
# TimeSinceStart : 13.717008113861084
# Training Loss : 104.50763702392578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 207.13978576660156
# Eval_StdReturn : 30.806659698486328
# Eval_MaxReturn : 237.1614227294922
# Eval_MinReturn : 131.21775817871094
# Eval_AverageEpLen : 98.0909090909091
# Train_AverageReturn : 121.41670227050781
# Train_StdReturn : 38.74394989013672
# Train_MaxReturn : 236.80674743652344
# Train_MinReturn : 69.09416198730469
# Train_AverageEpLen : 63.7515923566879
# Train_EnvstepsSoFar : 50107
# TimeSinceStart : 17.497297048568726
# Training Loss : 127.5750732421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.05843353271484
# Eval_StdReturn : 35.91088104248047
# Eval_MaxReturn : 210.52438354492188
# Eval_MinReturn : 72.82560729980469
# Eval_AverageEpLen : 66.73333333333333
# Train_AverageReturn : 198.43368530273438
# Train_StdReturn : 37.206172943115234
# Train_MaxReturn : 246.8400421142578
# Train_MinReturn : 63.11576461791992
# Train_AverageEpLen : 91.10909090909091
# Train_EnvstepsSoFar : 60129
# TimeSinceStart : 20.530694723129272
# Training Loss : 159.6915740966797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.96212005615234
# Eval_StdReturn : 39.633487701416016
# Eval_MaxReturn : 211.23968505859375
# Eval_MinReturn : 42.09701156616211
# Eval_AverageEpLen : 58.666666666666664
# Train_AverageReturn : 126.33770751953125
# Train_StdReturn : 41.53818893432617
# Train_MaxReturn : 218.86216735839844
# Train_MinReturn : 44.170143127441406
# Train_AverageEpLen : 66.0
# Train_EnvstepsSoFar : 70161
# TimeSinceStart : 23.646661043167114
# Training Loss : 129.6299591064453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10093 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 211.4407196044922
# Eval_StdReturn : 9.019519805908203
# Eval_MaxReturn : 228.84368896484375
# Eval_MinReturn : 199.71939086914062
# Eval_AverageEpLen : 95.63636363636364
# Train_AverageReturn : 109.3628921508789
# Train_StdReturn : 46.828712463378906
# Train_MaxReturn : 235.9429931640625
# Train_MinReturn : 31.183862686157227
# Train_AverageEpLen : 58.68023255813954
# Train_EnvstepsSoFar : 80254
# TimeSinceStart : 26.62422275543213
# Training Loss : 122.41712951660156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 208.17613220214844
# Eval_StdReturn : 18.116979598999023
# Eval_MaxReturn : 227.57083129882812
# Eval_MinReturn : 157.53024291992188
# Eval_AverageEpLen : 93.81818181818181
# Train_AverageReturn : 198.63511657714844
# Train_StdReturn : 30.49596405029297
# Train_MaxReturn : 233.70245361328125
# Train_MinReturn : 60.96944808959961
# Train_AverageEpLen : 90.9090909090909
# Train_EnvstepsSoFar : 90254
# TimeSinceStart : 29.482715129852295
# Training Loss : 159.75372314453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 183.05955505371094
# Eval_StdReturn : 28.04109001159668
# Eval_MaxReturn : 219.7987518310547
# Eval_MinReturn : 131.83541870117188
# Eval_AverageEpLen : 85.66666666666667
# Train_AverageReturn : 206.51234436035156
# Train_StdReturn : 21.45115089416504
# Train_MaxReturn : 228.4528045654297
# Train_MinReturn : 112.8465576171875
# Train_AverageEpLen : 93.18518518518519
# Train_EnvstepsSoFar : 100318
# TimeSinceStart : 32.436655044555664
# Training Loss : 162.13418579101562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.17738342285156
# Eval_StdReturn : 22.435693740844727
# Eval_MaxReturn : 224.64393615722656
# Eval_MinReturn : 139.07078552246094
# Eval_AverageEpLen : 82.3076923076923
# Train_AverageReturn : 182.63807678222656
# Train_StdReturn : 30.23134994506836
# Train_MaxReturn : 225.66488647460938
# Train_MinReturn : 94.17265319824219
# Train_AverageEpLen : 84.97457627118644
# Train_EnvstepsSoFar : 110345
# TimeSinceStart : 35.300517082214355
# Training Loss : 153.95924377441406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 156.01524353027344
# Eval_StdReturn : 30.15694808959961
# Eval_MaxReturn : 215.00381469726562
# Eval_MinReturn : 94.86861419677734
# Eval_AverageEpLen : 76.64285714285714
# Train_AverageReturn : 158.2279815673828
# Train_StdReturn : 31.466758728027344
# Train_MaxReturn : 226.31307983398438
# Train_MinReturn : 91.26165008544922
# Train_AverageEpLen : 76.73282442748092
# Train_EnvstepsSoFar : 120397
# TimeSinceStart : 38.12777590751648
# Training Loss : 144.03163146972656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 199.27545166015625
# Eval_StdReturn : 23.372407913208008
# Eval_MaxReturn : 223.25985717773438
# Eval_MinReturn : 140.4039764404297
# Eval_AverageEpLen : 90.5
# Train_AverageReturn : 163.08221435546875
# Train_StdReturn : 30.780630111694336
# Train_MaxReturn : 221.95733642578125
# Train_MinReturn : 94.8011474609375
# Train_AverageEpLen : 78.4140625
# Train_EnvstepsSoFar : 130434
# TimeSinceStart : 40.76330494880676
# Training Loss : 145.92575073242188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 216.75242614746094
# Eval_StdReturn : 5.638681888580322
# Eval_MaxReturn : 222.7738037109375
# Eval_MinReturn : 206.45742797851562
# Eval_AverageEpLen : 96.9090909090909
# Train_AverageReturn : 191.73484802246094
# Train_StdReturn : 25.962785720825195
# Train_MaxReturn : 230.04603576660156
# Train_MinReturn : 118.07830810546875
# Train_AverageEpLen : 88.35087719298245
# Train_EnvstepsSoFar : 140506
# TimeSinceStart : 43.466618061065674
# Training Loss : 157.1990509033203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 211.28875732421875
# Eval_StdReturn : 6.010679721832275
# Eval_MaxReturn : 218.78416442871094
# Eval_MinReturn : 196.66259765625
# Eval_AverageEpLen : 96.36363636363636
# Train_AverageReturn : 214.76141357421875
# Train_StdReturn : 9.454249382019043
# Train_MaxReturn : 229.0226287841797
# Train_MinReturn : 172.46719360351562
# Train_AverageEpLen : 96.34615384615384
# Train_EnvstepsSoFar : 150526
# TimeSinceStart : 46.56290888786316
# Training Loss : 163.60379028320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.1044464111328
# Eval_StdReturn : 45.3964729309082
# Eval_MaxReturn : 210.64634704589844
# Eval_MinReturn : 79.64820861816406
# Eval_AverageEpLen : 83.58333333333333
# Train_AverageReturn : 207.27479553222656
# Train_StdReturn : 7.259047985076904
# Train_MaxReturn : 222.8562774658203
# Train_MinReturn : 192.15966796875
# Train_AverageEpLen : 94.45283018867924
# Train_EnvstepsSoFar : 160538
# TimeSinceStart : 49.64099979400635
# Training Loss : 161.30624389648438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.72457885742188
# Eval_StdReturn : 40.081058502197266
# Eval_MaxReturn : 191.06910705566406
# Eval_MinReturn : 47.188228607177734
# Eval_AverageEpLen : 60.88235294117647
# Train_AverageReturn : 153.85435485839844
# Train_StdReturn : 44.37215042114258
# Train_MaxReturn : 212.44293212890625
# Train_MinReturn : 39.74650192260742
# Train_AverageEpLen : 76.37121212121212
# Train_EnvstepsSoFar : 170619
# TimeSinceStart : 52.545021772384644
# Training Loss : 140.59915161132812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.225830078125
# Eval_StdReturn : 21.290054321289062
# Eval_MaxReturn : 195.47349548339844
# Eval_MinReturn : 124.60720825195312
# Eval_AverageEpLen : 86.83333333333333
# Train_AverageReturn : 116.09605407714844
# Train_StdReturn : 43.102439880371094
# Train_MaxReturn : 199.7840576171875
# Train_MinReturn : 35.843624114990234
# Train_AverageEpLen : 62.422360248447205
# Train_EnvstepsSoFar : 180669
# TimeSinceStart : 55.39021396636963
# Training Loss : 122.2961654663086
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.07542419433594
# Eval_StdReturn : 5.580333709716797
# Eval_MaxReturn : 199.7461700439453
# Eval_MinReturn : 180.4686279296875
# Eval_AverageEpLen : 91.63636363636364
# Train_AverageReturn : 142.31961059570312
# Train_StdReturn : 54.591514587402344
# Train_MaxReturn : 202.8048858642578
# Train_MinReturn : 21.523414611816406
# Train_AverageEpLen : 72.14388489208633
# Train_EnvstepsSoFar : 190697
# TimeSinceStart : 57.87505388259888
# Training Loss : 135.79751586914062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 193.8572235107422
# Eval_StdReturn : 9.127514839172363
# Eval_MaxReturn : 215.51690673828125
# Eval_MinReturn : 180.52992248535156
# Eval_AverageEpLen : 91.36363636363636
# Train_AverageReturn : 187.6732177734375
# Train_StdReturn : 19.26500129699707
# Train_MaxReturn : 252.76904296875
# Train_MinReturn : 58.92824172973633
# Train_AverageEpLen : 90.51351351351352
# Train_EnvstepsSoFar : 200744
# TimeSinceStart : 60.16413474082947
# Training Loss : 148.00820922851562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.75457763671875
# Eval_StdReturn : 22.84505844116211
# Eval_MaxReturn : 247.109130859375
# Eval_MinReturn : 180.0208282470703
# Eval_AverageEpLen : 99.0909090909091
# Train_AverageReturn : 190.0537872314453
# Train_StdReturn : 22.709651947021484
# Train_MaxReturn : 298.2770080566406
# Train_MinReturn : 29.05083465576172
# Train_AverageEpLen : 91.77981651376147
# Train_EnvstepsSoFar : 210748
# TimeSinceStart : 63.29285502433777
# Training Loss : 148.37847900390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.62844848632812
# Eval_StdReturn : 96.67829895019531
# Eval_MaxReturn : 268.7952880859375
# Eval_MinReturn : -0.32313209772109985
# Eval_AverageEpLen : 84.38461538461539
# Train_AverageReturn : 202.13888549804688
# Train_StdReturn : 42.10993576049805
# Train_MaxReturn : 327.12298583984375
# Train_MinReturn : 0.0687950849533081
# Train_AverageEpLen : 97.29126213592232
# Train_EnvstepsSoFar : 220769
# TimeSinceStart : 66.06217789649963
# Training Loss : 151.94671630859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.6293487548828
# Eval_StdReturn : 39.0777587890625
# Eval_MaxReturn : 254.0356903076172
# Eval_MinReturn : 86.00482177734375
# Eval_AverageEpLen : 90.0
# Train_AverageReturn : 196.8726043701172
# Train_StdReturn : 33.07664489746094
# Train_MaxReturn : 308.07330322265625
# Train_MinReturn : 0.11048382520675659
# Train_AverageEpLen : 95.37142857142857
# Train_EnvstepsSoFar : 230783
# TimeSinceStart : 68.54250693321228
# Training Loss : 149.4088592529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.82705688476562
# Eval_StdReturn : 13.635950088500977
# Eval_MaxReturn : 176.2388458251953
# Eval_MinReturn : 132.46234130859375
# Eval_AverageEpLen : 77.6923076923077
# Train_AverageReturn : 174.2200469970703
# Train_StdReturn : 51.421546936035156
# Train_MaxReturn : 369.03265380859375
# Train_MinReturn : -0.018314659595489502
# Train_AverageEpLen : 85.76923076923077
# Train_EnvstepsSoFar : 240818
# TimeSinceStart : 71.56748485565186
# Training Loss : 143.80816650390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10065 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.91128540039062
# Eval_StdReturn : 48.65723419189453
# Eval_MaxReturn : 179.8603057861328
# Eval_MinReturn : 0.1371874213218689
# Eval_AverageEpLen : 65.3125
# Train_AverageReturn : 146.31739807128906
# Train_StdReturn : 32.233070373535156
# Train_MaxReturn : 234.50082397460938
# Train_MinReturn : 0.40300536155700684
# Train_AverageEpLen : 74.55555555555556
# Train_EnvstepsSoFar : 250883
# TimeSinceStart : 74.51412987709045
# Training Loss : 133.85716247558594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 139.053466796875
# Eval_StdReturn : 15.8247709274292
# Eval_MaxReturn : 167.32315063476562
# Eval_MinReturn : 105.68016815185547
# Eval_AverageEpLen : 71.33333333333333
# Train_AverageReturn : 133.4028778076172
# Train_StdReturn : 29.128280639648438
# Train_MaxReturn : 184.42694091796875
# Train_MinReturn : -0.15459227561950684
# Train_AverageEpLen : 69.61805555555556
# Train_EnvstepsSoFar : 260908
# TimeSinceStart : 77.78344583511353
# Training Loss : 128.70892333984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.20057678222656
# Eval_StdReturn : 16.114593505859375
# Eval_MaxReturn : 170.84478759765625
# Eval_MinReturn : 106.59149932861328
# Eval_AverageEpLen : 70.53333333333333
# Train_AverageReturn : 132.5667266845703
# Train_StdReturn : 27.872533798217773
# Train_MaxReturn : 177.84906005859375
# Train_MinReturn : -0.6050738096237183
# Train_AverageEpLen : 68.79452054794521
# Train_EnvstepsSoFar : 270952
# TimeSinceStart : 80.39246582984924
# Training Loss : 128.13539123535156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.66948699951172
# Eval_StdReturn : 12.864269256591797
# Eval_MaxReturn : 149.06228637695312
# Eval_MinReturn : 100.47770690917969
# Eval_AverageEpLen : 67.73333333333333
# Train_AverageReturn : 127.50578308105469
# Train_StdReturn : 25.716569900512695
# Train_MaxReturn : 178.6959991455078
# Train_MinReturn : 1.420120120048523
# Train_AverageEpLen : 67.02666666666667
# Train_EnvstepsSoFar : 281006
# TimeSinceStart : 82.8861129283905
# Training Loss : 124.96408081054688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 141.6534423828125
# Eval_StdReturn : 18.346576690673828
# Eval_MaxReturn : 176.6520538330078
# Eval_MinReturn : 116.43885803222656
# Eval_AverageEpLen : 73.42857142857143
# Train_AverageReturn : 124.06842041015625
# Train_StdReturn : 29.502639770507812
# Train_MaxReturn : 172.809326171875
# Train_MinReturn : -0.21931684017181396
# Train_AverageEpLen : 66.3112582781457
# Train_EnvstepsSoFar : 291019
# TimeSinceStart : 86.1523950099945
# Training Loss : 122.88632202148438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 129.39794921875
# Eval_StdReturn : 31.427778244018555
# Eval_MaxReturn : 209.8144989013672
# Eval_MinReturn : 87.68351745605469
# Eval_AverageEpLen : 69.06666666666666
# Train_AverageReturn : 126.07768249511719
# Train_StdReturn : 25.770212173461914
# Train_MaxReturn : 204.67721557617188
# Train_MinReturn : 0.48568129539489746
# Train_AverageEpLen : 67.16778523489933
# Train_EnvstepsSoFar : 301027
# TimeSinceStart : 89.57928681373596
# Training Loss : 123.38182067871094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 151.58734130859375
# Eval_StdReturn : 48.49177551269531
# Eval_MaxReturn : 195.1812286376953
# Eval_MinReturn : 0.9150201678276062
# Eval_AverageEpLen : 80.46153846153847
# Train_AverageReturn : 136.89990234375
# Train_StdReturn : 33.27465057373047
# Train_MaxReturn : 237.36709594726562
# Train_MinReturn : -0.3567601442337036
# Train_AverageEpLen : 71.92857142857143
# Train_EnvstepsSoFar : 311097
# TimeSinceStart : 92.42628192901611
# Training Loss : 126.81149291992188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.32171630859375
# Eval_StdReturn : 23.936634063720703
# Eval_MaxReturn : 203.8185272216797
# Eval_MinReturn : 120.59839630126953
# Eval_AverageEpLen : 89.08333333333333
# Train_AverageReturn : 157.43905639648438
# Train_StdReturn : 31.393564224243164
# Train_MaxReturn : 232.37513732910156
# Train_MinReturn : 79.51133728027344
# Train_AverageEpLen : 81.53658536585365
# Train_EnvstepsSoFar : 321126
# TimeSinceStart : 95.35538506507874
# Training Loss : 133.20144653320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10094 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.04307556152344
# Eval_StdReturn : 17.942800521850586
# Eval_MaxReturn : 211.51171875
# Eval_MinReturn : 144.0956573486328
# Eval_AverageEpLen : 94.0
# Train_AverageReturn : 175.8031768798828
# Train_StdReturn : 26.960105895996094
# Train_MaxReturn : 232.8383331298828
# Train_MinReturn : 79.05250549316406
# Train_AverageEpLen : 89.32743362831859
# Train_EnvstepsSoFar : 331220
# TimeSinceStart : 98.5342628955841
# Training Loss : 138.64389038085938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.88575744628906
# Eval_StdReturn : 10.072789192199707
# Eval_MaxReturn : 213.7352294921875
# Eval_MinReturn : 178.81431579589844
# Eval_AverageEpLen : 97.63636363636364
# Train_AverageReturn : 188.11502075195312
# Train_StdReturn : 16.25332260131836
# Train_MaxReturn : 278.7748718261719
# Train_MinReturn : 133.77662658691406
# Train_AverageEpLen : 94.66037735849056
# Train_EnvstepsSoFar : 341254
# TimeSinceStart : 100.94724082946777
# Training Loss : 141.51512145996094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10090 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.45127868652344
# Eval_StdReturn : 21.785940170288086
# Eval_MaxReturn : 217.05038452148438
# Eval_MinReturn : 131.18072509765625
# Eval_AverageEpLen : 92.36363636363636
# Train_AverageReturn : 184.59580993652344
# Train_StdReturn : 24.642532348632812
# Train_MaxReturn : 248.2347412109375
# Train_MinReturn : -0.6413261890411377
# Train_AverageEpLen : 93.42592592592592
# Train_EnvstepsSoFar : 351344
# TimeSinceStart : 103.28352975845337
# Training Loss : 140.44512939453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10043 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.1880340576172
# Eval_StdReturn : 18.343017578125
# Eval_MaxReturn : 213.60678100585938
# Eval_MinReturn : 148.42318725585938
# Eval_AverageEpLen : 92.81818181818181
# Train_AverageReturn : 184.1678924560547
# Train_StdReturn : 20.407798767089844
# Train_MaxReturn : 237.85531616210938
# Train_MinReturn : 127.77906036376953
# Train_AverageEpLen : 93.85981308411215
# Train_EnvstepsSoFar : 361387
# TimeSinceStart : 106.16422700881958
# Training Loss : 139.3912353515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.58018493652344
# Eval_StdReturn : 25.343881607055664
# Eval_MaxReturn : 214.2399139404297
# Eval_MinReturn : 125.41629791259766
# Eval_AverageEpLen : 91.45454545454545
# Train_AverageReturn : 179.10816955566406
# Train_StdReturn : 32.72540283203125
# Train_MaxReturn : 284.3106994628906
# Train_MinReturn : -0.023821711540222168
# Train_AverageEpLen : 91.52727272727273
# Train_EnvstepsSoFar : 371455
# TimeSinceStart : 108.53273391723633
# Training Loss : 138.59747314453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.5081024169922
# Eval_StdReturn : 32.24420928955078
# Eval_MaxReturn : 242.7417449951172
# Eval_MinReturn : 127.7685775756836
# Eval_AverageEpLen : 97.81818181818181
# Train_AverageReturn : 186.62493896484375
# Train_StdReturn : 29.240034103393555
# Train_MaxReturn : 307.8385009765625
# Train_MinReturn : 126.23400115966797
# Train_AverageEpLen : 94.58490566037736
# Train_EnvstepsSoFar : 381481
# TimeSinceStart : 110.87929892539978
# Training Loss : 140.44541931152344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10092 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.9939422607422
# Eval_StdReturn : 19.847898483276367
# Eval_MaxReturn : 206.51043701171875
# Eval_MinReturn : 142.44618225097656
# Eval_AverageEpLen : 91.36363636363636
# Train_AverageReturn : 177.00875854492188
# Train_StdReturn : 39.954830169677734
# Train_MaxReturn : 291.40045166015625
# Train_MinReturn : 1.0296235084533691
# Train_AverageEpLen : 90.10714285714286
# Train_EnvstepsSoFar : 391573
# TimeSinceStart : 113.27780985832214
# Training Loss : 139.5460205078125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.14097595214844
# Eval_StdReturn : 51.29280471801758
# Eval_MaxReturn : 243.06434631347656
# Eval_MinReturn : 57.58412551879883
# Eval_AverageEpLen : 87.0
# Train_AverageReturn : 172.3126678466797
# Train_StdReturn : 45.92673873901367
# Train_MaxReturn : 308.48541259765625
# Train_MinReturn : 61.17268371582031
# Train_AverageEpLen : 88.17543859649123
# Train_EnvstepsSoFar : 401625
# TimeSinceStart : 116.61022996902466
# Training Loss : 137.32479858398438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10096 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.32923889160156
# Eval_StdReturn : 56.36687469482422
# Eval_MaxReturn : 324.2945556640625
# Eval_MinReturn : 126.25627136230469
# Eval_AverageEpLen : 93.72727272727273
# Train_AverageReturn : 173.3035888671875
# Train_StdReturn : 53.06747817993164
# Train_MaxReturn : 369.6816101074219
# Train_MinReturn : 0.9885601997375488
# Train_AverageEpLen : 87.79130434782608
# Train_EnvstepsSoFar : 411721
# TimeSinceStart : 119.79072403907776
# Training Loss : 139.5904083251953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.2970733642578
# Eval_StdReturn : 51.01125717163086
# Eval_MaxReturn : 273.35235595703125
# Eval_MinReturn : 129.30908203125
# Eval_AverageEpLen : 95.63636363636364
# Train_AverageReturn : 179.76416015625
# Train_StdReturn : 60.40360641479492
# Train_MaxReturn : 426.8338623046875
# Train_MinReturn : 55.360984802246094
# Train_AverageEpLen : 89.83035714285714
# Train_EnvstepsSoFar : 421782
# TimeSinceStart : 122.20356488227844
# Training Loss : 142.24258422851562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.15367126464844
# Eval_StdReturn : 54.194034576416016
# Eval_MaxReturn : 284.87200927734375
# Eval_MinReturn : 126.96465301513672
# Eval_AverageEpLen : 94.72727272727273
# Train_AverageReturn : 181.4712371826172
# Train_StdReturn : 54.149635314941406
# Train_MaxReturn : 352.866455078125
# Train_MinReturn : 124.19021606445312
# Train_AverageEpLen : 90.61261261261261
# Train_EnvstepsSoFar : 431840
# TimeSinceStart : 125.92936682701111
# Training Loss : 142.90457153320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.91253662109375
# Eval_StdReturn : 40.67634201049805
# Eval_MaxReturn : 283.4105529785156
# Eval_MinReturn : 145.0872344970703
# Eval_AverageEpLen : 92.0
# Train_AverageReturn : 198.22512817382812
# Train_StdReturn : 57.05827331542969
# Train_MaxReturn : 379.3280334472656
# Train_MinReturn : 125.16880798339844
# Train_AverageEpLen : 97.6504854368932
# Train_EnvstepsSoFar : 441898
# TimeSinceStart : 128.6918330192566
# Training Loss : 146.539794921875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 193.93325805664062
# Eval_StdReturn : 42.50080108642578
# Eval_MaxReturn : 282.72320556640625
# Eval_MinReturn : 136.01039123535156
# Eval_AverageEpLen : 94.36363636363636
# Train_AverageReturn : 195.3335418701172
# Train_StdReturn : 56.537750244140625
# Train_MaxReturn : 389.37493896484375
# Train_MinReturn : 124.21504974365234
# Train_AverageEpLen : 94.90566037735849
# Train_EnvstepsSoFar : 451958
# TimeSinceStart : 131.04090094566345
# Training Loss : 147.9021453857422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.1069793701172
# Eval_StdReturn : 31.613597869873047
# Eval_MaxReturn : 255.13629150390625
# Eval_MinReturn : 138.8519744873047
# Eval_AverageEpLen : 91.18181818181819
# Train_AverageReturn : 194.24295043945312
# Train_StdReturn : 54.700096130371094
# Train_MaxReturn : 372.3824462890625
# Train_MinReturn : 0.46038520336151123
# Train_AverageEpLen : 94.9245283018868
# Train_EnvstepsSoFar : 462020
# TimeSinceStart : 133.38969492912292
# Training Loss : 147.14134216308594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 230.50509643554688
# Eval_StdReturn : 63.66856002807617
# Eval_MaxReturn : 345.3164367675781
# Eval_MinReturn : 156.31871032714844
# Eval_AverageEpLen : 109.2
# Train_AverageReturn : 205.11643981933594
# Train_StdReturn : 57.82625198364258
# Train_MaxReturn : 505.7816467285156
# Train_MinReturn : 128.66357421875
# Train_AverageEpLen : 99.18811881188118
# Train_EnvstepsSoFar : 472038
# TimeSinceStart : 135.7427990436554
# Training Loss : 150.0812225341797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10087 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 230.16482543945312
# Eval_StdReturn : 73.24169921875
# Eval_MaxReturn : 362.3933410644531
# Eval_MinReturn : 151.8155975341797
# Eval_AverageEpLen : 107.9
# Train_AverageReturn : 210.00701904296875
# Train_StdReturn : 60.07255935668945
# Train_MaxReturn : 413.23394775390625
# Train_MinReturn : 134.21226501464844
# Train_AverageEpLen : 100.87
# Train_EnvstepsSoFar : 482125
# TimeSinceStart : 138.0526478290558
# Training Loss : 151.1143798828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10080 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.12539672851562
# Eval_StdReturn : 53.32990646362305
# Eval_MaxReturn : 288.6308288574219
# Eval_MinReturn : 146.0251007080078
# Eval_AverageEpLen : 96.45454545454545
# Train_AverageReturn : 213.35984802246094
# Train_StdReturn : 62.14995574951172
# Train_MaxReturn : 486.5357360839844
# Train_MinReturn : 132.3450164794922
# Train_AverageEpLen : 102.85714285714286
# Train_EnvstepsSoFar : 492205
# TimeSinceStart : 140.43257594108582
# Training Loss : 151.91258239746094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 228.3846893310547
# Eval_StdReturn : 65.59818267822266
# Eval_MaxReturn : 351.95196533203125
# Eval_MinReturn : 163.4901580810547
# Eval_AverageEpLen : 104.6
# Train_AverageReturn : 213.63827514648438
# Train_StdReturn : 58.478336334228516
# Train_MaxReturn : 375.58636474609375
# Train_MinReturn : 149.9539794921875
# Train_AverageEpLen : 102.34693877551021
# Train_EnvstepsSoFar : 502235
# TimeSinceStart : 142.98091983795166
# Training Loss : 152.48385620117188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10076 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.29603576660156
# Eval_StdReturn : 46.337337493896484
# Eval_MaxReturn : 324.82171630859375
# Eval_MinReturn : 156.4276123046875
# Eval_AverageEpLen : 94.9090909090909
# Train_AverageReturn : 217.34548950195312
# Train_StdReturn : 63.26735305786133
# Train_MaxReturn : 400.4090881347656
# Train_MinReturn : 145.6572723388672
# Train_AverageEpLen : 102.81632653061224
# Train_EnvstepsSoFar : 512311
# TimeSinceStart : 145.44502687454224
# Training Loss : 155.07948303222656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 237.95144653320312
# Eval_StdReturn : 66.33033752441406
# Eval_MaxReturn : 379.30908203125
# Eval_MinReturn : 159.55946350097656
# Eval_AverageEpLen : 111.22222222222223
# Train_AverageReturn : 207.50741577148438
# Train_StdReturn : 58.48561096191406
# Train_MaxReturn : 462.8225402832031
# Train_MinReturn : 144.14910888671875
# Train_AverageEpLen : 101.35353535353535
# Train_EnvstepsSoFar : 522345
# TimeSinceStart : 147.97047591209412
# Training Loss : 149.62869262695312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.83233642578125
# Eval_StdReturn : 40.820533752441406
# Eval_MaxReturn : 286.83441162109375
# Eval_MinReturn : 148.71974182128906
# Eval_AverageEpLen : 95.9090909090909
# Train_AverageReturn : 204.4833984375
# Train_StdReturn : 55.149024963378906
# Train_MaxReturn : 393.04046630859375
# Train_MinReturn : 146.49371337890625
# Train_AverageEpLen : 100.31
# Train_EnvstepsSoFar : 532376
# TimeSinceStart : 150.14905905723572
# Training Loss : 148.62440490722656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.55142211914062
# Eval_StdReturn : 38.20657730102539
# Eval_MaxReturn : 304.15313720703125
# Eval_MinReturn : 163.71788024902344
# Eval_AverageEpLen : 93.45454545454545
# Train_AverageReturn : 207.00082397460938
# Train_StdReturn : 57.000267028808594
# Train_MaxReturn : 370.56195068359375
# Train_MinReturn : 156.8808135986328
# Train_AverageEpLen : 101.08080808080808
# Train_EnvstepsSoFar : 542383
# TimeSinceStart : 152.37278985977173
# Training Loss : 149.9097442626953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10066 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 213.7215118408203
# Eval_StdReturn : 55.438140869140625
# Eval_MaxReturn : 317.7392883300781
# Eval_MinReturn : 164.40399169921875
# Eval_AverageEpLen : 101.5
# Train_AverageReturn : 196.9410858154297
# Train_StdReturn : 55.66203689575195
# Train_MaxReturn : 449.51641845703125
# Train_MinReturn : 143.61964416503906
# Train_AverageEpLen : 97.72815533980582
# Train_EnvstepsSoFar : 552449
# TimeSinceStart : 154.53322792053223
# Training Loss : 146.4626922607422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.40640258789062
# Eval_StdReturn : 43.815765380859375
# Eval_MaxReturn : 325.4678649902344
# Eval_MinReturn : 154.40692138671875
# Eval_AverageEpLen : 100.8
# Train_AverageReturn : 205.58871459960938
# Train_StdReturn : 56.18987274169922
# Train_MaxReturn : 447.1868896484375
# Train_MinReturn : 148.2172088623047
# Train_AverageEpLen : 100.72
# Train_EnvstepsSoFar : 562521
# TimeSinceStart : 157.00701475143433
# Training Loss : 149.73968505859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10134 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 247.43475341796875
# Eval_StdReturn : 75.17882537841797
# Eval_MaxReturn : 430.14794921875
# Eval_MinReturn : 192.7691650390625
# Eval_AverageEpLen : 122.11111111111111
# Train_AverageReturn : 221.76986694335938
# Train_StdReturn : 72.37803649902344
# Train_MaxReturn : 469.1965026855469
# Train_MinReturn : 145.41864013671875
# Train_AverageEpLen : 106.67368421052632
# Train_EnvstepsSoFar : 572655
# TimeSinceStart : 159.35524082183838
# Training Loss : 154.9383544921875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10086 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 252.45086669921875
# Eval_StdReturn : 100.03112030029297
# Eval_MaxReturn : 485.2276916503906
# Eval_MinReturn : 172.65272521972656
# Eval_AverageEpLen : 121.55555555555556
# Train_AverageReturn : 256.5001525878906
# Train_StdReturn : 86.32647705078125
# Train_MaxReturn : 509.0496826171875
# Train_MinReturn : 159.7096405029297
# Train_AverageEpLen : 118.65882352941176
# Train_EnvstepsSoFar : 582741
# TimeSinceStart : 161.52926898002625
# Training Loss : 165.08970642089844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10075 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 312.79559326171875
# Eval_StdReturn : 77.05636596679688
# Eval_MaxReturn : 444.6122741699219
# Eval_MinReturn : 168.04568481445312
# Eval_AverageEpLen : 132.125
# Train_AverageReturn : 251.28158569335938
# Train_StdReturn : 82.21078491210938
# Train_MaxReturn : 537.5281982421875
# Train_MinReturn : 151.5041961669922
# Train_AverageEpLen : 117.15116279069767
# Train_EnvstepsSoFar : 592816
# TimeSinceStart : 163.66536378860474
# Training Loss : 163.10682678222656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10110 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 356.88336181640625
# Eval_StdReturn : 105.90106201171875
# Eval_MaxReturn : 502.3785705566406
# Eval_MinReturn : 170.6278076171875
# Eval_AverageEpLen : 152.85714285714286
# Train_AverageReturn : 283.0541076660156
# Train_StdReturn : 100.96512603759766
# Train_MaxReturn : 511.1513977050781
# Train_MinReturn : 147.06109619140625
# Train_AverageEpLen : 127.9746835443038
# Train_EnvstepsSoFar : 602926
# TimeSinceStart : 165.78826212882996
# Training Loss : 171.6326446533203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 277.39971923828125
# Eval_StdReturn : 115.316162109375
# Eval_MaxReturn : 465.43084716796875
# Eval_MinReturn : 159.49464416503906
# Eval_AverageEpLen : 133.625
# Train_AverageReturn : 318.6328125
# Train_StdReturn : 114.61300659179688
# Train_MaxReturn : 566.5758056640625
# Train_MinReturn : 125.97689819335938
# Train_AverageEpLen : 141.81690140845072
# Train_EnvstepsSoFar : 612995
# TimeSinceStart : 167.93065094947815
# Training Loss : 177.07762145996094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10132 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 353.9881591796875
# Eval_StdReturn : 127.1871566772461
# Eval_MaxReturn : 494.6287841796875
# Eval_MinReturn : 175.22235107421875
# Eval_AverageEpLen : 142.625
# Train_AverageReturn : 382.10870361328125
# Train_StdReturn : 123.69027709960938
# Train_MaxReturn : 590.3671875
# Train_MinReturn : 117.85661315917969
# Train_AverageEpLen : 158.3125
# Train_EnvstepsSoFar : 623127
# TimeSinceStart : 170.19716691970825
# Training Loss : 194.1437225341797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 375.2901306152344
# Eval_StdReturn : 134.8554229736328
# Eval_MaxReturn : 524.3764038085938
# Eval_MinReturn : 130.504638671875
# Eval_AverageEpLen : 166.66666666666666
# Train_AverageReturn : 357.3919372558594
# Train_StdReturn : 110.28085327148438
# Train_MaxReturn : 575.8634033203125
# Train_MinReturn : 149.3431396484375
# Train_AverageEpLen : 154.8923076923077
# Train_EnvstepsSoFar : 633195
# TimeSinceStart : 172.31643104553223
# Training Loss : 184.45068359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.695383071899414
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# ...
# TimeSinceStart : 192.21094393730164
# Training Loss : 95.47456359863281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.93043518066406
# Eval_StdReturn : 8.183367729187012
# Eval_MaxReturn : 115.03215789794922
# Eval_MinReturn : 85.34504699707031
# Eval_AverageEpLen : 57.22222222222222
# Train_AverageReturn : 87.57730865478516
# Train_StdReturn : 7.082425594329834
# Train_MaxReturn : 106.07283020019531
# Train_MinReturn : 59.129337310791016
# Train_AverageEpLen : 48.69417475728155
# Train_EnvstepsSoFar : 802889
# TimeSinceStart : 194.67024993896484
# Training Loss : 101.86199188232422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.05714416503906
# Eval_StdReturn : 9.422381401062012
# Eval_MaxReturn : 137.48788452148438
# Eval_MinReturn : 101.40950775146484
# Eval_AverageEpLen : 63.4375
# Train_AverageReturn : 100.55317687988281
# Train_StdReturn : 8.675684928894043
# Train_MaxReturn : 120.73125457763672
# Train_MinReturn : 79.08621215820312
# Train_AverageEpLen : 55.49723756906077
# Train_EnvstepsSoFar : 812934
# TimeSinceStart : 197.0231318473816
# Training Loss : 108.13446807861328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 143.71241760253906
# Eval_StdReturn : 19.131929397583008
# Eval_MaxReturn : 188.9728240966797
# Eval_MinReturn : 114.76702880859375
# Eval_AverageEpLen : 73.71428571428571
# Train_AverageReturn : 116.97758483886719
# Train_StdReturn : 11.855541229248047
# Train_MaxReturn : 194.6664276123047
# Train_MinReturn : 88.57310485839844
# Train_AverageEpLen : 63.77070063694268
# Train_EnvstepsSoFar : 822946
# TimeSinceStart : 199.59297585487366
# Training Loss : 114.48779296875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 143.57217407226562
# Eval_StdReturn : 22.618453979492188
# Eval_MaxReturn : 181.61895751953125
# Eval_MinReturn : 104.90254974365234
# Eval_AverageEpLen : 73.78571428571429
# Train_AverageReturn : 137.3716278076172
# Train_StdReturn : 14.332752227783203
# Train_MaxReturn : 196.47732543945312
# Train_MinReturn : 105.04902648925781
# Train_AverageEpLen : 72.14388489208633
# Train_EnvstepsSoFar : 832974
# TimeSinceStart : 201.96488404273987
# Training Loss : 124.0000228881836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 152.74803161621094
# Eval_StdReturn : 14.407496452331543
# Eval_MaxReturn : 175.24679565429688
# Eval_MinReturn : 130.07333374023438
# Eval_AverageEpLen : 78.3076923076923
# Train_AverageReturn : 151.55697631835938
# Train_StdReturn : 14.96466064453125
# Train_MaxReturn : 191.55764770507812
# Train_MinReturn : 117.43022918701172
# Train_AverageEpLen : 77.23846153846154
# Train_EnvstepsSoFar : 843015
# TimeSinceStart : 204.35538601875305
# Training Loss : 130.703857421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.23915100097656
# Eval_StdReturn : 15.15675163269043
# Eval_MaxReturn : 191.19589233398438
# Eval_MinReturn : 138.29824829101562
# Eval_AverageEpLen : 83.15384615384616
# Train_AverageReturn : 160.33448791503906
# Train_StdReturn : 15.148815155029297
# Train_MaxReturn : 205.23590087890625
# Train_MinReturn : 122.05262756347656
# Train_AverageEpLen : 80.4
# Train_EnvstepsSoFar : 853065
# TimeSinceStart : 207.01282215118408
# Training Loss : 134.3582305908203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.0325927734375
# Eval_StdReturn : 8.732177734375
# Eval_MaxReturn : 198.67454528808594
# Eval_MinReturn : 164.03260803222656
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 168.70298767089844
# Train_StdReturn : 12.870473861694336
# Train_MaxReturn : 198.5934600830078
# Train_MinReturn : 127.42872619628906
# Train_AverageEpLen : 83.44166666666666
# Train_EnvstepsSoFar : 863078
# TimeSinceStart : 209.47325801849365
# Training Loss : 137.87705993652344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.2065887451172
# Eval_StdReturn : 6.957058906555176
# Eval_MaxReturn : 184.47140502929688
# Eval_MinReturn : 163.3440704345703
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 170.226318359375
# Train_StdReturn : 11.614551544189453
# Train_MaxReturn : 205.02285766601562
# Train_MinReturn : 127.51181030273438
# Train_AverageEpLen : 84.3781512605042
# Train_EnvstepsSoFar : 873119
# TimeSinceStart : 211.83741688728333
# Training Loss : 137.92465209960938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.29608154296875
# Eval_StdReturn : 5.801206111907959
# Eval_MaxReturn : 184.27272033691406
# Eval_MinReturn : 161.20912170410156
# Eval_AverageEpLen : 85.83333333333333
# Train_AverageReturn : 173.6945343017578
# Train_StdReturn : 7.712681293487549
# Train_MaxReturn : 194.35577392578125
# Train_MinReturn : 156.2483367919922
# Train_AverageEpLen : 85.53846153846153
# Train_EnvstepsSoFar : 883127
# TimeSinceStart : 214.21994304656982
# Training Loss : 138.53964233398438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.85968017578125
# Eval_StdReturn : 4.4492292404174805
# Eval_MaxReturn : 179.77151489257812
# Eval_MinReturn : 161.4534149169922
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 171.65939331054688
# Train_StdReturn : 7.195847988128662
# Train_MaxReturn : 194.7303009033203
# Train_MinReturn : 149.32916259765625
# Train_AverageEpLen : 85.67521367521367
# Train_EnvstepsSoFar : 893151
# TimeSinceStart : 216.67015600204468
# Training Loss : 136.1311798095703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.24180603027344
# Eval_StdReturn : 4.771657466888428
# Eval_MaxReturn : 184.85745239257812
# Eval_MinReturn : 165.0888671875
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 171.7581024169922
# Train_StdReturn : 5.546971797943115
# Train_MaxReturn : 189.1844024658203
# Train_MinReturn : 155.1602783203125
# Train_AverageEpLen : 86.04273504273505
# Train_EnvstepsSoFar : 903218
# TimeSinceStart : 219.02067685127258
# Training Loss : 135.99803161621094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10083 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.7007598876953
# Eval_StdReturn : 3.0304975509643555
# Eval_MaxReturn : 172.64588928222656
# Eval_MinReturn : 162.03555297851562
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 169.68067932128906
# Train_StdReturn : 4.438072681427002
# Train_MaxReturn : 190.32205200195312
# Train_MinReturn : 152.38522338867188
# Train_AverageEpLen : 86.17948717948718
# Train_EnvstepsSoFar : 913301
# TimeSinceStart : 221.3232889175415
# Training Loss : 133.3675537109375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10082 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.54385375976562
# Eval_StdReturn : 2.8319449424743652
# Eval_MaxReturn : 170.80050659179688
# Eval_MinReturn : 160.74435424804688
# Eval_AverageEpLen : 86.0
# Train_AverageReturn : 168.3805389404297
# Train_StdReturn : 2.8228394985198975
# Train_MaxReturn : 176.20291137695312
# Train_MinReturn : 155.32565307617188
# Train_AverageEpLen : 86.17094017094017
# Train_EnvstepsSoFar : 923383
# TimeSinceStart : 223.7329728603363
# Training Loss : 131.9168701171875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.19776916503906
# Eval_StdReturn : 1.2574964761734009
# Eval_MaxReturn : 170.17080688476562
# Eval_MinReturn : 165.6619110107422
# Eval_AverageEpLen : 86.5
# Train_AverageReturn : 167.94500732421875
# Train_StdReturn : 2.106558084487915
# Train_MaxReturn : 174.0137939453125
# Train_MinReturn : 161.9158935546875
# Train_AverageEpLen : 86.24137931034483
# Train_EnvstepsSoFar : 933387
# TimeSinceStart : 226.06383109092712
# Training Loss : 130.5778045654297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.0170440673828
# Eval_StdReturn : 3.158482551574707
# Eval_MaxReturn : 172.07443237304688
# Eval_MinReturn : 159.77743530273438
# Eval_AverageEpLen : 86.5
# Train_AverageReturn : 168.67315673828125
# Train_StdReturn : 2.115492820739746
# Train_MaxReturn : 174.18638610839844
# Train_MinReturn : 162.15171813964844
# Train_AverageEpLen : 86.32758620689656
# Train_EnvstepsSoFar : 943401
# TimeSinceStart : 228.42044591903687
# Training Loss : 131.65377807617188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.6537322998047
# Eval_StdReturn : 2.4484310150146484
# Eval_MaxReturn : 173.47952270507812
# Eval_MinReturn : 165.2650909423828
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 168.9180145263672
# Train_StdReturn : 1.7484008073806763
# Train_MaxReturn : 172.9556884765625
# Train_MinReturn : 163.295166015625
# Train_AverageEpLen : 86.34482758620689
# Train_EnvstepsSoFar : 953417
# TimeSinceStart : 230.8010609149933
# Training Loss : 131.7003173828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.9105987548828
# Eval_StdReturn : 1.401002287864685
# Eval_MaxReturn : 171.5872039794922
# Eval_MinReturn : 166.74732971191406
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 169.24703979492188
# Train_StdReturn : 1.9827133417129517
# Train_MaxReturn : 173.27000427246094
# Train_MinReturn : 163.49993896484375
# Train_AverageEpLen : 86.38793103448276
# Train_EnvstepsSoFar : 963438
# TimeSinceStart : 233.17854499816895
# Training Loss : 130.98056030273438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.48927307128906
# Eval_StdReturn : 2.1443841457366943
# Eval_MaxReturn : 171.40208435058594
# Eval_MinReturn : 163.75534057617188
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 169.1990203857422
# Train_StdReturn : 2.118379831314087
# Train_MaxReturn : 173.98451232910156
# Train_MinReturn : 159.93038940429688
# Train_AverageEpLen : 86.35344827586206
# Train_EnvstepsSoFar : 973455
# TimeSinceStart : 235.5237169265747
# Training Loss : 132.19932556152344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.78126525878906
# Eval_StdReturn : 2.0279881954193115
# Eval_MaxReturn : 173.18133544921875
# Eval_MinReturn : 165.8907470703125
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 168.86355590820312
# Train_StdReturn : 2.000830888748169
# Train_MaxReturn : 172.8889617919922
# Train_MinReturn : 161.67739868164062
# Train_AverageEpLen : 86.23275862068965
# Train_EnvstepsSoFar : 983458
# TimeSinceStart : 238.4317820072174
# Training Loss : 131.69589233398438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.1381072998047
# Eval_StdReturn : 4.271395683288574
# Eval_MaxReturn : 172.28509521484375
# Eval_MinReturn : 155.604248046875
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 168.21047973632812
# Train_StdReturn : 3.337385416030884
# Train_MaxReturn : 172.6535186767578
# Train_MinReturn : 147.4257354736328
# Train_AverageEpLen : 86.1025641025641
# Train_EnvstepsSoFar : 993532
# TimeSinceStart : 240.90333080291748
# Training Loss : 130.8728485107422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.24546813964844
# Eval_StdReturn : 4.191364288330078
# Eval_MaxReturn : 171.51161193847656
# Eval_MinReturn : 155.13690185546875
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 168.6456756591797
# Train_StdReturn : 2.099858283996582
# Train_MaxReturn : 172.2357940673828
# Train_MinReturn : 162.09901428222656
# Train_AverageEpLen : 86.37931034482759
# Train_EnvstepsSoFar : 1003552
# TimeSinceStart : 243.36096286773682
# Training Loss : 130.9141082763672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.613977432250977
# Done logging...

# %%
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %% [markdown]
# ## Variance Reduction with a Value Function Baseline
# We can further reduce the policy gradient variance by including state-dependent baselines. In this section, we will train a value function network to predict the value of the policy at a state, then use the value function as a baseline by subtracting it from our reward-to-go estimate.
#
# Implement the value function baseline loss in the update method of the MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
# Test value function gradient
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            nn_baseline=True)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))
qvals = advs

first_weight_before = np.array(ptu.to_numpy(next(policy.baseline.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs, qvals=qvals)['Baseline Loss']

print(loss)
expected_loss = 0.925361
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.baseline.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.38988823,  0.70297027,  0.2609921 ],
                            [-1.0340402,  -0.84166795,  0.7254925 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.23799711  0.0213871   0.22824687]
#  [ 0.34642333 -0.39140946 -0.25141457]]
# 0.925361
# Loss Error 1.2076536367060315e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 0.15189107  0.72435737  0.48923904]
#  [-0.68761694 -1.2330772   0.474078  ]]
# Change in weights [[ 0.38988817  0.70297027  0.26099217]
#  [-1.0340402  -0.8416677   0.7254926 ]]
# Weight Update Error 1.4154350421085664e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# In the estimate_advantage function in <code>agents/pg_agent.py</code>, fill out the advantage estimate using the baseline and test your implementation below.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['nn_baseline'] = True
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

obs_dim = 4
N = 10
np.random.seed(0)
obs = np.random.normal(size=(N, obs_dim))
qs = np.random.normal(size=N)

baseline_advantages = pgagent.estimate_advantage(obs, qs)
expected_advantages = np.array([-0.44662586, -0.89629588, -1.14574752,  2.43957172, -0.06601728,
       -0.00501807, -0.74720337,  1.27468092, -1.20184486,  0.25312274])

advantage_error = rel_error(expected_advantages, baseline_advantages)
print("Advantage error", advantage_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Advantage error 3.6888988344448045e-07 should be on the order of 1e-6 or lower
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:440: UserWarning: WARN: The `registry.env_specs` property along with `EnvSpecTree` is deprecated. Please use `registry` directly as a dictionary instead.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %% [markdown]
# ## Train your policies!
# In this section, we will train our policies using the reward-to-go estimator and learning a value function baseline. On Hopper, you should see your methods get over 300 rewards consistently, and sometimes over 400. Returns will tend to oscillate during training. You should also see that using a value function baseline greatly improves performance over our earlier experiments without it.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['nn_baseline'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/with_baseline/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/with_baseline/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/with_baseline/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/with_baseline/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     584 / 10000
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment Hopper-v2 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/gym/envs/mujoco/mujoco_env.py:237: UserWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.warn(
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.36264038085938
# Eval_StdReturn : 60.808937072753906
# Eval_MaxReturn : 230.2005615234375
# Eval_MinReturn : 25.070186614990234
# Eval_AverageEpLen : 63.875
# Train_AverageReturn : 9.500977516174316
# Train_StdReturn : 5.021817207336426
# Train_MaxReturn : 61.28253173828125
# Train_MinReturn : 2.959118127822876
# Train_AverageEpLen : 12.97279792746114
# Train_EnvstepsSoFar : 10015
# TimeSinceStart : 3.6345510482788086
# Training Loss : 4.095727443695068
# Baseline Loss : 1.0605067014694214
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.38123321533203
# Eval_StdReturn : 48.506370544433594
# Eval_MaxReturn : 201.5376739501953
# Eval_MinReturn : 22.791522979736328
# Eval_AverageEpLen : 55.10526315789474
# Train_AverageReturn : 109.66216278076172
# Train_StdReturn : 50.18576431274414
# Train_MaxReturn : 279.042724609375
# Train_MinReturn : 10.234734535217285
# Train_AverageEpLen : 66.87333333333333
# Train_EnvstepsSoFar : 20046
# TimeSinceStart : 6.020581245422363
# Training Loss : -11.988049507141113
# Baseline Loss : 1.2159931659698486
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 152.9669189453125
# Eval_StdReturn : 56.86677169799805
# Eval_MaxReturn : 202.42237854003906
# Eval_MinReturn : 28.295087814331055
# Eval_AverageEpLen : 72.42857142857143
# Train_AverageReturn : 125.19293212890625
# Train_StdReturn : 51.30309295654297
# Train_MaxReturn : 235.7269287109375
# Train_MinReturn : 13.256525993347168
# Train_AverageEpLen : 64.3525641025641
# Train_EnvstepsSoFar : 30085
# TimeSinceStart : 8.394654273986816
# Training Loss : -7.112705230712891
# Baseline Loss : 1.0312039852142334
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.6097869873047
# Eval_StdReturn : 20.44987678527832
# Eval_MaxReturn : 190.5073699951172
# Eval_MinReturn : 120.9732666015625
# Eval_AverageEpLen : 79.3076923076923
# Train_AverageReturn : 137.3621063232422
# Train_StdReturn : 67.84070587158203
# Train_MaxReturn : 216.85858154296875
# Train_MinReturn : 15.213895797729492
# Train_AverageEpLen : 66.15789473684211
# Train_EnvstepsSoFar : 40141
# TimeSinceStart : 10.580174207687378
# Training Loss : -1.2480437755584717
# Baseline Loss : 1.0410888195037842
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.66085815429688
# Eval_StdReturn : 34.62105178833008
# Eval_MaxReturn : 201.07232666015625
# Eval_MinReturn : 88.30912017822266
# Eval_AverageEpLen : 77.92307692307692
# Train_AverageReturn : 167.68283081054688
# Train_StdReturn : 29.715505599975586
# Train_MaxReturn : 200.97607421875
# Train_MinReturn : 64.18321228027344
# Train_AverageEpLen : 78.546875
# Train_EnvstepsSoFar : 50195
# TimeSinceStart : 12.778078317642212
# Training Loss : 7.796752452850342
# Baseline Loss : 1.0320619344711304
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10079 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.44949340820312
# Eval_StdReturn : 7.0755534172058105
# Eval_MaxReturn : 188.57269287109375
# Eval_MinReturn : 162.22738647460938
# Eval_AverageEpLen : 83.0
# Train_AverageReturn : 179.4222869873047
# Train_StdReturn : 21.467266082763672
# Train_MaxReturn : 210.56448364257812
# Train_MinReturn : 80.87268829345703
# Train_AverageEpLen : 82.61475409836065
# Train_EnvstepsSoFar : 60274
# TimeSinceStart : 15.056979179382324
# Training Loss : 6.382052898406982
# Baseline Loss : 0.9559374451637268
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.10752868652344
# Eval_StdReturn : 5.198288917541504
# Eval_MaxReturn : 191.37197875976562
# Eval_MinReturn : 172.4912567138672
# Eval_AverageEpLen : 84.25
# Train_AverageReturn : 181.62425231933594
# Train_StdReturn : 16.55082130432129
# Train_MaxReturn : 208.32492065429688
# Train_MinReturn : 79.79185485839844
# Train_AverageEpLen : 83.85
# Train_EnvstepsSoFar : 70336
# TimeSinceStart : 17.240045070648193
# Training Loss : 2.986147880554199
# Baseline Loss : 0.8648248314857483
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.07791137695312
# Eval_StdReturn : 24.192764282226562
# Eval_MaxReturn : 189.4134063720703
# Eval_MinReturn : 92.3981704711914
# Eval_AverageEpLen : 81.84615384615384
# Train_AverageReturn : 179.74441528320312
# Train_StdReturn : 16.244279861450195
# Train_MaxReturn : 201.96495056152344
# Train_MinReturn : 79.85202026367188
# Train_AverageEpLen : 83.40833333333333
# Train_EnvstepsSoFar : 80345
# TimeSinceStart : 19.32242512702942
# Training Loss : 0.9354100823402405
# Baseline Loss : 0.815928041934967
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.32659912109375
# Eval_StdReturn : 3.656445026397705
# Eval_MaxReturn : 187.7467498779297
# Eval_MinReturn : 173.98489379882812
# Eval_AverageEpLen : 83.83333333333333
# Train_AverageReturn : 178.07891845703125
# Train_StdReturn : 13.64992904663086
# Train_MaxReturn : 195.6324462890625
# Train_MinReturn : 81.57199096679688
# Train_AverageEpLen : 83.4
# Train_EnvstepsSoFar : 90353
# TimeSinceStart : 21.336562156677246
# Training Loss : 1.350461483001709
# Baseline Loss : 0.7706061005592346
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.8548583984375
# Eval_StdReturn : 4.826933860778809
# Eval_MaxReturn : 187.9344024658203
# Eval_MinReturn : 173.22857666015625
# Eval_AverageEpLen : 86.66666666666667
# Train_AverageReturn : 179.2056427001953
# Train_StdReturn : 5.889631748199463
# Train_MaxReturn : 195.48439025878906
# Train_MinReturn : 165.5700225830078
# Train_AverageEpLen : 84.33613445378151
# Train_EnvstepsSoFar : 100389
# TimeSinceStart : 23.80399203300476
# Training Loss : 1.9134465456008911
# Baseline Loss : 0.7349751591682434
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.7868194580078
# Eval_StdReturn : 4.1178154945373535
# Eval_MaxReturn : 187.5792694091797
# Eval_MinReturn : 172.57870483398438
# Eval_AverageEpLen : 87.33333333333333
# Train_AverageReturn : 178.5911407470703
# Train_StdReturn : 11.943581581115723
# Train_MaxReturn : 203.00135803222656
# Train_MinReturn : 68.49662017822266
# Train_AverageEpLen : 85.76068376068376
# Train_EnvstepsSoFar : 110423
# TimeSinceStart : 28.042731046676636
# Training Loss : 0.7420273423194885
# Baseline Loss : 0.6736578345298767
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.9131317138672
# Eval_StdReturn : 25.658191680908203
# Eval_MaxReturn : 186.48123168945312
# Eval_MinReturn : 86.62047576904297
# Eval_AverageEpLen : 86.58333333333333
# Train_AverageReturn : 177.2671661376953
# Train_StdReturn : 9.948307991027832
# Train_MaxReturn : 190.78794860839844
# Train_MinReturn : 84.07854461669922
# Train_AverageEpLen : 87.44347826086957
# Train_EnvstepsSoFar : 120479
# TimeSinceStart : 31.263490200042725
# Training Loss : -1.1560291051864624
# Baseline Loss : 0.5852313041687012
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.49200439453125
# Eval_StdReturn : 39.58041000366211
# Eval_MaxReturn : 193.3077850341797
# Eval_MinReturn : 72.63087463378906
# Eval_AverageEpLen : 81.15384615384616
# Train_AverageReturn : 179.97177124023438
# Train_StdReturn : 14.642382621765137
# Train_MaxReturn : 201.49378967285156
# Train_MinReturn : 68.45085144042969
# Train_AverageEpLen : 89.42857142857143
# Train_EnvstepsSoFar : 130495
# TimeSinceStart : 33.50508999824524
# Training Loss : -2.328019142150879
# Baseline Loss : 0.5524287819862366
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10051 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.1392059326172
# Eval_StdReturn : 6.378871917724609
# Eval_MaxReturn : 195.39816284179688
# Eval_MinReturn : 173.68777465820312
# Eval_AverageEpLen : 94.27272727272727
# Train_AverageReturn : 175.22024536132812
# Train_StdReturn : 25.97963523864746
# Train_MaxReturn : 197.68678283691406
# Train_MinReturn : 64.35079956054688
# Train_AverageEpLen : 88.16666666666667
# Train_EnvstepsSoFar : 140546
# TimeSinceStart : 36.31065607070923
# Training Loss : -1.6111849546432495
# Baseline Loss : 0.5615963935852051
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10082 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.2093963623047
# Eval_StdReturn : 25.235029220581055
# Eval_MaxReturn : 194.55828857421875
# Eval_MinReturn : 97.6201171875
# Eval_AverageEpLen : 90.58333333333333
# Train_AverageReturn : 174.80258178710938
# Train_StdReturn : 27.798200607299805
# Train_MaxReturn : 198.23825073242188
# Train_MinReturn : 73.15773010253906
# Train_AverageEpLen : 89.22123893805309
# Train_EnvstepsSoFar : 150628
# TimeSinceStart : 38.77756214141846
# Training Loss : 1.1686654090881348
# Baseline Loss : 0.5388152003288269
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10094 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.53407287597656
# Eval_StdReturn : 4.396848201751709
# Eval_MaxReturn : 192.82998657226562
# Eval_MinReturn : 180.2023468017578
# Eval_AverageEpLen : 96.72727272727273
# Train_AverageReturn : 178.21514892578125
# Train_StdReturn : 20.54046058654785
# Train_MaxReturn : 196.91363525390625
# Train_MinReturn : 92.3260498046875
# Train_AverageEpLen : 90.93693693693693
# Train_EnvstepsSoFar : 160722
# TimeSinceStart : 40.911808013916016
# Training Loss : 3.9680891036987305
# Baseline Loss : 0.47910448908805847
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10092 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.22828674316406
# Eval_StdReturn : 5.8802103996276855
# Eval_MaxReturn : 198.13070678710938
# Eval_MinReturn : 174.7718963623047
# Eval_AverageEpLen : 95.9090909090909
# Train_AverageReturn : 183.15318298339844
# Train_StdReturn : 5.962956428527832
# Train_MaxReturn : 196.37417602539062
# Train_MinReturn : 165.5222930908203
# Train_AverageEpLen : 94.3177570093458
# Train_EnvstepsSoFar : 170814
# TimeSinceStart : 43.58706712722778
# Training Loss : 1.5533865690231323
# Baseline Loss : 0.37422919273376465
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10092 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.30809020996094
# Eval_StdReturn : 6.129987716674805
# Eval_MaxReturn : 191.99668884277344
# Eval_MinReturn : 172.7719268798828
# Eval_AverageEpLen : 92.45454545454545
# Train_AverageReturn : 180.6759796142578
# Train_StdReturn : 12.87855052947998
# Train_MaxReturn : 196.65670776367188
# Train_MinReturn : 64.21455383300781
# Train_AverageEpLen : 93.44444444444444
# Train_EnvstepsSoFar : 180906
# TimeSinceStart : 45.89961814880371
# Training Loss : -6.774834156036377
# Baseline Loss : 0.3974013328552246
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10059 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.02020263671875
# Eval_StdReturn : 3.613415479660034
# Eval_MaxReturn : 188.5229034423828
# Eval_MinReturn : 173.75006103515625
# Eval_AverageEpLen : 93.63636363636364
# Train_AverageReturn : 176.40553283691406
# Train_StdReturn : 22.557024002075195
# Train_MaxReturn : 202.74111938476562
# Train_MinReturn : 62.68754196166992
# Train_AverageEpLen : 91.44545454545455
# Train_EnvstepsSoFar : 190965
# TimeSinceStart : 49.64075016975403
# Training Loss : -6.460461139678955
# Baseline Loss : 0.4460087716579437
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.28599548339844
# Eval_StdReturn : 5.546078681945801
# Eval_MaxReturn : 184.92117309570312
# Eval_MinReturn : 165.32379150390625
# Eval_AverageEpLen : 90.5
# Train_AverageReturn : 171.75308227539062
# Train_StdReturn : 25.86175537109375
# Train_MaxReturn : 192.09854125976562
# Train_MinReturn : 61.434574127197266
# Train_AverageEpLen : 89.08849557522124
# Train_EnvstepsSoFar : 201032
# TimeSinceStart : 52.087332248687744
# Training Loss : -1.4546561241149902
# Baseline Loss : 0.4287892282009125
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.07179260253906
# Eval_StdReturn : 4.178922653198242
# Eval_MaxReturn : 186.39268493652344
# Eval_MinReturn : 171.17311096191406
# Eval_AverageEpLen : 92.36363636363636
# Train_AverageReturn : 179.19544982910156
# Train_StdReturn : 7.496399879455566
# Train_MaxReturn : 211.85549926757812
# Train_MinReturn : 148.86508178710938
# Train_AverageEpLen : 91.85321100917432
# Train_EnvstepsSoFar : 211044
# TimeSinceStart : 54.30380916595459
# Training Loss : 1.0802874565124512
# Baseline Loss : 0.36519554257392883
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.3965606689453
# Eval_StdReturn : 5.481660842895508
# Eval_MaxReturn : 186.44114685058594
# Eval_MinReturn : 167.7717742919922
# Eval_AverageEpLen : 89.16666666666667
# Train_AverageReturn : 178.47344970703125
# Train_StdReturn : 6.275388240814209
# Train_MaxReturn : 193.5107421875
# Train_MinReturn : 158.07528686523438
# Train_AverageEpLen : 90.95454545454545
# Train_EnvstepsSoFar : 221049
# TimeSinceStart : 57.0986852645874
# Training Loss : -1.3055522441864014
# Baseline Loss : 0.3219602704048157
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.7478485107422
# Eval_StdReturn : 3.065324544906616
# Eval_MaxReturn : 183.6103057861328
# Eval_MinReturn : 173.5616455078125
# Eval_AverageEpLen : 90.0
# Train_AverageReturn : 177.14657592773438
# Train_StdReturn : 5.7626543045043945
# Train_MaxReturn : 194.08338928222656
# Train_MinReturn : 162.7307891845703
# Train_AverageEpLen : 89.45535714285714
# Train_EnvstepsSoFar : 231068
# TimeSinceStart : 59.507166147232056
# Training Loss : -2.425288438796997
# Baseline Loss : 0.3106057345867157
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.7909393310547
# Eval_StdReturn : 10.669114112854004
# Eval_MaxReturn : 189.88478088378906
# Eval_MinReturn : 146.95518493652344
# Eval_AverageEpLen : 86.66666666666667
# Train_AverageReturn : 176.4264678955078
# Train_StdReturn : 10.540528297424316
# Train_MaxReturn : 188.20724487304688
# Train_MinReturn : 102.5014877319336
# Train_AverageEpLen : 88.61061946902655
# Train_EnvstepsSoFar : 241081
# TimeSinceStart : 61.7631311416626
# Training Loss : -1.539961576461792
# Baseline Loss : 0.32480311393737793
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 161.98866271972656
# Eval_StdReturn : 28.604337692260742
# Eval_MaxReturn : 181.00094604492188
# Eval_MinReturn : 77.01998901367188
# Eval_AverageEpLen : 81.15384615384616
# Train_AverageReturn : 165.2235107421875
# Train_StdReturn : 24.77581214904785
# Train_MaxReturn : 187.50962829589844
# Train_MinReturn : 75.69620513916016
# Train_AverageEpLen : 82.89256198347107
# Train_EnvstepsSoFar : 251111
# TimeSinceStart : 63.98593616485596
# Training Loss : -0.9056015610694885
# Baseline Loss : 0.45565178990364075
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.581787109375
# Eval_StdReturn : 3.09295916557312
# Eval_MaxReturn : 183.3674774169922
# Eval_MinReturn : 173.69190979003906
# Eval_AverageEpLen : 88.91666666666667
# Train_AverageReturn : 168.32330322265625
# Train_StdReturn : 18.331998825073242
# Train_MaxReturn : 185.25115966796875
# Train_MinReturn : 94.52312469482422
# Train_AverageEpLen : 84.71428571428571
# Train_EnvstepsSoFar : 261192
# TimeSinceStart : 66.51416230201721
# Training Loss : 2.568471908569336
# Baseline Loss : 0.3965921700000763
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.7001495361328
# Eval_StdReturn : 5.882422924041748
# Eval_MaxReturn : 189.1868896484375
# Eval_MinReturn : 163.51295471191406
# Eval_AverageEpLen : 88.08333333333333
# Train_AverageReturn : 177.87449645996094
# Train_StdReturn : 7.4081292152404785
# Train_MaxReturn : 193.2936248779297
# Train_MinReturn : 135.93258666992188
# Train_AverageEpLen : 88.52212389380531
# Train_EnvstepsSoFar : 271195
# TimeSinceStart : 69.18161821365356
# Training Loss : 3.6178970336914062
# Baseline Loss : 0.3312598168849945
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.37928771972656
# Eval_StdReturn : 2.6717617511749268
# Eval_MaxReturn : 184.86900329589844
# Eval_MinReturn : 176.3037567138672
# Eval_AverageEpLen : 89.5
# Train_AverageReturn : 177.9886016845703
# Train_StdReturn : 3.767061471939087
# Train_MaxReturn : 185.9752655029297
# Train_MinReturn : 166.0644989013672
# Train_AverageEpLen : 89.46428571428571
# Train_EnvstepsSoFar : 281215
# TimeSinceStart : 71.48779797554016
# Training Loss : -2.288545846939087
# Baseline Loss : 0.2777478098869324
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.6162567138672
# Eval_StdReturn : 3.9437272548675537
# Eval_MaxReturn : 183.7933349609375
# Eval_MinReturn : 170.94302368164062
# Eval_AverageEpLen : 89.0
# Train_AverageReturn : 177.722412109375
# Train_StdReturn : 3.589015245437622
# Train_MaxReturn : 185.10934448242188
# Train_MinReturn : 168.87815856933594
# Train_AverageEpLen : 89.33928571428571
# Train_EnvstepsSoFar : 291221
# TimeSinceStart : 73.71254706382751
# Training Loss : -6.166252136230469
# Baseline Loss : 0.3094395101070404
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.6414794921875
# Eval_StdReturn : 3.983882188796997
# Eval_MaxReturn : 183.036865234375
# Eval_MinReturn : 168.23765563964844
# Eval_AverageEpLen : 88.91666666666667
# Train_AverageReturn : 176.4545440673828
# Train_StdReturn : 4.5846123695373535
# Train_MaxReturn : 186.53086853027344
# Train_MinReturn : 160.07501220703125
# Train_AverageEpLen : 88.66371681415929
# Train_EnvstepsSoFar : 301240
# TimeSinceStart : 75.97591018676758
# Training Loss : -3.448334217071533
# Baseline Loss : 0.28404319286346436
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.5958709716797
# Eval_StdReturn : 3.2051496505737305
# Eval_MaxReturn : 181.9214630126953
# Eval_MinReturn : 170.9449005126953
# Eval_AverageEpLen : 89.16666666666667
# Train_AverageReturn : 176.045166015625
# Train_StdReturn : 4.498833179473877
# Train_MaxReturn : 187.79290771484375
# Train_MinReturn : 162.42930603027344
# Train_AverageEpLen : 88.53982300884955
# Train_EnvstepsSoFar : 311245
# TimeSinceStart : 78.79133105278015
# Training Loss : 2.6335337162017822
# Baseline Loss : 0.2692306935787201
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.60704040527344
# Eval_StdReturn : 2.896327018737793
# Eval_MaxReturn : 181.45127868652344
# Eval_MinReturn : 171.20864868164062
# Eval_AverageEpLen : 89.08333333333333
# Train_AverageReturn : 176.36851501464844
# Train_StdReturn : 4.048992156982422
# Train_MaxReturn : 183.39071655273438
# Train_MinReturn : 166.2803497314453
# Train_AverageEpLen : 88.97345132743362
# Train_EnvstepsSoFar : 321299
# TimeSinceStart : 81.04540705680847
# Training Loss : 4.797688961029053
# Baseline Loss : 0.26415345072746277
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10083 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.0833282470703
# Eval_StdReturn : 3.3587965965270996
# Eval_MaxReturn : 183.6621551513672
# Eval_MinReturn : 170.0604248046875
# Eval_AverageEpLen : 88.83333333333333
# Train_AverageReturn : 176.82974243164062
# Train_StdReturn : 3.30700421333313
# Train_MaxReturn : 183.87217712402344
# Train_MinReturn : 165.77774047851562
# Train_AverageEpLen : 89.23008849557522
# Train_EnvstepsSoFar : 331382
# TimeSinceStart : 83.56769013404846
# Training Loss : 1.239716649055481
# Baseline Loss : 0.22815796732902527
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.7760467529297
# Eval_StdReturn : 3.2348625659942627
# Eval_MaxReturn : 181.86241149902344
# Eval_MinReturn : 171.8521270751953
# Eval_AverageEpLen : 89.75
# Train_AverageReturn : 176.92257690429688
# Train_StdReturn : 4.094015121459961
# Train_MaxReturn : 185.02340698242188
# Train_MinReturn : 164.57220458984375
# Train_AverageEpLen : 89.23893805309734
# Train_EnvstepsSoFar : 341466
# TimeSinceStart : 85.83770322799683
# Training Loss : -4.887913227081299
# Baseline Loss : 0.22673270106315613
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.0136260986328
# Eval_StdReturn : 4.467716693878174
# Eval_MaxReturn : 183.2973175048828
# Eval_MinReturn : 168.77694702148438
# Eval_AverageEpLen : 89.66666666666667
# Train_AverageReturn : 177.68321228027344
# Train_StdReturn : 3.6638243198394775
# Train_MaxReturn : 187.00601196289062
# Train_MinReturn : 167.70382690429688
# Train_AverageEpLen : 89.58928571428571
# Train_EnvstepsSoFar : 351500
# TimeSinceStart : 88.10256314277649
# Training Loss : -4.913328170776367
# Baseline Loss : 0.22760550677776337
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.56683349609375
# Eval_StdReturn : 9.075020790100098
# Eval_MaxReturn : 183.84017944335938
# Eval_MinReturn : 149.32371520996094
# Eval_AverageEpLen : 89.0
# Train_AverageReturn : 178.0816650390625
# Train_StdReturn : 4.395930767059326
# Train_MaxReturn : 186.0050048828125
# Train_MinReturn : 152.13499450683594
# Train_AverageEpLen : 89.89285714285714
# Train_EnvstepsSoFar : 361568
# TimeSinceStart : 90.46881198883057
# Training Loss : 0.28306955099105835
# Baseline Loss : 0.21011431515216827
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.81321716308594
# Eval_StdReturn : 3.6670174598693848
# Eval_MaxReturn : 188.32931518554688
# Eval_MinReturn : 174.3409423828125
# Eval_AverageEpLen : 91.9090909090909
# Train_AverageReturn : 179.62799072265625
# Train_StdReturn : 4.110069274902344
# Train_MaxReturn : 191.170654296875
# Train_MinReturn : 164.03802490234375
# Train_AverageEpLen : 90.63063063063063
# Train_EnvstepsSoFar : 371628
# TimeSinceStart : 93.01831030845642
# Training Loss : 3.7869322299957275
# Baseline Loss : 0.23923230171203613
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.80709838867188
# Eval_StdReturn : 3.7616512775421143
# Eval_MaxReturn : 187.6729278564453
# Eval_MinReturn : 173.03118896484375
# Eval_AverageEpLen : 91.63636363636364
# Train_AverageReturn : 180.4460906982422
# Train_StdReturn : 4.217000961303711
# Train_MaxReturn : 189.16970825195312
# Train_MinReturn : 161.9331512451172
# Train_AverageEpLen : 91.43636363636364
# Train_EnvstepsSoFar : 381686
# TimeSinceStart : 95.44599223136902
# Training Loss : 1.6805208921432495
# Baseline Loss : 0.23025162518024445
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 183.55186462402344
# Eval_StdReturn : 3.4172911643981934
# Eval_MaxReturn : 188.1671142578125
# Eval_MinReturn : 175.86036682128906
# Eval_AverageEpLen : 93.36363636363636
# Train_AverageReturn : 181.54757690429688
# Train_StdReturn : 4.230774879455566
# Train_MaxReturn : 191.68634033203125
# Train_MinReturn : 167.14852905273438
# Train_AverageEpLen : 92.20183486238533
# Train_EnvstepsSoFar : 391736
# TimeSinceStart : 97.80210614204407
# Training Loss : -3.5559325218200684
# Baseline Loss : 0.23655642569065094
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 183.4828643798828
# Eval_StdReturn : 2.9240121841430664
# Eval_MaxReturn : 187.15330505371094
# Eval_MinReturn : 177.05735778808594
# Eval_AverageEpLen : 93.45454545454545
# Train_AverageReturn : 181.252197265625
# Train_StdReturn : 10.457286834716797
# Train_MaxReturn : 199.41697692871094
# Train_MinReturn : 90.13119506835938
# Train_AverageEpLen : 92.1651376146789
# Train_EnvstepsSoFar : 401782
# TimeSinceStart : 100.00793218612671
# Training Loss : -3.9178712368011475
# Baseline Loss : 0.256772518157959
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.2194061279297
# Eval_StdReturn : 7.586533546447754
# Eval_MaxReturn : 190.56668090820312
# Eval_MinReturn : 162.52468872070312
# Eval_AverageEpLen : 92.9090909090909
# Train_AverageReturn : 182.9626007080078
# Train_StdReturn : 4.516389846801758
# Train_MaxReturn : 193.4253387451172
# Train_MinReturn : 161.0337371826172
# Train_AverageEpLen : 93.05555555555556
# Train_EnvstepsSoFar : 411832
# TimeSinceStart : 102.34242606163025
# Training Loss : 0.9449018836021423
# Baseline Loss : 0.22060830891132355
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.84327697753906
# Eval_StdReturn : 22.36758041381836
# Eval_MaxReturn : 196.44027709960938
# Eval_MinReturn : 110.56526947021484
# Eval_AverageEpLen : 92.0
# Train_AverageReturn : 182.97215270996094
# Train_StdReturn : 6.397159576416016
# Train_MaxReturn : 193.38002014160156
# Train_MinReturn : 152.75018310546875
# Train_AverageEpLen : 93.26851851851852
# Train_EnvstepsSoFar : 421905
# TimeSinceStart : 104.59361219406128
# Training Loss : 2.177523136138916
# Baseline Loss : 0.23551060259342194
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.29916381835938
# Eval_StdReturn : 11.836360931396484
# Eval_MaxReturn : 191.70614624023438
# Eval_MinReturn : 148.022216796875
# Eval_AverageEpLen : 93.36363636363636
# Train_AverageReturn : 179.63124084472656
# Train_StdReturn : 15.924419403076172
# Train_MaxReturn : 193.81381225585938
# Train_MinReturn : 86.46470642089844
# Train_AverageEpLen : 91.76146788990826
# Train_EnvstepsSoFar : 431907
# TimeSinceStart : 107.34816408157349
# Training Loss : -1.9616650342941284
# Baseline Loss : 0.2741630971431732
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10089 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.89224243164062
# Eval_StdReturn : 4.322713851928711
# Eval_MaxReturn : 192.71937561035156
# Eval_MinReturn : 178.78269958496094
# Eval_AverageEpLen : 95.0909090909091
# Train_AverageReturn : 181.24017333984375
# Train_StdReturn : 10.740130424499512
# Train_MaxReturn : 192.64859008789062
# Train_MinReturn : 102.03016662597656
# Train_AverageEpLen : 92.55963302752293
# Train_EnvstepsSoFar : 441996
# TimeSinceStart : 109.97549700737
# Training Loss : -2.466906785964966
# Baseline Loss : 0.23915868997573853
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.51426696777344
# Eval_StdReturn : 18.365720748901367
# Eval_MaxReturn : 193.61419677734375
# Eval_MinReturn : 121.72804260253906
# Eval_AverageEpLen : 91.0909090909091
# Train_AverageReturn : 182.3294219970703
# Train_StdReturn : 10.29552936553955
# Train_MaxReturn : 194.0314178466797
# Train_MinReturn : 112.19766998291016
# Train_AverageEpLen : 93.22222222222223
# Train_EnvstepsSoFar : 452064
# TimeSinceStart : 113.09416818618774
# Training Loss : 0.11285647749900818
# Baseline Loss : 0.23406606912612915
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.61138916015625
# Eval_StdReturn : 3.9728550910949707
# Eval_MaxReturn : 190.16673278808594
# Eval_MinReturn : 174.76803588867188
# Eval_AverageEpLen : 92.0909090909091
# Train_AverageReturn : 181.95751953125
# Train_StdReturn : 12.692766189575195
# Train_MaxReturn : 193.23265075683594
# Train_MinReturn : 95.47834777832031
# Train_AverageEpLen : 93.1574074074074
# Train_EnvstepsSoFar : 462125
# TimeSinceStart : 116.48115420341492
# Training Loss : 2.6509437561035156
# Baseline Loss : 0.23631718754768372
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.10467529296875
# Eval_StdReturn : 3.8197264671325684
# Eval_MaxReturn : 190.2527313232422
# Eval_MinReturn : 177.29519653320312
# Eval_AverageEpLen : 93.18181818181819
# Train_AverageReturn : 182.3565216064453
# Train_StdReturn : 3.8027613162994385
# Train_MaxReturn : 193.5775909423828
# Train_MinReturn : 170.27288818359375
# Train_AverageEpLen : 93.1574074074074
# Train_EnvstepsSoFar : 472186
# TimeSinceStart : 118.87644410133362
# Training Loss : 0.7869778275489807
# Baseline Loss : 0.18957267701625824
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.79913330078125
# Eval_StdReturn : 3.3577020168304443
# Eval_MaxReturn : 187.90878295898438
# Eval_MinReturn : 177.06480407714844
# Eval_AverageEpLen : 93.0909090909091
# Train_AverageReturn : 181.57125854492188
# Train_StdReturn : 4.634644508361816
# Train_MaxReturn : 192.72430419921875
# Train_MinReturn : 171.80230712890625
# Train_AverageEpLen : 92.87962962962963
# Train_EnvstepsSoFar : 482217
# TimeSinceStart : 121.16281509399414
# Training Loss : -2.2396411895751953
# Baseline Loss : 0.18631842732429504
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10043 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 183.3463592529297
# Eval_StdReturn : 3.224125862121582
# Eval_MaxReturn : 190.19583129882812
# Eval_MinReturn : 178.37913513183594
# Eval_AverageEpLen : 93.0
# Train_AverageReturn : 182.11766052246094
# Train_StdReturn : 3.8734323978424072
# Train_MaxReturn : 191.16273498535156
# Train_MinReturn : 171.51531982421875
# Train_AverageEpLen : 92.99074074074075
# Train_EnvstepsSoFar : 492260
# TimeSinceStart : 123.36596608161926
# Training Loss : -1.8369460105895996
# Baseline Loss : 0.17653852701187134
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.85008239746094
# Eval_StdReturn : 3.5556936264038086
# Eval_MaxReturn : 184.3037567138672
# Eval_MinReturn : 173.26649475097656
# Eval_AverageEpLen : 91.0
# Train_AverageReturn : 180.89926147460938
# Train_StdReturn : 4.156935214996338
# Train_MaxReturn : 191.63339233398438
# Train_MinReturn : 169.53233337402344
# Train_AverageEpLen : 92.01834862385321
# Train_EnvstepsSoFar : 502290
# TimeSinceStart : 125.89650011062622
# Training Loss : 1.3397306203842163
# Baseline Loss : 0.1724606156349182
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.10302734375
# Eval_StdReturn : 4.658829689025879
# Eval_MaxReturn : 187.1702117919922
# Eval_MinReturn : 173.44505310058594
# Eval_AverageEpLen : 91.45454545454545
# Train_AverageReturn : 179.78050231933594
# Train_StdReturn : 3.9781720638275146
# Train_MaxReturn : 187.7083282470703
# Train_MinReturn : 169.4093780517578
# Train_AverageEpLen : 91.02727272727273
# Train_EnvstepsSoFar : 512303
# TimeSinceStart : 128.78945994377136
# Training Loss : 0.8361237049102783
# Baseline Loss : 0.15338034927845
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.0638427734375
# Eval_StdReturn : 21.208858489990234
# Eval_MaxReturn : 188.62379455566406
# Eval_MinReturn : 104.31477355957031
# Eval_AverageEpLen : 87.41666666666667
# Train_AverageReturn : 180.02174377441406
# Train_StdReturn : 4.064813137054443
# Train_MaxReturn : 195.613037109375
# Train_MinReturn : 166.1382293701172
# Train_AverageEpLen : 90.66666666666667
# Train_EnvstepsSoFar : 522367
# TimeSinceStart : 134.29544019699097
# Training Loss : -2.6079201698303223
# Baseline Loss : 0.16277147829532623
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.31982421875
# Eval_StdReturn : 17.739444732666016
# Eval_MaxReturn : 200.6932373046875
# Eval_MinReturn : 133.9120330810547
# Eval_AverageEpLen : 88.5
# Train_AverageReturn : 177.6698455810547
# Train_StdReturn : 15.010586738586426
# Train_MaxReturn : 202.6684112548828
# Train_MinReturn : 66.73616790771484
# Train_AverageEpLen : 89.4375
# Train_EnvstepsSoFar : 532384
# TimeSinceStart : 138.24876523017883
# Training Loss : -0.08414297550916672
# Baseline Loss : 0.20669056475162506
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10079 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.8790740966797
# Eval_StdReturn : 34.20947265625
# Eval_MaxReturn : 207.58270263671875
# Eval_MinReturn : 69.39015197753906
# Eval_AverageEpLen : 87.41666666666667
# Train_AverageReturn : 176.47557067871094
# Train_StdReturn : 15.1990966796875
# Train_MaxReturn : 209.28021240234375
# Train_MinReturn : 84.27336883544922
# Train_AverageEpLen : 88.41228070175438
# Train_EnvstepsSoFar : 542463
# TimeSinceStart : 141.64074802398682
# Training Loss : 1.792264699935913
# Baseline Loss : 0.23485417664051056
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.2146453857422
# Eval_StdReturn : 45.35588073730469
# Eval_MaxReturn : 247.74771118164062
# Eval_MinReturn : 88.33689880371094
# Eval_AverageEpLen : 94.0
# Train_AverageReturn : 180.30783081054688
# Train_StdReturn : 21.598920822143555
# Train_MaxReturn : 249.35597229003906
# Train_MinReturn : 72.89678192138672
# Train_AverageEpLen : 89.36607142857143
# Train_EnvstepsSoFar : 552472
# TimeSinceStart : 144.70493531227112
# Training Loss : 0.6699708700180054
# Baseline Loss : 0.3946899473667145
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.76519775390625
# Eval_StdReturn : 88.10717010498047
# Eval_MaxReturn : 347.42303466796875
# Eval_MinReturn : 101.00322723388672
# Eval_AverageEpLen : 89.66666666666667
# Train_AverageReturn : 185.64755249023438
# Train_StdReturn : 48.11101531982422
# Train_MaxReturn : 291.4032287597656
# Train_MinReturn : 71.01297760009766
# Train_AverageEpLen : 90.36036036036036
# Train_EnvstepsSoFar : 562502
# TimeSinceStart : 147.71277618408203
# Training Loss : 4.932362079620361
# Baseline Loss : 1.097381830215454
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10111 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.5689239501953
# Eval_StdReturn : 91.21085357666016
# Eval_MaxReturn : 358.5233154296875
# Eval_MinReturn : 103.0888900756836
# Eval_AverageEpLen : 84.58333333333333
# Train_AverageReturn : 179.77597045898438
# Train_StdReturn : 73.6172103881836
# Train_MaxReturn : 363.91253662109375
# Train_MinReturn : 83.30830383300781
# Train_AverageEpLen : 87.16379310344827
# Train_EnvstepsSoFar : 572613
# TimeSinceStart : 150.8633153438568
# Training Loss : 4.887069225311279
# Baseline Loss : 2.007904529571533
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 258.9291076660156
# Eval_StdReturn : 73.44107055664062
# Eval_MaxReturn : 348.8542785644531
# Eval_MinReturn : 110.64781188964844
# Eval_AverageEpLen : 109.6
# Train_AverageReturn : 176.6762237548828
# Train_StdReturn : 78.20333862304688
# Train_MaxReturn : 377.0394287109375
# Train_MinReturn : 100.2059326171875
# Train_AverageEpLen : 85.03389830508475
# Train_EnvstepsSoFar : 582647
# TimeSinceStart : 154.00117826461792
# Training Loss : 7.844192981719971
# Baseline Loss : 1.664724349975586
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 266.3411560058594
# Eval_StdReturn : 49.6622200012207
# Eval_MaxReturn : 339.2164611816406
# Eval_MinReturn : 184.92697143554688
# Eval_AverageEpLen : 118.0
# Train_AverageReturn : 205.0462188720703
# Train_StdReturn : 85.5660400390625
# Train_MaxReturn : 392.6340026855469
# Train_MinReturn : 100.46287536621094
# Train_AverageEpLen : 93.94392523364486
# Train_EnvstepsSoFar : 592699
# TimeSinceStart : 157.2723970413208
# Training Loss : 0.4599519371986389
# Baseline Loss : 1.3407669067382812
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 296.9274597167969
# Eval_StdReturn : 101.88809204101562
# Eval_MaxReturn : 558.0889892578125
# Eval_MinReturn : 166.40611267089844
# Eval_AverageEpLen : 126.33333333333333
# Train_AverageReturn : 273.8052673339844
# Train_StdReturn : 62.74302291870117
# Train_MaxReturn : 379.49884033203125
# Train_MinReturn : 124.30669403076172
# Train_AverageEpLen : 118.03529411764706
# Train_EnvstepsSoFar : 602732
# TimeSinceStart : 160.92142510414124
# Training Loss : -7.127630233764648
# Baseline Loss : 1.1706174612045288
# Initial_DataCollection_AverageReturn : 9.500977516174316
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 393.617431640625
# Eval_StdReturn : 88.2735824584961
# Eval_MaxReturn : 529.417724609375
# Eval_MinReturn : 265.01043701171875
# Eval_AverageEpLen : 153.71428571428572
# Train_AverageReturn : 300.674560546875
# Train_StdReturn : 62.62745666503906
# Train_MaxReturn : 453.3110046386719
# Train_MinReturn : 166.2427978515625
# Train_AverageEpLen : 125.9125
# Train_EnvstepsSoFar : 612805
# TimeSinceStart : 164.36750626564026
# ...
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 422.13824462890625
# Eval_StdReturn : 99.87500762939453
# Eval_MaxReturn : 586.4161987304688
# Eval_MinReturn : 282.6617431640625
# Eval_AverageEpLen : 161.57142857142858
# Train_AverageReturn : 378.7527770996094
# Train_StdReturn : 145.16244506835938
# Train_MaxReturn : 673.3089599609375
# Train_MinReturn : 162.5459442138672
# Train_AverageEpLen : 149.4179104477612
# Train_EnvstepsSoFar : 805120
# TimeSinceStart : 200.4930317401886
# Training Loss : -8.70356559753418
# Baseline Loss : 0.6236966252326965
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 408.0314025878906
# Eval_StdReturn : 96.3336410522461
# Eval_MaxReturn : 520.911376953125
# Eval_MinReturn : 200.90890502929688
# Eval_AverageEpLen : 159.71428571428572
# Train_AverageReturn : 408.6705627441406
# Train_StdReturn : 119.8559799194336
# Train_MaxReturn : 698.3059692382812
# Train_MinReturn : 169.4593963623047
# Train_AverageEpLen : 159.06349206349208
# Train_EnvstepsSoFar : 815141
# TimeSinceStart : 203.66240787506104
# Training Loss : -8.774166107177734
# Baseline Loss : 0.5547977089881897
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10112 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 434.6896667480469
# Eval_StdReturn : 116.71605682373047
# Eval_MaxReturn : 607.9512939453125
# Eval_MinReturn : 272.3955383300781
# Eval_AverageEpLen : 167.57142857142858
# Train_AverageReturn : 408.9177551269531
# Train_StdReturn : 110.9968490600586
# Train_MaxReturn : 585.6668701171875
# Train_MinReturn : 189.8980712890625
# Train_AverageEpLen : 155.56923076923076
# Train_EnvstepsSoFar : 825253
# TimeSinceStart : 206.35286903381348
# Training Loss : -7.585582733154297
# Baseline Loss : 0.6240123510360718
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10177 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 382.92987060546875
# Eval_StdReturn : 104.00707244873047
# Eval_MaxReturn : 540.1837768554688
# Eval_MinReturn : 203.58758544921875
# Eval_AverageEpLen : 145.85714285714286
# Train_AverageReturn : 428.8565368652344
# Train_StdReturn : 99.25067901611328
# Train_MaxReturn : 621.311279296875
# Train_MinReturn : 159.52313232421875
# Train_AverageEpLen : 161.53968253968253
# Train_EnvstepsSoFar : 835430
# TimeSinceStart : 209.136962890625
# Training Loss : -0.4527035057544708
# Baseline Loss : 0.5609318614006042
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10103 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 486.6894226074219
# Eval_StdReturn : 82.79618835449219
# Eval_MaxReturn : 602.277099609375
# Eval_MinReturn : 347.22772216796875
# Eval_AverageEpLen : 163.0
# Train_AverageReturn : 430.5422058105469
# Train_StdReturn : 75.13652038574219
# Train_MaxReturn : 558.92578125
# Train_MinReturn : 196.83584594726562
# Train_AverageEpLen : 157.859375
# Train_EnvstepsSoFar : 845533
# TimeSinceStart : 211.77870297431946
# Training Loss : 3.3937158584594727
# Baseline Loss : 0.5190415382385254
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 404.6648864746094
# Eval_StdReturn : 68.9294204711914
# Eval_MaxReturn : 525.0241088867188
# Eval_MinReturn : 280.18072509765625
# Eval_AverageEpLen : 150.57142857142858
# Train_AverageReturn : 434.0107421875
# Train_StdReturn : 84.2726058959961
# Train_MaxReturn : 603.1900634765625
# Train_MinReturn : 191.69467163085938
# Train_AverageEpLen : 157.203125
# Train_EnvstepsSoFar : 855594
# TimeSinceStart : 214.93306303024292
# Training Loss : 8.891362190246582
# Baseline Loss : 0.4457457363605499
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 410.5070495605469
# Eval_StdReturn : 141.05445861816406
# Eval_MaxReturn : 516.3013916015625
# Eval_MinReturn : 70.94774627685547
# Eval_AverageEpLen : 146.28571428571428
# Train_AverageReturn : 433.9528503417969
# Train_StdReturn : 90.03158569335938
# Train_MaxReturn : 592.8482666015625
# Train_MinReturn : 79.93309020996094
# Train_AverageEpLen : 153.98461538461538
# Train_EnvstepsSoFar : 865603
# TimeSinceStart : 217.47194600105286
# Training Loss : 7.675684928894043
# Baseline Loss : 0.37891826033592224
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10151 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 455.9553527832031
# Eval_StdReturn : 42.88347625732422
# Eval_MaxReturn : 521.9700317382812
# Eval_MinReturn : 399.19244384765625
# Eval_AverageEpLen : 162.0
# Train_AverageReturn : 432.19464111328125
# Train_StdReturn : 68.21906280517578
# Train_MaxReturn : 617.8305053710938
# Train_MinReturn : 307.0013122558594
# Train_AverageEpLen : 156.16923076923078
# Train_EnvstepsSoFar : 875754
# TimeSinceStart : 219.84716701507568
# Training Loss : 7.154693603515625
# Baseline Loss : 0.35016441345214844
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10142 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 465.7293395996094
# Eval_StdReturn : 55.586219787597656
# Eval_MaxReturn : 557.2034912109375
# Eval_MinReturn : 376.97900390625
# Eval_AverageEpLen : 157.57142857142858
# Train_AverageReturn : 435.5971374511719
# Train_StdReturn : 69.12062072753906
# Train_MaxReturn : 543.0913696289062
# Train_MinReturn : 193.7534637451172
# Train_AverageEpLen : 153.66666666666666
# Train_EnvstepsSoFar : 885896
# TimeSinceStart : 222.88266110420227
# Training Loss : 0.26104310154914856
# Baseline Loss : 0.3344828486442566
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 418.6644592285156
# Eval_StdReturn : 71.53462982177734
# Eval_MaxReturn : 508.9302673339844
# Eval_MinReturn : 279.7441101074219
# Eval_AverageEpLen : 147.14285714285714
# Train_AverageReturn : 435.646728515625
# Train_StdReturn : 63.68866729736328
# Train_MaxReturn : 589.4669189453125
# Train_MinReturn : 318.6629943847656
# Train_AverageEpLen : 156.59375
# Train_EnvstepsSoFar : 895918
# TimeSinceStart : 225.5471510887146
# Training Loss : -4.005387783050537
# Baseline Loss : 0.34517520666122437
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10109 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 423.5730285644531
# Eval_StdReturn : 27.533781051635742
# Eval_MaxReturn : 450.1703186035156
# Eval_MinReturn : 370.846435546875
# Eval_AverageEpLen : 149.42857142857142
# Train_AverageReturn : 429.74169921875
# Train_StdReturn : 75.40276336669922
# Train_MaxReturn : 582.8546752929688
# Train_MinReturn : 96.30882263183594
# Train_AverageEpLen : 153.16666666666666
# Train_EnvstepsSoFar : 906027
# TimeSinceStart : 227.89680004119873
# Training Loss : -10.83755874633789
# Baseline Loss : 0.35494887828826904
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10150 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 403.37738037109375
# Eval_StdReturn : 59.3282356262207
# Eval_MaxReturn : 467.7039489746094
# Eval_MinReturn : 314.720703125
# Eval_AverageEpLen : 144.71428571428572
# Train_AverageReturn : 452.47723388671875
# Train_StdReturn : 72.82998657226562
# Train_MaxReturn : 593.5802612304688
# Train_MinReturn : 280.2755126953125
# Train_AverageEpLen : 158.59375
# Train_EnvstepsSoFar : 916177
# TimeSinceStart : 230.4623429775238
# Training Loss : -12.226033210754395
# Baseline Loss : 0.36416447162628174
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 473.4704895019531
# Eval_StdReturn : 47.56496047973633
# Eval_MaxReturn : 531.1507568359375
# Eval_MinReturn : 391.47406005859375
# Eval_AverageEpLen : 162.85714285714286
# Train_AverageReturn : 437.35833740234375
# Train_StdReturn : 77.6292495727539
# Train_MaxReturn : 590.396728515625
# Train_MinReturn : 244.8422088623047
# Train_AverageEpLen : 154.4
# Train_EnvstepsSoFar : 926213
# TimeSinceStart : 233.3029501438141
# Training Loss : -8.121667861938477
# Baseline Loss : 0.3640673756599426
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10145 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 439.766357421875
# Eval_StdReturn : 78.14543151855469
# Eval_MaxReturn : 503.3880920410156
# Eval_MinReturn : 271.43914794921875
# Eval_AverageEpLen : 154.42857142857142
# Train_AverageReturn : 459.5625
# Train_StdReturn : 70.31180572509766
# Train_MaxReturn : 570.9586181640625
# Train_MinReturn : 263.2818298339844
# Train_AverageEpLen : 158.515625
# Train_EnvstepsSoFar : 936358
# TimeSinceStart : 235.73876905441284
# Training Loss : -5.447892665863037
# Baseline Loss : 0.3237452805042267
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 462.0870056152344
# Eval_StdReturn : 83.24287414550781
# Eval_MaxReturn : 532.6211547851562
# Eval_MinReturn : 311.37237548828125
# Eval_AverageEpLen : 160.42857142857142
# Train_AverageReturn : 433.7996520996094
# Train_StdReturn : 78.70532989501953
# Train_MaxReturn : 599.389404296875
# Train_MinReturn : 223.4217529296875
# Train_AverageEpLen : 154.92307692307693
# Train_EnvstepsSoFar : 946428
# TimeSinceStart : 238.23215103149414
# Training Loss : 0.3209390342235565
# Baseline Loss : 0.46024101972579956
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10125 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 406.7316589355469
# Eval_StdReturn : 73.8282241821289
# Eval_MaxReturn : 503.31243896484375
# Eval_MinReturn : 293.76593017578125
# Eval_AverageEpLen : 150.0
# Train_AverageReturn : 440.9371337890625
# Train_StdReturn : 81.99354553222656
# Train_MaxReturn : 585.0748291015625
# Train_MinReturn : 271.6978759765625
# Train_AverageEpLen : 158.203125
# Train_EnvstepsSoFar : 956553
# TimeSinceStart : 240.65945386886597
# Training Loss : 4.926810264587402
# Baseline Loss : 0.4241740107536316
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10153 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 484.917724609375
# Eval_StdReturn : 37.48832702636719
# Eval_MaxReturn : 553.5322875976562
# Eval_MinReturn : 451.1029357910156
# Eval_AverageEpLen : 173.0
# Train_AverageReturn : 436.7250671386719
# Train_StdReturn : 82.32850646972656
# Train_MaxReturn : 590.586669921875
# Train_MinReturn : 269.5
# Train_AverageEpLen : 153.83333333333334
# Train_EnvstepsSoFar : 966706
# TimeSinceStart : 243.20043301582336
# Training Loss : 4.224628925323486
# Baseline Loss : 0.41491463780403137
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10121 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 466.64776611328125
# Eval_StdReturn : 63.23179626464844
# Eval_MaxReturn : 541.984375
# Eval_MinReturn : 349.10784912109375
# Eval_AverageEpLen : 163.28571428571428
# Train_AverageReturn : 416.9774169921875
# Train_StdReturn : 87.89811706542969
# Train_MaxReturn : 585.9326782226562
# Train_MinReturn : 228.4256591796875
# Train_AverageEpLen : 151.0597014925373
# Train_EnvstepsSoFar : 976827
# TimeSinceStart : 245.96929502487183
# Training Loss : 5.486191749572754
# Baseline Loss : 0.4211598336696625
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10119 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 443.6747741699219
# Eval_StdReturn : 56.63798522949219
# Eval_MaxReturn : 516.73974609375
# Eval_MinReturn : 353.4120178222656
# Eval_AverageEpLen : 163.0
# Train_AverageReturn : 443.8443908691406
# Train_StdReturn : 85.50463104248047
# Train_MaxReturn : 634.320556640625
# Train_MinReturn : 218.77352905273438
# Train_AverageEpLen : 158.109375
# Train_EnvstepsSoFar : 986946
# TimeSinceStart : 248.98706912994385
# Training Loss : -2.318537712097168
# Baseline Loss : 0.3877870738506317
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10116 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 419.1817321777344
# Eval_StdReturn : 103.37062072753906
# Eval_MaxReturn : 576.408935546875
# Eval_MinReturn : 295.8500061035156
# Eval_AverageEpLen : 152.14285714285714
# Train_AverageReturn : 456.8051452636719
# Train_StdReturn : 79.68352508544922
# Train_MaxReturn : 602.3704833984375
# Train_MinReturn : 236.88836669921875
# Train_AverageEpLen : 160.57142857142858
# Train_EnvstepsSoFar : 997062
# TimeSinceStart : 251.60721492767334
# Training Loss : -6.179367542266846
# Baseline Loss : 0.39991816878318787
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 370.4044494628906
# Eval_StdReturn : 42.034603118896484
# Eval_MaxReturn : 430.56707763671875
# Eval_MinReturn : 322.6993103027344
# Eval_AverageEpLen : 146.71428571428572
# Train_AverageReturn : 437.623046875
# Train_StdReturn : 77.86119079589844
# Train_MaxReturn : 598.3682861328125
# Train_MinReturn : 254.3385467529297
# Train_AverageEpLen : 156.96875
# Train_EnvstepsSoFar : 1007108
# TimeSinceStart : 254.2041881084442
# Training Loss : -2.4993152618408203
# Baseline Loss : 0.3305756747722626
# Initial_DataCollection_AverageReturn : 18.539552688598633
# Done logging...

# %%
# Plot learning curves
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# /Users/jangdong-eon/miniforge3/envs/hw4/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.
